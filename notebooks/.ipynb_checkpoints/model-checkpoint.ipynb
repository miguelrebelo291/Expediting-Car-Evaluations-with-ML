# %% [markdown]
# # Cars 4 You - Car Price Prediction
#
# ## Group Member Contribution
#
# | Number | Member | Contribution | Estimated % |
# |--------|--------|--------------|-------------|
# |20250391|Guilherme Vieira| Webscraping, EDA, Preprocessing, Neural Networks, Model Optimization and Deployment, Open-Ended Section|30%|
# |20250358 | Miguel Rebelo | EDA, Preprocessing, Decision Trees, Model Optimization and Deployment,Open-Ended Section |30%|
# |20250371| João Roque | EDA, Random Forest, Model Optimization and Deployment,Open-Ended Section |25%|
# |20240940| Rita Escudeiro | EDA, Linear Regression, Ridge Regression |15%|

# %% [markdown]
# ## Abstract
#
# This project addresses the business challenge faced by Cars 4 You, an online car resale company seeking to expedite their car evaluation process. The primary objective is to develop a regression model capable of accurately predicting car prices based on user-provided features.
#
# We employed a comprehensive machine learning pipeline incorporating data preprocessing with custom transformers for handling missing values through mode imputation, grouped by brand and model, and categorical encoding with rare label grouping. Five regression algorithms were benchmarked: Linear Regression, Ridge Regression, Decision Trees, Random Forest, and Neural Networks.
#
# Our model assessment strategy utilized 5-fold cross-validation with Mean Absolute Error (MAE) as the primary metric, supplemented by RMSE and R² for comprehensive evaluation. Feature selection was performed using Recursive Feature Elimination (RFE), Lasso-based coefficient analysis, and ESCREVERAQUI O DA DT. Hyperparameter tuning was conducted through GridSearchCV and RandomizedSearchCV.
#
# The Random Forest model achieved the best generalization performance with a cross-validated MAE of approximately X,XXX. The open-ended section explores different preprocessing strategies through various pipelines, and brand-specific vs general model comparison.

# %% [markdown]
# # 0. Import Packages

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast
from math import ceil
from sklearn.feature_selection import RFE
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, FunctionTransformer, StandardScaler, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV, ElasticNetCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, make_scorer
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
from sklearn.impute import KNNImputer
from sklearn.model_selection import cross_val_score
from sklearn.utils.validation import check_is_fitted, _check_feature_names_in
from sklearn.model_selection import cross_validate
from sklearn.pipeline import make_pipeline
from sklearn.base import clone
#from sklearn.utils.validation import validate_data
import joblib
pd.set_option('display.max_columns', None)
import time
from itertools import product

# %%
def evaluate_pipeline(prep_pipe, model, X, y, cv):
    pipe = Pipeline([
        ('prep', clone(PreprocessAndRemoveByName(prep_pipe, features_to_remove))),
        ('model', clone(model))
    ])
    
    scores = cross_val_score(
        pipe,
        X, y,
        cv=cv,
        scoring='neg_mean_absolute_error',
        n_jobs=-1
    )
    
    return -scores.mean(), scores.std()

# %% [markdown]
# # Identifying Business Needs
#
#
#
# ## Business Context
#
#
#
# Cars 4 You is an online car resale company facing operational challenges due to growing waiting lists for car inspections. The current process requires physical mechanic evaluation before purchasing vehicles, creating bottlenecks that drive potential customers to competitors.
#
#
#
# ## Project Goals
#
#
#
# 1. **Primary Objective**: Develop a regression model to predict car prices (target: 'price') based on user-provided specifications
#
# 2. **Secondary Objectives**:
#
#    - Identify key features influencing car prices
#
#    - Compare multiple modeling approaches
#
#    - Create a deployable prediction pipeline
#
#
#
# ## Model Assessment Strategy
#
#
#
# We adopt the following assessment approach:
#
#
#
# - **Validation Method**: 5-Fold Cross-Validation
#
#   - Provides robust performance estimates
#
#   - Balances bias-variance tradeoff in model evaluation
#
#
#
# - **Primary Metric**: Mean Absolute Error (MAE)
#
#   - Directly interpretable in business terms (pounds)
#
#   - Less sensitive to outliers than RMSE
#
#   - Appropriate for price prediction where actual error magnitude matters
#
#
#
# - **Secondary Metrics**:
#
#   - RMSE: Penalizes larger errors more heavily
#
#   - R²: Proportion of variance explained
#
#
#
# - **Hyperparameter Tuning**:
#
#   - RandomizedSearchCV for initial exploration
#
#   - GridSearchCV for fine-tuning around best parameters

# %% [markdown]
# # 1. Read Data and Inspect

# %%
#importing original data and previously worked dataframe
df_train = pd.read_csv("../project_data/handout_data/training_handout.csv")

# %%
df_train.columns
# Out:
# Index(['Unnamed: 0', 'carID', 'brand', 'model', 'price', 'transmission',
#        'mileage', 'fuelType', 'tax', 'mpg', 'engineSize', 'paintQuality%',
#        'previousOwners', 'hasDamage', 'car_age'],
#       dtype='object')

# %%
df_train.shape
# Out:
# (75973, 15)

# %%
#remove unnamed 0 column
df_train = df_train.drop(columns=['Unnamed: 0'])
df_train
# Out:
#        carID     brand     model  price transmission  mileage fuelType    tax  \
# 0      69512        vw      golf  22290    semi-auto  28421.0   petrol    NaN
# 1      53000    toyota     yaris  13790       manual   4589.0   petrol  145.0
# 2       6366      audi        q2  24990    semi-auto   3624.0   petrol  145.0
# 3      29021      ford    fiesta  12500       manual   9102.0   petrol  145.0
# 4      10062       bmw  2 series  22995       manual   1000.0   petrol  145.0
# ...      ...       ...       ...    ...          ...      ...      ...    ...
# 75968  37194  mercedes   c class  13498       manual  14480.0   petrol  125.0
# 75969   6265      audi        q3  12495    semi-auto  52134.0   diesel  200.0
# 75970  54886    toyota      aygo   8399    automatic  11304.0   petrol  145.0
# 75971    860      audi        q3  12990       manual  69072.0   diesel  125.0
# 75972  15795      ford    fiesta  10495       manual  16709.0   petrol  145.0
#
# ...

# %% [markdown]
# ### Missing Data

# %%
miss = df_train.isna().sum()
mv = pd.DataFrame({"missing": miss[miss>0], "missing_%": (miss[miss>0]/len(df_train)*100).round(2)}).sort_values("missing_%", ascending=False)
if not mv.empty:
    print("\nMissing-values summary (non-zero):")
    print(mv.head(20))
# Out:
# Missing-values summary (non-zero):
#                 missing  missing_%
# tax                8282      10.90
# mpg                7970      10.49
# transmission       2263       2.98
# engineSize         2034       2.68
# previousOwners     1921       2.53
# car_age            1849       2.43
# mileage            1832       2.41
# model              1721       2.27
# fuelType           1678       2.21
# hasDamage          1548       2.04
# paintQuality%      1524       2.01
# brand                43       0.06

# %% [markdown]
# - In most features, missing data represents a small fraction, tax and mpg being the only ones where it represents more than 10%.
# - The fact that the existing data outweighs the missing data by such a large margin, imputing the latter appears to be a good idea.

# %%
df_train[df_train["brand"].isnull()]
# Out:
#        carID brand model  price transmission  mileage fuelType    tax   mpg  \
# 442    16342   NaN   NaN   8600       manual  28820.0   diesel    0.0  74.4
# 2031   12064   NaN   NaN  21300    automatic  11258.0      NaN  145.0  64.2
# 2223   44351   NaN   NaN  12990    automatic  43000.0   diesel  145.0  54.3
# 4250   38960   NaN   NaN  25495    semi-auto   4255.0   petrol  145.0  44.8
# 5513   55454   NaN   NaN   8997       manual  11200.0   petrol   30.0  58.0
# 5967   74657   NaN   NaN  19750    semi-auto   9500.0   petrol  145.0  55.4
# 6233     669   NaN   NaN  29250    automatic  10055.0   diesel  145.0  47.9
# 7793   20208   NaN   NaN  15499    semi-auto  64315.0   diesel  145.0  54.3
# 12893  44161   NaN   NaN  14999       manual  29053.0   diesel   20.0  64.2
# 13087  65456   NaN   NaN  16500       manual   3000.0   diesel  145.0  57.7
# 13777  44380   NaN   NaN  25849    semi-auto  10977.0   petrol  145.0  47.1
# ...

# %% [markdown]
# The missing data imputation will be mainly made through the brand feature, as it will be explained later in the notebook. Due to that and to the fact that the instances where there is no information about the brand represent 0.06% of the total data, these lines will be dropped.

# %%
df_train = df_train[~df_train["brand"].isnull()]
df_train
# Out:
#        carID     brand     model  price transmission  mileage fuelType    tax  \
# 0      69512        vw      golf  22290    semi-auto  28421.0   petrol    NaN
# 1      53000    toyota     yaris  13790       manual   4589.0   petrol  145.0
# 2       6366      audi        q2  24990    semi-auto   3624.0   petrol  145.0
# 3      29021      ford    fiesta  12500       manual   9102.0   petrol  145.0
# 4      10062       bmw  2 series  22995       manual   1000.0   petrol  145.0
# ...      ...       ...       ...    ...          ...      ...      ...    ...
# 75968  37194  mercedes   c class  13498       manual  14480.0   petrol  125.0
# 75969   6265      audi        q3  12495    semi-auto  52134.0   diesel  200.0
# 75970  54886    toyota      aygo   8399    automatic  11304.0   petrol  145.0
# 75971    860      audi        q3  12990       manual  69072.0   diesel  125.0
# 75972  15795      ford    fiesta  10495       manual  16709.0   petrol  145.0
#
# ...

# %% [markdown]
# #### Removing Features Previously Identified as irrelavant in EDA

# %%
df_train = df_train.drop(columns=['carID', 'previousOwners', 'paintQuality%', 'hasDamage'])

# %%
df_train.columns
# Out:
# Index(['brand', 'model', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize', 'car_age'],
#       dtype='object')

# %% [markdown]
# ### Correlation Between Features:

# %%
numeric_cols = df_train.select_dtypes(include=['int64', 'Int64', 'float64']).columns

# Compute correlation matrix
corr_matrix = df_train[numeric_cols].corr()

# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Matrix of Numeric Variables")
plt.show()

# %% [markdown]
# - On one hand it seems like a good opportunity to use a KNN imputer because the missing data is way below the common treshold of 30% and the missing data seems to be MAR
# - On the other, the correlations between numeric variables is not the best since in most cases the r is lower than 0.3 plus the imputation of mode grouped by brand and model seems to also make very sense, as the knn imputer would be prone to do something that is out of reality like imputing models to brands that don´t exist and values that also don´t exist

# %% [markdown]
# # 2. Modify the Data

# %% [markdown]
# ## Split the data

# %%
X = df_train.drop("price", axis=1).copy()
y = df_train["price"].copy()

# %% [markdown]
# ## Pipeline construction

# %% [markdown]
# ### Column Transformers

# %%
class RareLabelGrouper(BaseEstimator, TransformerMixin):
    
    """
    This class will be useful to identify and group rare instances in the model column as "other". 
    The minimal proportion needed to not be grouped is min_prop.
    
    """
   
    def __init__(self, min_prop=0.005, column=None): 
        self.min_prop = min_prop
        
        self.column = column
        
        self.keep_values_ = None  #This will be used to store the values to group
    
    
    def fit(self, X, y=None):
        s = X if isinstance(X, pd.Series) else pd.Series(X.iloc[:,0] if hasattr(X, "iloc") else X[:,0])  # 
        
        vc = s.value_counts(dropna=False) 
        
        total = len(s)  
        
        keep = vc[vc / total >= self.min_prop].index # Chooses the categories for which the minimum proportion is met
        
        self.keep_values_ = set(keep.tolist()) # Attributes them to an attribute of the class in the form of a list
        
        return self
    
    
    def transform(self, X):
        """
        np.where() works like an if-else statement. If s is in stored values to keep, then keep s, else attribute "Other".
        To attribute the name of the column, if it was passed and stored in the attribute .column, then use that name, else use the generic 'col' name.
        """
        s = X if isinstance(X, pd.Series) else pd.Series(X.iloc[:,0] if hasattr(X, "iloc") else X[:,0])  #Same pandas series problem
        return pd.DataFrame(np.where(s.isin(self.keep_values_), s, "Other"),  
                            columns=[self.column if self.column else "col"])

    
    def get_feature_names_out(self, input_features=None):

        if input_features is not None:
            return np.asarray(input_features, dtype=object)

        col_name = self.column if self.column else "col"
        return np.asarray([col_name], dtype=object)

# %%
class CustomWinsorizer(BaseEstimator, TransformerMixin):
    
    """
    Takes care of outliers by winsorizing selected numeric variables.
    During fit(), it learns the lower and upper quantile limits for each variable.
    During transform(), any value below the lower limit is replaced with that limit, and any value above the upper limit is capped at the upper limit.
    This reduces the influence of extreme values while keeping all observations in the dataset.
    """
    
    def __init__(self, variables, lower_bound=0.01, upper_bound=0.99):
        self.variables = variables  #is a list of the columns we want to apply the transformer to (Confirmable further)
        self.lower_bound = lower_bound
        self.upper_bound = upper_bound
        self.limits_ = {} #Will store the value of the limits calculated in fit() to apply in transform()


    def fit(self, X, y=None):
        for var in self.variables:  #Iterates over all columns specified in the list
            if var in X.columns:  #Makes sure it is one of the DataFrame's columns
                lower_limit = X[var].quantile(self.lower_bound)  #Calculates the lower-limit
                upper_limit = X[var].quantile(self.upper_bound)  #Calculates the upper-limit
                self.limits_[var] = (lower_limit, upper_limit)  #Stores the limits calculated for use in transform(). It's stored associated to a key with the name of the column
        
        return self


    def transform(self, X):
        X_transformed = X.copy()
        
        for var, (lower_limit, upper_limit) in self.limits_.items():  #Iterates over all columns chosen to transform
            if var in X.columns:  #Defensive programming to make sure the column is there
                X_transformed[var] = np.clip(X_transformed[var], lower_limit, upper_limit) #Replaces values in the series that are higher than lower_limit with the lower limit and the same for the upper limit
        
        return X_transformed

# %%
class Mode_Imput_By_Brand (BaseEstimator, TransformerMixin):

    """
    O objetivo com este transformer é preencher os valores nulos de cada coluna através da moda, mas primeiro, agrupar por brand.
    Como fallback, caso nao haja nenhuma linha preenchida daquela brand em especifico, depois de utilizar este transformer
    iremos utilzar o SimpleImputer.
    
    """
    
    def __init__(self, imput_cols = None , group_col = "brand"):       
        self.imput_cols = imput_cols  #Store the imputing values for each group
        self.group_col = group_col #Stores the variable name in which we want to group to input the value we need (for example, group by the brand to input the most likely model of a given car)

    # é obrigatorio colocar X e y em todos os metodos de fit do sklearn
    def fit(self , X, y = None):
        X = X.copy()  # em qualquer metodo do sklearn criamos uma copia do df original, pois no pipeline é usado o mesmo df nao modificado para os vários passos
        
        if self.imput_cols is None: # sklearn nao gosta de args obrigatórios entao fazemos isto para contornar
            self.imput_cols = [col for col in X.columns if col != self.group_col] #Iterates over all columns that are not group_col and stores their names in a list 
        
        self.mode_maps_ = {}

        for col in self.imput_cols:  #Iterate over all columns except the group_col
            mode_map = X.groupby(self.group_col)[col].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else np.nan)  #Calculates the mode for each group and if there isn't assume np.nan
            self.mode_maps_[col] = mode_map

        return self

        
    def transform(self, X):
        X = X.copy()

        for col in self.imput_cols:  #Iterate over all columns except the group_col
            X[col] = X[col].fillna(X[self.group_col].map(self.mode_maps_[col]))  #Fills all nans in one column (col) with the mode found in the mode_maps_ dict, which contains the mode for the different groups that were grouped through the group_col

        return X

# %%
class Imput_By_Brand_and_Model (BaseEstimator, TransformerMixin):

    """

    The goal with this transformer is to fullfill the Nans by the mode,  but 1st grouping by brand and model. Has a fallback
    in the pipeline, after using this transformer, it should be used a SimplImputer to guarantee that in the end, there is no missing
    values.

    =============================================================================================================================

    Parameters:

        imput_cols: List of cols you want to imput, if none is passed then it will assume all columns should be imputed besides the 
        ones on the group_cols

        group_cols: List of cols you want to groupby, it's defaulted to be brand and model

        .mode_maps: Dictionary for each imput column, where each key is an imput_col and each value is a dictionary where each key is
                    a combiantion of brand and model and each value is the mode

    ==============================================================================================================================

    Methods:
    
        .fit: Creates a loop that for each column to imput: 0. Creates an empty dict to store each imput col as a key
                                                            1. Groups the data by the group_cols
                                                            2. Calculates the mode, if more than 1 get´s the 1st one 
                                                            if there is no value it returns Nan
                                                            3. Stores the combination of brand and model (group_cols) and mode
                                                            as a key-value pair 
        
        .transform: 1. For each row of the dataset stores the pair of (brand,model) into a Series
                    2. Loops trough the imput_cols and for each one it uses the pairs created before as a key to get the value of 
                    the mode_maps, storing this value in a Series called mapped
                    3. Goes trough each line of the data, if the value is nan it fulfiles it with the corresponding value of the
                    mapped series

    ==============================================================================================================================

    Attributes:

        mode_maps_ : Dictionary of dictionarys that stores the mode for each pair in each column of X.

                     {{"feature_1:"("bmw","i8"): mode,
                     ('vw', 'up!'): mode},
                     {"feature_2": "("bmw","i8"): mode,
                     ('vw', 'up!'): mode}}
                     
    
    """

    def __init__(self, imput_cols = None , group_cols = ["brand", "model"]):       
        self.imput_cols = imput_cols
        self.group_cols = group_cols

    
    def fit(self , X, y = None):
        X = X.copy()  
        
        if self.imput_cols is None: 
            self.imput_cols = [col for col in X.columns if col != self.group_cols]
        
        self.mode_maps_ = {}

        for col in self.imput_cols:
            mode_map = X.groupby(self.group_cols)[col].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else np.nan) 
            self.mode_maps_[col] = mode_map.to_dict()

        return self 
    
    def transform(self, X):
        X = X.copy()

        keys = list(zip(*[X[g] for g in self.group_cols]))  # [(brand, model), ...]
        key_series = pd.Series(keys, index=X.index)

        for col in self.imput_cols:
            mapped = key_series.map(self.mode_maps_[col])
            X[col] = X[col].fillna(mapped)

        return X

# %%
class Log1pSkewed(BaseEstimator, TransformerMixin):
    """ 
    This transformer computes the natural logarithm of (1 + x) for the columns specified in log_candidates. 
    The goal is to reduce right-skewness and stabilise variance in those features.
     ========================================================================================================

    Parameters: 
        numeric_cols: list of str
                      Names of the numeric columns of X
        log_candidates: list of str
                        Names of the columns of X that are right_skewed
     ========================================================================================================

    Methods:
        .fit: Stores the name of all features the indices of the features that will
        undergo through the log1p transformation (log_candidates).
        .transform: Applies the log1p transformation to the selected columns.
        .get_feature_names_out:        
    ========================================================================================================

    Attributes:

        n_features_in_: number of features before applying the fit
        feature_names_in_: name of the features before applying the fit
        log_idx_: indices of the columns in log_candidates
    """
    
    def __init__(self, numeric_cols, log_candidates):
        self.numeric_cols = numeric_cols
        self.log_candidates = log_candidates

    def fit(self, X, y=None):  
        #X = validate_data(self, X, accept_sparse=False, reset=True) # guarantees a correct format and stores n_features_in_
        #X = self._validate_data(X, accept_sparse=False, reset=True, force_all_finite='allow-nan') # guarantees a correct format and stores n_features_in_
        if hasattr(X, "columns"): # here the intention is to give more flexibility, on the current pipeline, we know that it will receive an array.
            self.feature_names_in_ = np.array(X.columns, dtype=object) 
        else:
            self.feature_names_in_ = np.array(self.numeric_cols, dtype=object)
        self.log_idx_ = [self.numeric_cols.index(c) for c in self.log_candidates]
        return self

    
    def transform(self, X):        
        X = np.asarray(X).copy() # turn X into an array just in case       
        X[:, self.log_idx_] = np.log1p(X[:, self.log_idx_])        
        return X

    
    def get_feature_names_out(self, input_features=None):
        
        if input_features is not None:
            return np.asarray(input_features, dtype=object)
        
        elif hasattr(self, "feature_names_in_"): # just in case this is the 1st transformer, even tough it probably never will
            return self.feature_names_in_

# %%
class ColumnSelector(BaseEstimator, TransformerMixin):
    """
    Selects a single column from the incoming DataFrame X, based on the column name provided at initialization.
    This column is returned as a DataFrame
    """
    
    def __init__(self, column): 
        self.column = column
    
    
    def fit(self, X, y=None): 
        return self
    
    
    def transform(self, X): 
        return pd.DataFrame(X[self.column])


    def get_feature_names_out(self, input_features=None):
        return np.asarray([self.column], dtype=object)
    
class ColumnDropper(BaseEstimator, TransformerMixin):
    """Drop specified columns."""
    def __init__(self, columns):
        self.columns = columns
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        X = X.copy()
        cols_to_drop = [c for c in self.columns if c in X.columns]
        return X.drop(columns=cols_to_drop)

# %%
class PreprocessAndRemoveByName(BaseEstimator, TransformerMixin):

    """
    Wrapper transformer that applies a given preprocessing pipeline and removes a predefined set of output features by name.

    ========================================================================================================

    Parameters: 

        preprocessor: sklearn.pipeline
                    A preprocessing pipeline

        removed_features: list of str
                        list of undesired features

        feature_name_step: str, default="column_transformer"
                         Name of the step within the preprocessing pipeline from which output 
                         feature names are extracted.
                        

     ========================================================================================================

    Methods:

        .fit: Stores the name of all features the indices of the features that will
        undergo through the log1p transformation (log_candidates).

        .transform: Applies the log1p transformation to the selected columns.

        .get_feature_names_out: 
        
    ========================================================================================================

    Attributes:

        self.preprocessor_: sklearn.pipeline
                            Fitted clone of the preprocessing pipeline provided at initialization.
                            This instance is created during `fit` to avoid sharing fitted state
                            across cross-validation folds
                            

        keep_indices_ : list of int
                        Indices of the output features retained after preprocessing.
                        These indices correspond to the features whose names are not included
                        in 'removed_features' and are used to slice the transformed feature
                        matrix during 'transform'.


        removed_found_: list of str
                        Subset of `removed_features` that were found among the output features
                        of the preprocessing pipeline. This attribute is useful for debugging 
                        and verification of the feature-removal process.
    """

    
    def __init__(self, preprocessor, removed_features, feature_name_step="column_transformer"):
        self.preprocessor = preprocessor
        self.removed_features = removed_features
        self.feature_name_step = feature_name_step  # this is the step inside de preprocessor that has the names of the features, which will be "column_transformer" or any other name given to the ColumnTransformer

    def fit(self, X, y=None):
        # this prevents from using the same fitted preprocessor in different folds, in each fold it creates a clone of the "exterior" pipeline which in this case is PreprocessAndRemoveByName so we need to force a new clone of the pipeline inside it  
        self.preprocessor_ = clone(self.preprocessor) 
        self.preprocessor_.fit(X, y)

        # We go to the inside pipeline and to the specific step (Column Transformer name) to get the features names
        feature_names = self.preprocessor_.named_steps[self.feature_name_step].get_feature_names_out()
        feature_names = list(feature_names)

        self.keep_indices_ = [i for i, f in enumerate(feature_names) if f not in self.removed_features]

        self.feature_names_out_ = [feature_names[i] for i in self.keep_indices_] # update the fetures that will be kepted
        return self

    def transform(self, X):
        Xt = self.preprocessor_.transform(X)
        return Xt[:, self.keep_indices_]

    def get_feature_names_out(self, input_features=None):
        return np.array(self.feature_names_out_)

# %%
class KNNMileageImputer(BaseEstimator, TransformerMixin):
    """
    Impute mileage using KNN based on car_age, since it's the only relevant column associated with mileage

    """

    def __init__(self, n_neighbors=5, auxiliary_cols=['car_age'], knn_cols=['car_age', 'mileage']):
        self.n_neighbors = n_neighbors
        self.knn_imputer = None
        self.knn_cols = knn_cols
        self.auxiliary_cols = auxiliary_cols
        self.knn_imputer = KNNImputer(n_neighbors=self.n_neighbors)
        self.simple_imputer = SimpleImputer(strategy='median')
        self.scaler = StandardScaler()

    
    def fit(self, X, y=None):
        X = X.copy()

        # create a temporary dataframe in order to scale and imput auxliary features on just this temporary df and to in the end not return scaled features to the column transformer
        temp_df = X[self.knn_cols].copy()

        # we need to fit transform the scaler and imputation so the knn only applies (fit) to mileage and does it correctly since they are in different scales
        temp_df[self.auxiliary_cols] = self.simple_imputer.fit_transform(temp_df[self.auxiliary_cols])
        temp_df[self.auxiliary_cols] = self.scaler.fit_transform(temp_df[self.auxiliary_cols])

        self.knn_imputer.fit(temp_df)

        return self

   
    def transform(self, X):
        X = X.copy()

        # creating temporary df again    
        temp_df = X[self.knn_cols].copy()

        # applyig the same imputation and scaling on auxiliiary columns as before
        temp_df[self.auxiliary_cols] = self.simple_imputer.transform(temp_df[self.auxiliary_cols])
        temp_df[self.auxiliary_cols] = self.scaler.transform(temp_df[self.auxiliary_cols])

        # store the results of the knn as a dataframe
        imputed = pd.DataFrame(self.knn_imputer.transform(temp_df), columns=self.knn_cols)

        X['mileage'] = imputed["mileage"].values

        return X

# %%
class ModelPredictorImputer(BaseEstimator, TransformerMixin):
    """
    Impute missing 'model' values using a classifier trained within each brand.
    Uses features like engineSize, mpg, transmission, fuelType to predict model.
    """

    def __init__(self, n_estimators=50):
        self.n_estimators = n_estimators
        self.brand_classifiers_ = {}
        self.brand_model_modes_ = {}
        self.brand_encoders_ = {}
        self.cat_cols = ['transmission', 'fuelType']
        self.num_cols = ['tax', 'mpg', 'engineSize', 'car_age']
        self.feature_cols = self.cat_cols + self.num_cols
        

    def fit(self, X, y=None):
        X = X.copy()
        for brand in X['brand'].dropna().unique():
            brand_data = X[X['brand'] == brand].copy()

            # Store mode as fallback
            if not brand_data['model'].mode().empty:
                self.brand_model_modes_[brand] = brand_data['model'].mode().iloc[0]           

            # Only train if we have enough complete cases
            complete_data = brand_data.dropna(subset=['model'] + self.feature_cols)
            if len(complete_data) >= 20 and complete_data['model'].nunique() > 1:                
                X_train = complete_data[self.feature_cols]
                y_train = complete_data['model']
                
                preprocessor_temp = ColumnTransformer([
                    ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), 
                     self.cat_cols)],
                    remainder='passthrough'
                )
                
                pipeline_temp = Pipeline([
                    ('prep', preprocessor_temp),
                    ('clf', RandomForestClassifier(
                        n_estimators=self.n_estimators,
                        random_state=44,
                        n_jobs=-1
                    ))
                ])

                clf = RandomForestClassifier(
                    n_estimators=self.n_estimators,
                    random_state=44,
                    n_jobs=-1,
                    class_weight='balanced'
                )
                
                pipeline_temp.fit(X_train, y_train)
                self.brand_classifiers_[brand] = pipeline_temp
        
        return self
    

    def transform(self, X):
        X = X.copy()
        missing_model_idx = X[X['model'].isnull()].index     

        for idx in missing_model_idx:
            brand = X.loc[idx, 'brand']
    
            
            if pd.notna(brand) and brand in self.brand_classifiers_:
                features = X.loc[[idx], self.feature_cols]
                
                if not features.isnull().any().any():
                    try:
                        predicted_model = self.brand_classifiers_[brand].predict(features)[0]
                        X.loc[idx, 'model'] = predicted_model
                        continue
                    except Exception:
                        pass
                    
            # Fallback to brand mode            
            if pd.notna(brand) and brand in self.brand_model_modes_:
                X.loc[idx, 'model'] = self.brand_model_modes_[brand]
                continue
            
            X.loc[idx, 'model'] = self.global_mode_
        
        return X


class FrequencyEncoder(BaseEstimator, TransformerMixin):
    def __init__(self, col='model'):
        self.col = col
        self.freq_map = {}

    def fit(self, X, y=None):
        self.freq_map = X[self.col].value_counts(normalize=True).to_dict()
        return self

    def transform(self, X):
        X_copy = X.copy()
        X_copy[self.col] = X_copy[self.col].map(self.freq_map).fillna(0)
        return X_copy

# %% [markdown]
# ### Scalling Logic

# %% [markdown]
# - **Reasoning:** Linear/regularized models are scale-sensitive. Numeric features can have very different ranges (ex: mileage vs engine size), which would bias coefficients.
#
# - **Choice:** **StandardScaler** for numeric columns (after imputation and outlier capping).
#
#     - **StandardScaler over MinMaxScaler:** Standardization centers the mean and normalizes the standard deviation of the data distribution. This is required for Ridge and Lasso because these penalize coefficient magnitude, while a feature’s contribution to prediction scales with both its coefficient and its standard deviation. By normalizing the variance of all features equally, the coefficient will be the only factor responsible for contributing to the linear predictor, ensuring the penalization is fair across all features.
#
# All scaling is fit on the training fold only within the pipeline to ensure that there is **no data leakage**.

# %% [markdown]
# #### Mathematical Demonstration of Deature Contribution Scaling

# %% [markdown]
# Since RMS is defined as:
#
# $$
# {MRS(v) = \sqrt{\frac{1}{n}\sum_{i=1}^{n}v_{i}^{2}}}
# $$
#
# It is a measure of the "typical magnitude" of a set of numbers v.
#
# Since the instances of a feature $x_{j}$ are a set of numbers, and its contribution to the prediction will be given by:
#
# $$
# \hat{y}_j = \beta_jx_j
# $$
#
# then follows that the "typical magnitude" of the feature contribution will be given by:
#
# $$
# MRS (\hat{y}_j) = \sqrt{\frac{1}{n}\sum_{i=1}^{n}\hat{y}^{2}_{ji}} = \sqrt{\frac{1}{n}\sum_{i=1}^{n}(\beta_jx_{ji})^2} = |\beta_j|\sqrt{\frac{1}{n}\sum_{i=1}^{n}(x_{ji})^2} = |\beta_j|\sqrt{Var(x_j)} \Leftrightarrow
# $$
#
# $$
# \Leftrightarrow MRS (\hat{y}_j) = |\beta_j|.\sigma(x_j)
# $$
#
# Therefore, the "typical magnitude" of the feature contribution scales with both the coefficient and the standard deviation.

# %% [markdown]
# ### Imputation Logic

# %% [markdown]
# Logically, it appears safe to assume that cars of the same brand and model will, in most cases, present similar mechanical characteristics. This being the case, as stated above, the imputation will be made considering a grouping of the data around these two specific features.
#
# As we made sure all instances of the data set have the column "brand" filled, the only possible problem arising would be missing values in the "brand" column. Due to this, the imputation will be done in two steps:
#
# 1. For each brand, a mode of the model column is calculated. Afterwards, all instances in the data set that don't have information about the model will be imputed with its brand's respective mode.
#
# 2. Once all instances have these two columns filled, for each model of each brand, a mode is calculated for each one of the other features. Afterwards, these values are imputed for missing values.
#
# Many assumptions are made, and possible problems/impressions are overlooked in this type of approach, for example:
#
#     1. Using the mode to input both the numerical and the categorical features might not be the best option.
#     2. Assuming that the mileage feature will be similar between cars of the same brand and model might not hold up as well as assuming the same for features like fuel type or engine size, since the former refers to car usage and the latter to mechanical specifications.
#
# Other imputation strategies are tested in the open-ended section. They serve as a way of measuring the impact of different approaches on the predictive models, but also as a way of trying to mitigate the problems listed above.

# %% [markdown]
# ### Implementation

# %%
numeric_cols = X.select_dtypes(include=[np.number]).columns.tolist()
num_cols_whitout_mileage = numeric_cols.copy()
num_cols_whitout_mileage.remove("mileage")
categorical_cols = [c for c in X.columns if c not in numeric_cols]
without_model = [c for c in X.columns if c not in numeric_cols + ['model']]
without_model_brand = [c for c in X.columns if c not in ["model", "brand"]]
without_model_brand_mileage = [c for c in X.columns if c not in ["model", "brand", "mileage"]]
log_candidates = ['mpg', 'car_age', 'mileage', 'engineSize', 'tax']

# %%
numeric_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("log1p_skewed", Log1pSkewed(numeric_cols, log_candidates)),  
    ("scaler", StandardScaler())
])

# %%
cats = []
cats.append(("cat",
                 Pipeline([("fallback_impute", SimpleImputer(strategy="most_frequent")),
                           ("ohe", OneHotEncoder(handle_unknown="ignore", drop="first", sparse_output=False))]),
                without_model))
cats.append(("model_collap",
                 Pipeline([("fallback_impute", SimpleImputer(strategy="most_frequent")),
                           ("rare", RareLabelGrouper(min_prop=0.005, column="model")),
                           ("ohe", OneHotEncoder(handle_unknown="ignore", drop="first", sparse_output=False))]),
                  ["model"] ))

# %%
preprocessor = ColumnTransformer([("num", numeric_pipeline, numeric_cols), *cats])
pipe_preprocessor = Pipeline([("Imput_model_mode_grouped", Mode_Imput_By_Brand(imput_cols=["model"], group_col="brand")),
                              ("Imput_overal_mode_grouped_by_brand_and_model", Imput_By_Brand_and_Model(imput_cols = without_model_brand)),
                              ("column_transformer",preprocessor)])

# %%
pipe_preprocessor
# Out:
# Pipeline(steps=[('Imput_model_mode_grouped',
#                  Mode_Imput_By_Brand(imput_cols=['model'])),
#                 ('Imput_overal_mode_grouped_by_brand_and_model',
#                  Imput_By_Brand_and_Model(imput_cols=['transmission', 'mileage',
#                                                       'fuelType', 'tax', 'mpg',
#                                                       'engineSize',
#                                                       'car_age'])),
#                 ('column_transformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(st...
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
# ...

# %%
pipe_preprocessor.fit(X)
n_total = pipe_preprocessor.transform(X).shape[1]

# %%
# this indicates us the amount of features obtained to then uset it as max in the rfe
n_total
# Out:
# 65

# %% [markdown]
# ### Feature Selection using KFold Cross-Validation (JUMPED THE TEXT REVIEW!!!!)

# %% [markdown]
# - We will perform feature selection using the CV method, as we believe it´s overal a better way of doing it, since the metrics of each method will not only be based on one segmentation of the data, rather 10 different ones (number of folds), which reduces the risk of selecting features that perform well only on one particular data segmentation.
# - We will implement several methods and in the end chose the features that most of them indicated to keep.
# - Even tought each model implementation had it's own feature selection (to better select the best features specific for each one), the main goal of this feature selection is to select a subset of features and then use them to compare differente models, under the same preprocessing and feature selection.

# %% [markdown]
# #### Recursive Feature Elimination (RFE)

# %% [markdown]
# - We apply an RFE using Linear Regression as an estimator, this is a wrapper method that starts with all available features and eliminates the "least important" wich in our case will be the feature with the smallest absolute regression coefficient until it reaches the number of features that we previously estabilshed.
# - Based on the hold out performed previously, even tought the final decisions will not be made according to those results, we can say that the performance really decreased as the number of features goes down, because of this we will set the minimum number of features to be 45 and the maximium to be all features (65), if the results indicate that we should try a lower number of features (this means the MAE is not decreasing) we will perform it again.

# %%
# %%time

pipeline = Pipeline([
    ('prep', pipe_preprocessor),                    
    ('rfe',  RFE(estimator=LinearRegression())),  
    ('model', LinearRegression())
])


param_grid = {
    'rfe__n_features_to_select': list(range(45,66))
    
}

grid = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    scoring='neg_mean_absolute_error',
    cv=10,
    #n_jobs=-1,
    return_train_score = True,
    verbose=1
)

grid.fit(X, y)

print("Best number of features:", grid.best_params_['rfe__n_features_to_select'])
print("Best MAE:", -grid.best_score_)
# Out:
# Fitting 10 folds for each of 21 candidates, totalling 210 fits
# Best number of features: 64
# Best MAE: 2789.4463534739803
# Wall time: 1h 17min 48s

# %%
results = pd.DataFrame(grid.cv_results_)
results = pd.read_excel("../project_data/final_results/final_rfe_cv_results.xlsx")
results
# Out:
#     Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0            0       2.493101      0.114559         0.049169        0.003260
# 1            1       2.477602      0.084958         0.050546        0.002795
# 2            2       2.362570      0.090899         0.048927        0.003290
# 3            3       2.349087      0.076100         0.051133        0.002224
# 4            4       2.304794      0.075238         0.050375        0.001712
# 5            5       2.180768      0.117553         0.050070        0.003924
# 6            6       2.144723      0.103603         0.052328        0.003137
# 7            7       2.046774      0.110887         0.051440        0.004316
# 8            8       1.893768      0.116550         0.049343        0.001348
# 9            9       1.818914      0.143065         0.049421        0.001644
# 10          10       1.724705      0.115084         0.049914        0.002347
# ...

# %%
#original = pd.DataFrame(grid.cv_results_)
#original.to_excel("rfe_cv_results.xlsx")

# %% [markdown]
# - In contrast to the RFE performed in the hold-out, because of the differences in data partition, the minimum numbers of cars was not met in order to maintain some model_colap_columns, since we put a treshold of X %.
# - Whit this being said, the maximum number of features achieved was 65, since the performance between 63  and 67 is the same in every fold (plus the warning message while performing the RFE).

# %%
# obtaining all results to plot
results = results[results["param_rfe__n_features_to_select"] < 64]

train_score_list = -results['mean_train_score']
val_score_list   = -results['mean_test_score']

# %%
plt.plot(list(range(45,64)), train_score_list, label="MAE on Training Set", color='yellowgreen')
plt.plot(list(range(45,64)), val_score_list, label="MAE on Validation Set", color='dimgray')
plt.xlabel("Number of Features")
plt.ylabel("MAE")
plt.legend()
plt.show()

# %% [markdown]
# - As expected, the ideal number of features is around the maximum number of features.
# - The scores got worst than in the hold out meaning probably it got a partition (the holdout)  that really favored our model.
# - The difference between training and validation keeps being minimal, wich means no overfitting.

# %%
pipe_64 = Pipeline([
    ('prep', pipe_preprocessor),
    ('rfe', RFE(estimator=LinearRegression(), n_features_to_select=64)),
    ('model', LinearRegression())
]).fit(X, y)

feature_names = pipe_64.named_steps["prep"].named_steps["column_transformer"].get_feature_names_out() # array with feauture names
mask = pipe_64.named_steps["rfe"].support_  # bol array saying if each feature was kept [true,true, false, etc]

removed_64 = feature_names[~mask]

# %%
removed_64
# Out:
# array(['model_collap__model_2 series'], dtype=object)

# %% [markdown]
# - In the cross-validation the maximum number of features achivied was 66 and not 67 like in the hold-out split.
# - The discrepancy in the number of features is a consequence from data partitioning effects. An additional dummy variable was created in the hold-out split due to category frequency thresholds being met, but not within the cross-validation folds. The selection of features will be made exclusively based on the methods that are included in the cross-validation, so this dummy variable is disregarded.

# %%
pipe_63 = Pipeline([
    ('prep', pipe_preprocessor),
    ('rfe', RFE(estimator=LinearRegression(), n_features_to_select=63)),
    ('model', LinearRegression())
]).fit(X, y)

feature_names = pipe_63.named_steps["prep"].named_steps["column_transformer"].get_feature_names_out()
mask = pipe_63.named_steps["rfe"].support_

removed_63 = feature_names[~mask]

# %%
removed_63
# Out:
# array(['model_collap__model_2 series', 'model_collap__model_a4'],
#       dtype=object)

# %% [markdown]
# - Based on the cross-validation results we should be using either 65 or 66 features (all).
# - The inclusion of the feature that was removed when selecting 65 features ("model_collap__model_2 series") will be further assess based on the other selection methods.

# %% [markdown]
# #### Decision Tree

# %%
dt_pipe_mse = Pipeline([
    ("prep", pipe_preprocessor),
    ("dt", DecisionTreeRegressor(random_state=42))
])

# this is a dict containing several keys one of which is estimator
cv_out_mse = cross_validate(
    dt_pipe_mse,
    X, y,
    cv=10,
    return_estimator=True,
    n_jobs=2
)

# %%
# doing the same for mae
dt_pipe_mae = Pipeline([
    ("prep", pipe_preprocessor),
    ("dt", DecisionTreeRegressor(criterion='absolute_error', random_state=42))
])

cv_out_mae = cross_validate(
    dt_pipe_mae,
    X, y,
    cv=10,
    return_estimator=True,
    n_jobs=2
)

# %%
series_list_mse = []
# estimator is the pipeline trained in each fold (in total 10 estimators)
for est in cv_out_mse["estimator"]:
    feat_names = est.named_steps["prep"].named_steps["column_transformer"].get_feature_names_out() # from the column transformer get the names for all features
    importance_vector = est.named_steps["dt"].feature_importances_ # from the dt get vector containing each feature importance
    series_list_mse.append(pd.Series(importance_vector, index=feat_names)) # create a series with the names from feat_names and importance from importance vector

series_list_mae = []
for est in cv_out_mae["estimator"]:
    feat_names = est.named_steps["prep"].named_steps["column_transformer"].get_feature_names_out()
    importance_vector = est.named_steps["dt"].feature_importances_
    series_list_mae.append(pd.Series(importance_vector, index=feat_names))

series_list_mae
# Out:
# [num__mileage                  0.162548
#  num__tax                      0.020562
#  num__mpg                      0.085843
#  num__engineSize               0.177039
#  num__car_age                  0.205168
#                                  ...
#  model_collap__model_tucson    0.000223
#  model_collap__model_up!       0.001944
#  model_collap__model_x1        0.000786
#  model_collap__model_yaris     0.004696
#  model_collap__model_zafira    0.000164
#  Length: 65, dtype: float64,
#  num__mileage                  0.155197
#  num__tax                      0.021952
#  num__mpg                      0.085322
#  num__engineSize               0.177295
#  num__car_age                  0.211649
#                                  ...
#  model_collap__model_tucson    0.000391
#  model_collap__model_up!       0.002128
#  model_collap__model_x1        0.000700
#  model_collap__model_yaris     0.005640
#  model_collap__model_zafira    0.000179
#  Length: 65, dtype: float64,
# ...

# %%
# transform to dataframe, each series becomes a column
feature_importance_mse = pd.concat(series_list_mse, axis=1)
feature_importance_mse.columns = [f"fold_{i+1}" for i in range(10)]

feature_importance_mae = pd.concat(series_list_mae, axis=1)
feature_importance_mae.columns = [f"fold_{i+1}" for i in range(10)]

#feature_importance_mse.to_excel("feature_importance_mse.xlsx")
#feature_importance_mae.to_excel("feature_importance_mae.xlsx")
feature_importance_mae
# Out:
#                               fold_1    fold_2    fold_3    fold_4    fold_5  \
# num__mileage                0.162548  0.155197  0.157434  0.155681  0.161354
# num__tax                    0.020562  0.021952  0.021645  0.020671  0.022234
# num__mpg                    0.085843  0.085322  0.083169  0.084735  0.085494
# num__engineSize             0.177039  0.177295  0.176257  0.178558  0.176509
# num__car_age                0.205168  0.211649  0.212275  0.210890  0.204862
# ...                              ...       ...       ...       ...       ...
# model_collap__model_up!     0.001944  0.002128  0.002104  0.001903  0.002230
# model_collap__model_x1      0.000786  0.000700  0.000708  0.000742  0.000655
# model_collap__model_yaris   0.004696  0.005640  0.005724  0.005082  0.005027
# model_collap__model_zafira  0.000164  0.000179  0.000218  0.000151  0.000264
# model_collap__model_i30          NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
# create df with just mean for each feature importance
mse_summary = pd.DataFrame({
    "Feature": feature_importance_mse.index,
    "mean_importance": feature_importance_mse.mean(axis=1, skipna=True)})

mae_summary = pd.DataFrame({
    "Feature": feature_importance_mae.index,
    "mean_importance": feature_importance_mae.mean(axis=1, skipna=True)})

importance_comparison = mse_summary.merge(
    mae_summary,
    on="Feature",
    suffixes=("_MSE", "_MAE")
)

importance_comparison
# Out:
#                        Feature  mean_importance_MSE  mean_importance_MAE
# 0                 num__mileage             0.070042             0.159272
# 1                     num__tax             0.010127             0.021347
# 2                     num__mpg             0.060378             0.084682
# 3              num__engineSize             0.257665             0.176879
# 4                 num__car_age             0.228845             0.208273
# ..                         ...                  ...                  ...
# 61     model_collap__model_up!             0.000548             0.002057
# 62      model_collap__model_x1             0.000203             0.000737
# 63   model_collap__model_yaris             0.002085             0.005088
# 64  model_collap__model_zafira             0.000034             0.000177
# 65     model_collap__model_i30             0.000107             0.000497
#
# [66 rows x 3 columns]

# %%
importance_melted = importance_comparison.melt(
    id_vars='Feature',
    value_vars=['mean_importance_MSE', 'mean_importance_MAE'],
    var_name='Criterion',
    value_name='Importance'
)

avg_order = importance_melted.groupby('Feature')['Importance'].mean().sort_values()

plt.figure(figsize=(12, 8))
sns.barplot(
    data=importance_melted,
    y='Feature',
    x='Importance',
    hue='Criterion',
    order=avg_order.index
)
plt.title('Feature importance comparison (MSE vs MAE)')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.tight_layout()
plt.show()

# %% [markdown]
# - Although the graph is not the most readable (because there is too many features) , we can see that most of the dummy variables representing the car model column, don't contribute much for the performance model's in either MSE or MAE.
# - However we feel like this is a "trap" in the sense that these results will probably hapen everytime we have a lot of dummie variables, in the sense that it's normal that the value of the column model is diluted in several smaller ones and in each one the value is not that big.
# - We will still define a very conservative treshold, every feature wich does not achieve 0.005 in either MSE or MAE will be flagged.
# - The goal is to reduce the dimensionality, but keeping in mind that we are not really sure about the contribution of these columns. Results from other feature selection methods will be crucial in deciding whether to keep the features identified here.

# %%
importance_comparison = pd.read_excel("../project_data/final_results/final_importance_comparision.xlsx")

flagged_features = importance_comparison[
    (importance_comparison["mean_importance_MSE"] < 0.0005) |
    (importance_comparison["mean_importance_MAE"] < 0.0005)
]

# %%
flagged_features
# Out:
#     Unnamed: 0                          Feature  mean_importance_MSE  \
# 15          15           cat__fuelType_electric         4.995152e-07
# 19          19     model_collap__model_3 series         4.053216e-04
# 20          20     model_collap__model_4 series         2.344283e-04
# 26          26           model_collap__model_a4         4.184403e-04
# 27          27           model_collap__model_a5         3.933315e-04
# 28          28           model_collap__model_a6         4.402179e-04
# 29          29        model_collap__model_astra         2.139811e-04
# 30          30        model_collap__model_auris         4.118512e-05
# 31          31         model_collap__model_aygo         3.748703e-04
# 32          32      model_collap__model_b class         4.532105e-04
# 34          34        model_collap__model_c max         8.906352e-05
# 36          36  model_collap__model_crossland x         9.383786e-05
# 38          38     model_collap__model_ecosport         7.491231e-05
# ...

# %% [markdown]
# #### Lasso Regression

# %% [markdown]
# Given our problem of having many dummy variables for the car model, we chose Lasso (L1 regularization) as the last method of feature selection,  because it can set the coefficients of less important features to zero, as a form of penalization, helping to remove redundant features and reduce dimensionality.

# %%
lasso_pipe = Pipeline([
    ("prep", pipe_preprocessor),
    ("lasso", LassoCV())
])

cv_out_lasso = cross_validate(
    lasso_pipe,
    X, y,
    cv=10,
    return_estimator=True,
    n_jobs=-1
)

# %%
series_list_lasso = []
# estimator is the pipeline trained in each fold (in total 10 estimators)
for est in cv_out_lasso["estimator"]:
    feat_names = est.named_steps["prep"].named_steps["column_transformer"].get_feature_names_out() # from the column transformer get the names for all features
    coeff = est.named_steps["lasso"].coef_# from the dt get vector containing each feature coefficient
    series_list_lasso.append(pd.Series(coeff, index=feat_names)) # create a series with the names from feat_names and importance from importance vector

series_list_lasso
# Out:
# [num__mileage                 -1150.530660
#  num__tax                      -552.888322
#  num__mpg                     -1039.149823
#  num__engineSize               4333.188508
#  num__car_age                 -3952.510177
#                                   ...
#  model_collap__model_tucson    2644.756629
#  model_collap__model_up!       -753.817764
#  model_collap__model_x1          -0.000000
#  model_collap__model_yaris     -502.351062
#  model_collap__model_zafira     494.060500
#  Length: 65, dtype: float64,
#  num__mileage                 -1152.359838
#  num__tax                      -534.416674
#  num__mpg                     -1022.819558
#  num__engineSize               4325.129490
#  num__car_age                 -3949.356400
#                                   ...
#  model_collap__model_tucson    2751.219659
#  model_collap__model_up!       -642.660141
#  model_collap__model_x1          -0.000000
#  model_collap__model_yaris     -314.077992
# ...

# %%
lasso = pd.concat(series_list_lasso, axis = 1)
lasso.columns = [f"fold_{i+1}" for i in range(10)]
lasso
# Out:
#                                  fold_1       fold_2       fold_3  \
# num__mileage               -1150.530660 -1152.359838 -1143.921248
# num__tax                    -552.888322  -534.416674  -548.457181
# num__mpg                   -1039.149823 -1022.819558 -1020.033936
# num__engineSize             4333.188508  4325.129490  4374.363925
# num__car_age               -3952.510177 -3949.356400 -3964.169217
# ...                                 ...          ...          ...
# model_collap__model_up!     -753.817764  -642.660141  -587.461016
# model_collap__model_x1        -0.000000    -0.000000    -0.000000
# model_collap__model_yaris   -502.351062  -314.077992  -407.993928
# model_collap__model_zafira   494.060500   485.834725   550.676377
# model_collap__model_i30             NaN          NaN          NaN
#
#                                  fold_4       fold_5       fold_6  \
# num__mileage               -1161.103691 -1147.153294 -1166.503780
# ...

# %%
lasso_summary = pd.DataFrame({
    "mean_coeff": lasso.mean(axis=1, skipna=True)
})
lasso_summary
# Out:
#                              mean_coeff
# num__mileage               -1154.592585
# num__tax                    -539.936589
# num__mpg                   -1013.035626
# num__engineSize             4357.645596
# num__car_age               -3948.379582
# ...                                 ...
# model_collap__model_up!     -673.917419
# model_collap__model_x1         0.000000
# model_collap__model_yaris   -396.210255
# model_collap__model_zafira   507.095461
# model_collap__model_i30      270.794199
#
# [66 rows x 1 columns]

# %%
# checking which features lasso punished coeff to be 0 
lasso_removed = lasso_summary[lasso_summary["mean_coeff"] == 0]
lasso_removed
# Out:
#                                  mean_coeff
# cat__fuelType_electric                  0.0
# model_collap__model_5 series            0.0
# model_collap__model_a6                  0.0
# model_collap__model_auris               0.0
# model_collap__model_crossland x         0.0
# model_collap__model_mokka x             0.0
# model_collap__model_octavia             0.0
# model_collap__model_passat              0.0
# model_collap__model_q2                  0.0
# model_collap__model_x1                  0.0

# %% [markdown]
# #### Final Decision

# %% [markdown]
# Several features were identified as irrelevant or redundant by the three feature selection methods. We focus on these features, and the final exclusion criterion is that a feature is removed by at least two out of the three methods.

# %%
# features removed on each method
dt_removed= set(flagged_features["Feature"])
rfe_removed = set(removed_64)
lasso_removed_set = set(lasso_removed.index)
# checking if some feature is at least in two
features_in_at_least_two = ((dt_removed & rfe_removed) |(dt_removed & lasso_removed_set) |(rfe_removed & lasso_removed_set))
features_in_at_least_two
# Out:
# {'cat__fuelType_electric',
#  'model_collap__model_a6',
#  'model_collap__model_auris',
#  'model_collap__model_crossland x',
#  'model_collap__model_mokka x',
#  'model_collap__model_passat',
#  'model_collap__model_x1'}

# %%
features_to_remove = list(features_in_at_least_two)

# %%
remove = {'cat__fuelType_electric',
 'model_collap__model_a6',
 'model_collap__model_auris',
 'model_collap__model_crossland x',
 'model_collap__model_mokka x',
 'model_collap__model_passat',
 'model_collap__model_x1'}

features_to_remove = list(remove)

# %% [markdown]
# - For the final set of excluded features, we observe that most of them are dummy variables derived from the model column. These dummies likely have limited predictive value due to their very low representation in the dataset.
#
# - Additionally, the feature fueltype_electric was also excluded. This result was expected based on the univariate analysis, as only 4 cars out of approximately 75,000 in the dataset have this specification.

# %% [markdown]
# # 3. Modeling and evaluation

# %% [markdown]
# This section focuses on the implementation of various predictive models in order to predict the used car prices. The following machine learning algorithms were selected for performance evaluation:
#
# - **Linear Regression**
# - **Ridge Regression**
# - **Decision Tree Regressor**
# - **RandomForestRegressor**
# - **Neural Network**
#
# **Assessment Strategy:**
#
# A consistent evaluation framework is implemented using:
#
# - **5-Fold Cross-Validation** was used for a robust performance estimation.
#
# - **Different metrics** were used:
#
#     - **Primary Metric**: Mean Absolute Error (MAE): Interpretable, since it is in price units, and less sensitive to outliers compared to other metrics.
#
#     - **Secondary Metrics**: Root Mean Squared Error (RMSE): Penalizes large errors; R²: Indicates the proportion of variance in the dependent variable explained by the independent variables. Most meaningful for linear models, as its calculation assumes a linear relationship between predictors and outcome.
#
#  - **Validation and training scores** were recorded and studied for overfitting detection.

# %% [markdown]
# ## Model Benchmarking

# %% [markdown]
# As a first step in model implementation, the chosen models are run with the default parameters. The results output will allow for a basic notion of the efficacy of each model.

# %%
models = {
    'Linear Regression': LinearRegression(),
    'Ridge': Ridge(alpha=1.0),
    'Decision Tree': DecisionTreeRegressor(random_state=42),
    'Random Forest': RandomForestRegressor(random_state=42, n_jobs=-1),
    'Neural Network': MLPRegressor(max_iter=500, random_state=42, early_stopping=True) #The defalt parameter max_iter is 200, yet it converges too fast
}

scoring = {
    'MAE': 'neg_mean_absolute_error',
    'RMSE': 'neg_root_mean_squared_error',
    'R2': 'r2'
}

# %%
kfold = KFold(n_splits=2, shuffle=True, random_state=44)
results = []

for name, model in models.items():
    start_time = time.time()
    
    full_pipeline = Pipeline([
        ('prep', clone(pipe_preprocessor)),
        ('model', model)
    ])
    
    cv_results = cross_validate(
        full_pipeline, X, y,
        cv=kfold,
        scoring=scoring,
        return_train_score=True,
        n_jobs=-1
    )
    
    results.append({
        'Model': name,
        'Train_MAE': -cv_results['train_MAE'].mean(),
        'Val_MAE': -cv_results['test_MAE'].mean(),
        'Val_MAE_std': cv_results['test_MAE'].std(),
        'Train_R2': cv_results['train_R2'].mean(),
        'Val_R2': cv_results['test_R2'].mean(),
        'Time (s)': round(time.time() - start_time, 2)
    })
    
    print(f"{Model}:")
    print(f"MAE:{-cv_results['test_MAE'].mean():.2f} (+/-{cv_results['test_MAE'].std():.2f})")

baseline_results = pd.DataFrame(results).set_index('Model').sort_values('Val_MAE')

print('\n')
print("Benchmarks:")
baseline_results.round(2)
# Out:
# MAE:2789.64 (+/-7.83)
# MAE:2791.38 (+/-8.17)
# MAE:1833.48 (+/-1.29)
# MAE:1463.34 (+/-0.82)
# MAE:2037.81 (+/-18.47)
# Benchmarks
# ...
#                    Train_MAE  Val_MAE  Val_MAE_std  Train_R2  Val_R2  Time (s)
# Model
# Random Forest         555.03  1463.34         0.82      0.99    0.93     39.29
# Decision Tree          19.42  1833.48         1.29      1.00    0.88     12.26
# Neural Network       2022.97  2037.81        18.47      0.87    0.86    114.68
# Linear Regression    2785.32  2789.64         7.83      0.79    0.79     16.44
# Ridge                2787.38  2791.38         8.17      0.79    0.79     11.74

# %% [markdown]
# ### Baseline Observations
#
# From the baseline comparison:
#
# 1. **Random Forest** shows the best validation performance with the lowest MAE, even tho it shows signs of overfitting.
#
# 2. **Decision Tree** shows clear signs of overfitting due to the large gap between train/val and the $R^2 = 1.0$. This was certain to happen since there is no pruning was applied.
#
# 3. **Neural Network** shows competitive performance but requires more tuning.
#
# 4. **Linear models** (LR, Ridge) serve as interpretable baselines. The problem appears not to be linear, and so deeper research should focus on the models that can capture this apparent non-linear behavior.

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ### Hyperparameter Tuning

# %% [markdown]
# The following tuning approach was followed:
#
# - RandomizedSearchCV is called to try to cover the most parameter space possible, given the limited computing resources and time available;
#
# - Interpret and choose a specific area of the parameter space, based on a selection that performed quite well. It's also important to consider the overfitting when choosing this area, as DTs are very prone to doing so;
#
# - GridSearchCV is called and used around that chosen area;
#
# - Choose and deploy the model.

# %%
dt_pipe = Pipeline([
    ("prep", pipe_preprocessor),
    ("dt", DecisionTreeRegressor(random_state=42))
])

# %%
param_dist = {
    "dt__criterion": ["squared_error", "absolute_error"],
    "dt__max_depth": [5, 8, 15, 30, None],
    "dt__min_samples_split": [5, 10, 20, 30, 40],
    "dt__min_samples_leaf": [5, 10, 20, 30],
    "dt__max_features": [None, "sqrt", "log2"],
    "dt__ccp_alpha": [0.0001, 0.001, 0.01]
    }

# %%
# %%time

search_dt = RandomizedSearchCV(
    estimator=dt_pipe,
    param_distributions=param_dist,
    n_iter=40,                         
    scoring="neg_mean_absolute_error",
    cv=5,
    random_state=42,
    n_jobs=-1,
    verbose=1,
    return_train_score=True
)

search_dt.fit(X, y)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# CPU times: total: 12.6 s
# Wall time: 30min 23s
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('prep',
#                                               Pipeline(steps=[('Imput_model_mode_grouped',
#                                                                Mode_Imput_By_Brand(imput_cols=['model'])),
#                                                               ('Imput_overal_mode_grouped_by_brand_and_model',
#                                                                Imput_By_Brand_and_Model(imput_cols=['transmission',
#                                                                                                     'mileage',
#                                                                                                     'fuelType',
#                                                                                                     'tax',
# ...

# %%
#cv_results = pd.read_excel("../project_data/model_results/DT_RandomSearch_top_20_results_1.xlsx")
cv_results = pd.DataFrame(search_dt.cv_results_)
cv_results = cv_results.sort_values("mean_test_score", ascending = False)
#cv_results.head(20).to_excel("DT_RandomSearch_top_20_results_1.xlsx", index = False)
cv_results.head(20)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        2.414979      0.525363         0.168950        0.042106
# 1        1.782053      0.498370         0.140303        0.047915
# 2      736.172451     82.577760         0.125870        0.015737
# 3      710.404581     55.074566         0.102155        0.015944
# 4      562.133224     23.973827         0.113188        0.019525
# 5      167.878376     39.152509         0.159397        0.052821
# 6        1.304289      0.069507         0.175073        0.055018
# 7      147.423120     29.474118         0.149808        0.055523
# 8      617.526843     18.466473         0.102566        0.021145
# 9      674.773715     25.487763         0.110371        0.015873
# 10       2.066109      0.582481         0.216795        0.070006
# 11       1.478509      0.206618         0.134285        0.020805
# 12       2.248241      0.479674         0.198567        0.047546
# ...

# %%
cv_results["overfit"] = (cv_results["mean_test_score"] - cv_results["mean_train_score"]) *-1
cv_results["overfit%"] =  cv_results["overfit"] / cv_results["mean_test_score"] * -100
# Out:
# 0     312.949889
# 1     309.763147
# 2     217.996652
# 3     155.916760
# 4     178.078730
# 5     311.441668
# 6     128.994363
# 7     200.342007
# 8      60.748090
# 9      52.874676
# 10     63.757579
# 11     56.074010
# 12     56.074010
# 13     56.074010
# 14    122.421251
# 15    116.612907
# 16    121.351026
# 17     80.731004
# 18    103.095377
# 19     91.065988
# Name: overfit, dtype: float64
# 0     18.575373
# 1     17.960131
# 2     12.293163
# 3      8.473457
# 4      9.657455
# 5     15.379525
# 6      5.694245
# 7      8.553091
# 8      2.537821
# 9      2.198695
# 10     2.620144
# 11     2.290813
# 12     2.290813
# 13     2.290813
# 14     4.977948
# 15     4.727393
# 16     4.779167
# 17     3.147398
# 18     3.987615
# 19     3.510027
# Name: overfit%, dtype: float64

# %% [markdown]
# By looking at the results, even though the best performance tree in validation has a mean MAE of ~ 1690, it also has the largest amount of overfitting, with 312 on the difference between validation score and training score.
#
# Another possibility is the 3rd set of parameters. It has in the rank has 90 more units in the validation MAE than the best model, yet minus 90 on "overfit".
#
# Considering the discussion above, the hyperparameter tuning considers an extensive search of combinations around the parameter space of these 2 models, looking for the best model under a 400 difference between the validation score and train score.

# %%
param_gridcv = {
    "dt__max_depth": [30, 33, None],
    "dt__min_samples_leaf": [2, 5, 10, 20],
    "dt__min_samples_split": [5, 10, 20, 40],
    "dt__ccp_alpha": [0.0, 0.0001, 0.0002],
    "dt__criterion": ["absolute_error", "squared_error"],
    "dt__max_features": [None]
}

# %%
# %%time

grid_search_dt = GridSearchCV(
    estimator=dt_pipe,
    param_grid =param_gridcv,                         
    scoring="neg_mean_absolute_error",
    cv=5,
    n_jobs=-1,
    verbose=1,
    return_train_score=True
)

grid_search_dt.fit(X, y)

grid_results_dt = pd.DataFrame(grid_search_dt.cv_results_)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# CPU times: total: 9min 26s
# Wall time: 7h 24min

# %%
grid_results_dt = grid_results_dt.sort_values("mean_test_score", ascending = False)
grid_results_dt["overfit"] = (grid_results_dt["mean_test_score"] - grid_results_dt["mean_train_score"]) *-1
#grid_results_dt.to_excel("GridSearchCV_DT_3_Results.xlsx", index=False)

# %% [markdown]
# ### Chosing Final DT Model

# %%
#grid_results_dt = pd.read_excel("../project_data/model_results/GridSearchCV_DT_3_Results.xlsx")

# %%
train_scores = -grid_results_dt["mean_train_score"]  
test_scores = -grid_results_dt["mean_test_score"]    
overfit = grid_results_dt["overfit"] 


fig, ax = plt.subplots(figsize=(10, 10))

ax.set_xlabel("Overfit", fontsize=15)
ax.set_ylabel("Validation MAE", fontsize=15)
ax.set_title("Validation MAE vs Overfit")


ax.axvline(
    x=400,
    linestyle="--",
    linewidth=2,
    color="green",
    label="Overfit threshold (400)"
)

ax.plot(
    overfit,
    test_scores,
    marker="o",
    label="Validation MAE",
    drawstyle="steps-post"
)

ax.invert_yaxis()
ax.legend()
plt.show()

# %% [markdown]
# Based on the results of the extensive parameter search, there is a range of viable candidates, with validation MAE between 1625 and 1660, and under the 400 "overfit" threshold.
#
# This indicates a region of acceptable trade-off between predictive performance and model generalization, although we can't be sure if there is a better tree outside of this range.

# %%
cols_for_chosing = ['params', 'mean_test_score', 'overfit', 'std_test_score']
filtered_grid = grid_results_dt[(grid_results_dt['overfit'] < 400) & (grid_results_dt['mean_test_score'] > -1660)]
filtered_grid = filtered_grid[cols_for_chosing]

# %%
filtered_grid
# Out:
#                                                 params  mean_test_score  \
# 45   {'dt__ccp_alpha': 0.0002, 'dt__criterion': 'sq...     -1625.545617
# 46   {'dt__ccp_alpha': 0.0001, 'dt__criterion': 'sq...     -1625.545617
# 47   {'dt__ccp_alpha': 0.0, 'dt__criterion': 'squar...     -1625.545617
# 48   {'dt__ccp_alpha': 0.0, 'dt__criterion': 'squar...     -1625.890942
# 49   {'dt__ccp_alpha': 0.0002, 'dt__criterion': 'sq...     -1625.890942
# 50   {'dt__ccp_alpha': 0.0001, 'dt__criterion': 'sq...     -1625.890942
# 51   {'dt__ccp_alpha': 0.0001, 'dt__criterion': 'sq...     -1626.011788
# 52   {'dt__ccp_alpha': 0.0002, 'dt__criterion': 'sq...     -1626.011788
# 53   {'dt__ccp_alpha': 0.0, 'dt__criterion': 'squar...     -1626.011788
# 54   {'dt__ccp_alpha': 0.0002, 'dt__criterion': 'ab...     -1627.232610
# 55   {'dt__ccp_alpha': 0.0001, 'dt__criterion': 'ab...     -1627.238843
# 56   {'dt__ccp_alpha': 0.0, 'dt__criterion': 'absol...     -1627.241100
# ...

# %% [markdown]
# Two final decision tree models were selected: one prioritizing minimal validation MAE under the overfitting threshold (tree 60), and a second model with slightly higher MAE but reduced overfitting, potentially offering better generalization (tree 126).

# %%
params_60 = ast.literal_eval(grid_results_dt["params"].iloc[60])
params_60 = {k.replace("dt__", ""): v for k, v in params_60.items()}
params_60
# Out:
# {'ccp_alpha': 0.0002,
#  'criterion': 'absolute_error',
#  'max_depth': 30,
#  'max_features': None,
#  'min_samples_leaf': 2,
#  'min_samples_split': 40}

# %%
params_126 = ast.literal_eval(grid_results_dt["params"].iloc[126])
params_126
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 params_126 = ast.literal_eval(grid_results_dt["params"].iloc[126])
#       2 params_126
#
# NameError: name 'ast' is not defined

# %%
params_60 = {'ccp_alpha': 0.0002,
 'criterion': 'absolute_error',
 'max_depth': 30,
 'max_features': None,
 'min_samples_leaf': 2,
 'min_samples_split': 40}

# %% [markdown]
# The DT 60 was considered the best model, yet the parameters for the DT 126 will be kept for testing in the final test data provided by th professor.

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Hyperparameter Tuning

# %% [markdown]
# The following tuning approach was followed:
#
# - RandomizedSearchCV is called to try to cover the most parameter space possible, given the limited computing resources and time available;
#
# - Interpret and choose a specific model, considering the possible overfitting.

# %%
dt_pipe = Pipeline([
    ("prep", pipe_preprocessor),
    ("rf", RandomForestRegressor(bootstrap = True, random_state=42))
])

# %%
param_dist = {
    "dt__criterion": ["squared_error", "absolute_error"],
    "rf__n_estimators": n_esti,
    "rf__max_samples": [0.2, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9],
    "rf__max_depth": [5, 10, 20, 30],
    "rf__max_features": [None, "sqrt", "log2"],
    "rf__oob_score": [True, False]
    }

# %%
# %%time

search_rf = RandomizedSearchCV(
    estimator=dt_pipe,
    param_distributions=param_dist,
    n_iter=100,                         
    scoring="neg_mean_absolute_error",
    cv=5,
    random_state=42,
    n_jobs=-1,
    verbose=1,
    return_train_score=True
)

search_dt.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:1
#
# NameError: name 'RandomizedSearchCV' is not defined

# %% [markdown]
# ### Chosing Final RF Model

# %%
grid_results_rf = pd.read_excel("../project_data/model_results/Random_Search_Results_RandomForest.xlsx")
train_scores = -grid_results_rf["mean_train_score"]  
test_scores = -grid_results_rf["mean_test_score"]    
overfit = grid_results_rf["overfit"]

# %% [markdown]
# To study the best model output by the RandomSearchCV, and similarly to what was done in the decision tree section, a visual approach and discussion were chosen for that task.

# %% [markdown]
# #### Val MAE VS Overfit

# %%
fig, ax = plt.subplots(figsize=(10, 10))

ax.set_xlabel("Training MAE", fontsize=15)
ax.set_xlim(0, max(train_scores)+100)
ax.invert_xaxis()
ax.set_ylabel("Validation MAE", fontsize=15)
ax.set_ylim(0, max(test_scores)+100)
ax.set_title("Validation MAE vs Training MAE")

ax.axvline(
    x=620,
    linestyle="--",
    linewidth=2,
    color="green",
    label="Overfit threshold (620)"
)

ax.plot(
    train_scores,
    test_scores,
    marker="o",
    linestyle="None",
    label="Validation MAE",
    drawstyle="steps-post"
)

ax.legend()
plt.show()

# %% [markdown]
# Considering the graph shown above, the relation between the MAE of both the training and the validation data appears to change depending on two different intervals of the training MAE axis:
#
# 1. For the approximate range [620, 3707], it is clear that, while the training MAE decreases, so does the validation MAE. As the graph reaches the lower limit of this interval, the decrease in MAE for the validation data starts to slow down compared to the one referring to the training data, turning an approximate linear relation between the two axes into a concave up curve.
#
# 2. For the small quantity of records that exist before the interval mentioned above, the validation MAE increases. Due to the prior reduction behavior seen in the curve's steepness, and inducing it further, we could assume the increase to be due to the behavior of the curve itself, not fluctuation errors. Because of that, the threshold chosen is a good candidate to represent where the model starts to overfit.
#
# Since there are a small number of data points in this second regime, and it is hard to visualize if this increase is relevant or only due to small fluctuations, a deeper research is required.

# %% [markdown]
# #### Val MAE VS Train MAE

# %%
fig, ax = plt.subplots(figsize=(10, 10))

ax.set_xlabel("Validation MAE", fontsize=15)
ax.set_xlim(0, max(test_scores)+100)
ax.invert_xaxis()
ax.set_ylabel("Validation MAE - Traning MAE", fontsize=15)
ax.set_ylim(0, max(overfit)+100)
ax.set_title("Overfit Treshold")


ax.axvline(
    x=1396,
    linestyle="--",
    linewidth=2,
    color="green",
    label="Approximate Validation MAE (1396)"
)

ax.axhline(
    y=1396-620,
    linestyle="--",
    linewidth=2,
    color="red",
    label="Difference at overfit threshold (776)"
)

ax.plot(
    test_scores,
    overfit,
    marker="o",
    linestyle="None",
    label="Validation MAE - Training MAE",
    drawstyle="steps-post"
)

ax.legend()
plt.show()

# %% [markdown]
# Represented in this graph is the relation between the validation MAE and the difference between the MAEs.
#
# It shows that, as the validation MAE decreases, the difference between the errors increases since the validation MAE starts decreasing at a lower rate compared to the training MAE. This was expected when considering the discussion after the last graph.
#
# Furthermore, the difference between MAEs increases faster when the validation MAE is smaller, which was also expected. Due to this same logic, as the validation MAE starts to increase again, the difference between MAEs should also present a noticeable growth, since not only will the training MAE be decreasing, but also the validation MAE will be increasing, creating a faster increase in their difference around this specific area.
#
# As can be seen in the graph, at validation MAE = 1396, which is approximately the value for the threshold defined earlier, the difference increases substantially, jumping to a near difference between MAEs = 776.
#
# Since:
#
# $$
# \text{Train MAE} = \text{Val MAE} - \text{Diff MAEs}
# \iff \text{Train MAE} = 1396 - 776 = 620
# $$
#
# Then we know this jump happens when the training MAE is near 620, which is the threshold chosen in the prior graph.
#
# Although this graph does not introduce new information, as it is derived from the same data, it provides a clearer visualization of the divergence between training and validation errors around the previously identified threshold, offering a complementary perspective on the onset of overfitting. As such, this visualization should be interpreted as supportive rather than confirmatory.

# %% [markdown]
# Due to the discussion above, after considering the presented threshold, the best parameters found are the following:

# %%
best_param_rf = {'n_estimators': 250, 'max_samples': 0.8, 'max_features': None, 'max_depth': 30, 'criterion': 'squared_error'}

# %%
best_rf = Pipeline([
    ("prep", pipe_preprocessor),
    ("rf", RandomForestRegressor(**best_param_rf))
])

# %%
best_rf.fit(X, y)
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Pipeline(steps=[('prep',
#                  Pipeline(steps=[('Imput_model_mode_grouped',
#                                   Mode_Imput_By_Brand(imput_cols=['model'])),
#                                  ('Imput_overal_mode_grouped_by_brand_and_model',
#                                   Imput_By_Brand_and_Model(imput_cols=['tax',
#                                                                        'mpg',
#                                                                        'engineSize',
#                                                                        'car_age'])),
#                                  ('Imput_overal_mode_grouped_by_brand',
# ...

# %% [markdown]
# ## Neural Network

# %% [markdown]
# For Neural Networks, we follow the same two-stage approach:
#
# 1. RandomizedSearchCV for broad exploration
#
# 2. GridSearchCV for fine-tuning

# %%
nn_pipe = Pipeline([
    ("prep", PreprocessAndRemoveByName(pipe_preprocessor, features_to_remove)),
    ("nn", MLPRegressor(max_iter=1000, early_stopping=True, random_state=44))
])

# %%
nn_params = {
    'nn__hidden_layer_sizes': [
        (50,), (100,), (150,),
        (50, 25), (100, 50), (100, 100),
        (100, 50, 25), (150, 100, 50)
    ],
    'nn__activation': ['relu', 'tanh'],
    'nn__solver': ['adam', 'sgd'],
    'nn__alpha': [0.0001, 0.001, 0.01, 0.1],
    'nn__learning_rate_init': [0.001, 0.01, 0.1],
    'nn__batch_size': [32, 64, 128, 256],
    'nn__max_iter': [500, 1000]
}


random_nn_search = RandomizedSearchCV(
    estimator= nn_pipe,
    param_distributions= nn_params,
    n_iter=30,
    cv=5,
    scoring="neg_mean_absolute_error",
    n_jobs=-1,
    verbose=1,
    random_state=44
)
random_nn_search.fit(X, y)

print(f'Best params: {random_nn_search.best_params_}')
print(f'Best MAE: {-random_nn_search.best_score_:,.2f}')
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# C:\Users\MasterG\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 32 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\MasterG\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\MasterG\anaconda3\lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
# ...

# %%
# Save NN RandomizedSearch results
nn_random_results = pd.DataFrame(random_nn_search.cv_results_)
nn_random_results = nn_random_results.sort_values('rank_test_score')
nn_random_results.to_csv('nn_randomized_search_results.csv', index=False)

# %%
#random_results_nn = pd.read_excel("../project_data/model_results/nn_randomized_search_results.csv")

# %%
# Neural Network - GridSearchCV (fine-tuning)

best_nn_params = random_nn_search.best_params_

# %%
best_nn_params
# Out:
# {'nn__solver': 'adam',
#  'nn__max_iter': 500,
#  'nn__learning_rate_init': 0.001,
#  'nn__hidden_layer_sizes': (150, 100, 50),
#  'nn__batch_size': 32,
#  'nn__alpha': 0.0001,
#  'nn__activation': 'relu'}

# %%
best_hidden = best_nn_params.get('nn__hidden_layer_sizes', (100,))
best_alpha = best_nn_params.get('nn__alpha', 0.001)
best_lr = best_nn_params.get('nn__learning_rate_init', 0.001)

nn_param_grid = {
    'nn__hidden_layer_sizes': [(150, 100, 50), (160, 120, 60)],
    'nn__activation': ['relu'],
    'nn__solver': ['adam'],
    'nn__alpha': [0.00005, 0.0001, 0.0002],
    'nn__learning_rate_init': [0.0005, 0.001, 0.002],
    'nn__batch_size': [32, 35],
    'nn__max_iter': [500, 650]
}

# %%
nn_param_grid
# Out:
# {'nn__hidden_layer_sizes': [(150, 100, 50)],
#  'nn__activation': ['relu'],
#  'nn__solver': ['adam'],
#  'nn__alpha': [5e-05, 0.0001, 0.0002],
#  'nn__learning_rate_init': [0.0005, 0.001, 0.002],
#  'nn__batch_size': [32],
#  'nn__max_iter': [500]}

# %%
nn_grid_search = GridSearchCV(
    nn_pipe,
    param_grid=nn_param_grid,
    cv=5,
    scoring='neg_mean_absolute_error',
    n_jobs=-1,
    verbose=1
)

nn_grid_search.fit(X_train, y_train)

print(f"\nBest MAE (GridSearch): {-nn_grid_search.best_score_:.2f}")
print(f"Best parameters: {nn_grid_search.best_params_}")

# %%
# Save NN GridSearch results
nn_grid_results = pd.DataFrame(nn_grid_search.cv_results_)
nn_grid_results = nn_grid_results.sort_values('rank_test_score')
nn_grid_results.to_csv('nn_grid_search_results.csv', index=False)

# %%
# nn_grid_results = pd.read_csv("../project_data/model_results/nn_grid_search_results.csv")
nn_grid_results.head(15)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0     1720.860431    162.181801         0.969498        0.310449
# 1     1710.643326    158.292944         1.191313        0.508937
# 2      983.007745    241.346738         0.782048        0.040776
# 3     1025.740902    273.930668         0.798623        0.052513
# 4     1192.042315    147.671262         1.083340        0.295732
# 5     1193.503416    156.798275         0.857853        0.095091
# 6     1236.108360    132.886410         1.007598        0.119454
# 7     1216.192720    142.443183         0.789961        0.103774
# 8     1512.267648    227.138185         1.001150        0.086849
# 9     1521.111842    228.643110         0.983222        0.064195
# 10    1816.902097    236.822898         1.140663        0.146346
# 11    1805.384237    262.814566         1.043040        0.237089
# 12     946.985313    163.585393         0.878392        0.120987
# ...

# %%
# Store best NN model
best_nn_params = ast.literal_eval(nn_grid_results["params"].iloc[0])
#best_nn = nn_grid_search.best_estimator_
best_nn_params = {k.replace("nn__", ""): v for k, v in best_nn_params.items()}
best_nn_params
# Out:
# {'activation': 'relu',
#  'alpha': 0.0002,
#  'batch_size': 35,
#  'hidden_layer_sizes': (160, 120, 60),
#  'learning_rate_init': 0.0005,
#  'max_iter': 650,
#  'solver': 'adam'}

# %% [markdown]
# ## Final Model Comparison

# %%
final_models = {
    'Linear Regression': Pipeline([
        ('prep', clone(PreprocessAndRemoveByName(pipe_preprocessor, features_to_remove))),
        ('model', LinearRegression())
    ]),

    'Ridge Regression': Pipeline([
        ('prep', clone(PreprocessAndRemoveByName(pipe_preprocessor, features_to_remove))),
        ('model', Ridge())
    ]),

    'Decision Tree (tuned)': Pipeline([
        ('prep', clone(PreprocessAndRemoveByName(pipe_preprocessor, features_to_remove))),
        ('model', DecisionTreeRegressor(**params_60))
    ]),

    'Random Forest (tuned)': Pipeline([
        ('prep', clone(PreprocessAndRemoveByName(pipe_preprocessor, features_to_remove))),
        ('model', RandomForestRegressor(**best_param_rf))
    ]),

    'Neural Network (tuned)': Pipeline([
        ('prep', clone(PreprocessAndRemoveByName(pipe_preprocessor, features_to_remove))),
        ('model', MLPRegressor(**best_nn_params))
    ])
}

scoring = {'MAE': 'neg_mean_absolute_error','RMSE': 'neg_root_mean_squared_error','R2': 'r2'}

final_results = []
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

for name, model in final_models.items():
    cv_results = cross_validate(
        model,
        X, y,
        cv=kfold,
        scoring=scoring,
        return_train_score=True,
        n_jobs=-1,
        error_score='raise'
    )

    results = {
        'Model': name,
        'Train_MAE': -cv_results['train_MAE'].mean(),
        'Val_MAE': -cv_results['test_MAE'].mean(),
        'Val_MAE_std': cv_results['test_MAE'].std(),

        'Train_RMSE': -cv_results['train_RMSE'].mean(),
        'Val_RMSE': -cv_results['test_RMSE'].mean(),

        'Train_R2': cv_results['train_R2'].mean(),
        'Val_R2': cv_results['test_R2'].mean()
    }

    final_results.append(results)

    print(f"{name}:")
    print(f"  Val MAE: {results['Val_MAE']:.2f} (+/- {results['Val_MAE_std']:.2f})")
# Out:
# Linear Regression:
#   Val MAE: 2857.19 (+/- 22.22)
# Ridge Regression:
#   Val MAE: 2856.99 (+/- 22.17)
# Decision Tree (tuned):
#   Val MAE: 1645.22 (+/- 22.28)
# Random Forest (tuned):
#   Val MAE: 1383.08 (+/- 12.51)
# Neural Network (tuned):
#   Val MAE: 1527.67 (+/- 39.91)

# %%
final_results_df = pd.DataFrame(final_results)

# %%
final_results_df.to_csv("final_model_comparison.csv")

# %% [markdown]
# ### Model Selection Rationale
#
# Based on the final comparison:
#
# 1. **Random Forest (Tuned)** typically achieves the best validation MAE
# 2. The gap between train and validation scores indicates good generalization
# 3. Tree-based models (DT, RF) outperform linear models due to non-linear relationships
# 4. Neural Network performance is  ESCREVER AQUII
#
# We proceed with the best-performing model for deployment.

# %% [markdown]
# # 4. Open-Ended Section
#
# ## Objectives
#
# 1. **Comparison of Pre-Processing Strategies:** Analyze how different pre-processing strategies impacts model performance.
# 2. **Brand-Specific Models:** Compare general model vs brand-specific models

# %% [markdown]
# ##  Comparison of Pre-processing Strategies
#
# ### Objectives
#
# The objective of this section is to compare different end-to-end pre-processing strategies and evaluate how alternative combinations of data cleaning, transformation, encoding and imputation impact model performance and stability.
#
# Rather than assessing individual preprocessing components in isolation, this analysis adopts a holistic perspective, acknowledging that preprocessing decisions interact and shape the learning problem.
#
# From pipeline to pipeline the goal was to increment the complexity of the pre-processing techinques used.
#
# ---
#
# ### Comparison of Different Pre-processing Pipelines
#
# To ensure a fair comparison, the modeling stage is kept fixed across all experiments.
# Differences in performance can therefore be attributed to the combined effect of preprocessing choices, rather than changes in the predictive model itself.
#
# The following preprocessing pipelines are compared:
#
# - **Pipeline A — Naive Global Pre-processing**
#
#   This pipeline serves as a simple baseline, which aims to answer the question "How would the models perform with the simpleast way of preprocessing?"
#
#   No grouping or domain-specific information is used, no handling of outliers was done, altough we scaled the data.
#
#   The preprocessing steps are as follows:
#
#
#     - Numerical variables are imputed using global median.
#     - Categorical variables are imputed using the global mode.
#     - Categorical variables are encoded using one-hot encoding.
#     - Numerical variables are scaled using a robust scaling approach.
#
#
# - **Pipeline B — Outlier and variable 'model' treatment**
#
#     Outlier treatment: log transformation was performed on high-skewness data, while the rest were handled using winsorization (capping and flooring).
#   Missing Values are imputed using global statistics:
#   - Numerical features are filled with the global median
#   - Categorical features are filled with the global mode , 'model' column rare observations are grouped as "other" before aplying one hot encoding to avoid high cardinality.
#   - Highly skewed numerical variables are log-transformed.
#   - Categorical variables are encoded using one-hot encoding.
#   - Numerical variables are scaled using standardization (standard-scaler).
#
#
# - **Pipeline C — Group-aware Imputation (Used in the project)**
#   Missing values are imputed using a hierarchical, domain-aware strategy:
#   - Imputation by *(brand, model)* group
#   - If not possible, imputation by *brand*
#   - As a fallback, global mean or mode is used
#   - Mileage imputed by KNN, since it's the only collumn that is related to the usage of the car and it's not a carachteristic.
#   - Log1p was used on the variables that were considered right skewed.
#
#   This approach represents the imputation strategy used throughout the rest of the project.
#
#
# - **Pipeline D — Model-based Imputation**
#   - 'model' missing values are imputed using baseline predictive models
#   - Every numeric is imputed by KNN
#
#
#   This pipeline is included to evaluate whether increased imputation complexity

# %% [markdown]
# The imputation of missing data will be done considering a logic that divides the features into two sections:
#
#
# 1. **Car specification features**
#     - For these, we consider features that characterize the cars mechanically.
#         - These features are: "brand", "model", "transmission", "fuelType", "tax", "mpg", "engineSize", and "car_age".
#     - Overall, the group assumed these columns can be imputed by the mode of the date grouped by brand and model. Logically, it is expected that all the cars of the same model and brand will have similar mechanical characteristics.
#         - This is further confirmed by the descriptive analysis, where it was identified that, in most cases, a clear mode for each category does exist. Even though that may not be true for all cases, it appears to be a reasonable assumption.
#
# 2. **Car usage features**
#     - For these, we consider features that characterize the past usage of cars.
#         - These features are: "mileage".

# %% [markdown]
# #### Pipeline A

# %%
numeric_pipeline_A = make_pipeline(
    SimpleImputer(strategy="median"),
    RobustScaler()
)

categorical_pipe = make_pipeline(
    SimpleImputer(strategy="most_frequent"),
    OneHotEncoder(handle_unknown="ignore")
)

preprocessor_A = ColumnTransformer(
    transformers=[
        ("num", numeric_pipeline_A, numeric_cols),
        ("cat", categorical_pipe, categorical_cols)
    ]
)
pipe_preprocessor_A = Pipeline([("column_transformer", preprocessor_A)])
pipe_preprocessor_A
# Out:
# Pipeline(steps=[('column_transformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('robustscaler',
#                                                                    RobustScaler())]),
#                                                   ['mileage', 'tax', 'mpg',
#                                                    'engineSize', 'car_age']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
# ...

# %% [markdown]
# #### Pipeline B

# %%
numeric_pipeline_B = make_pipeline(SimpleImputer(strategy="median"), 
                                   Log1pSkewed(numeric_cols, log_candidates),
                                   StandardScaler()
                                  )

cats_B = []

cats_B.append(("cat",
                 Pipeline([("impute_global_mode", SimpleImputer(strategy="most_frequent")),
                           ("ohe", OneHotEncoder(handle_unknown="ignore", drop="first", sparse_output=False))]),
                without_model))
cats_B.append(("model_collap",
                 Pipeline([("select", ColumnSelector("model")),
                           ("impute_global_mode", SimpleImputer(strategy="most_frequent")),
                           ("rare", RareLabelGrouper(min_prop=0.005, column="model")),
                           ("ohe", OneHotEncoder(handle_unknown="ignore", drop="first", sparse_output=False))]),
                 ["model"]))

# %%
preprocessor_B = ColumnTransformer([("num", numeric_pipeline_B, numeric_cols), *cats_B], remainder="drop")

pipe_preprocessor_B = Pipeline([("column_transformer", preprocessor_B)])
pipe_preprocessor_B
# Out:
# Pipeline(steps=[('column_transformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('log1pskewed',
#                                                                    Log1pSkewed(log_candidates=['mpg',
#                                                                                                'car_age',
#                                                                                                'mileage',
#                                                                                                'engineSize',
#                                                                                                'tax'],
# ...

# %% [markdown]
# #### Pipeline D

# %%
numeric_pipeline_D =  Pipeline([
    ("log1p_skewed", Log1pSkewed(numeric_cols, log_candidates)),
    ("scaler", StandardScaler()),
    ("KNN_Imputer", KNNImputer())
])

cats_D = []
cats_D.append(("cat_D",
                 Pipeline([("fallback_impute", SimpleImputer(strategy="most_frequent")),
                           ("ohe", OneHotEncoder(handle_unknown="ignore", drop="first", sparse_output=False))]),
                without_model))
cats_D.append(("model_collap",
                 Pipeline([("fallback_impute", SimpleImputer(strategy="most_frequent")),
                           ("rare", RareLabelGrouper(min_prop=0.005, column="model")),
                           ("ohe", OneHotEncoder(handle_unknown="ignore", drop="first", sparse_output=False))]),
                  ["model"] ))

# %%
preprocessor_D = ColumnTransformer([('num', numeric_pipeline_D, numeric_cols), *cats_D])

pipe_preprocessor_D = Pipeline([
    ('inputer_model', ModelPredictorImputer()),
    ("Imput_overal_mode_grouped_by_brand_and_model", Imput_By_Brand_and_Model(imput_cols = num_cols_whitout_mileage)),
    ('column_transformer', preprocessor_D)
])

# %%
x_reduzido = X[:1000]

# %%
pipe_preprocessor_D.fit(x_reduzido)
# Out:
# Pipeline(steps=[('inputer_model', ModelPredictorImputer()),
#                 ('Imput_overal_mode_grouped_by_brand_and_model',
#                  Imput_By_Brand_and_Model(imput_cols=['tax', 'mpg',
#                                                       'engineSize',
#                                                       'car_age'])),
#                 ('column_transformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('log1p_skewed',
#                                                                    Log1pSkewed(log_candidates=['mpg',
#                                                                                                'car_age',
#                                                                                                'mileage',
#                                                                                                'engineSize',
# ...

# %%
best_param_rf = {'n_estimators': 250, 'max_samples': 0.8, 'max_features': None, 'max_depth': 30, 'criterion': 'squared_error'}

# %%
preprocessors = {
    'A': pipe_preprocessor_A,
    'B': pipe_preprocessor_B,
    'C': pipe_preprocessor,
    'D': pipe_preprocessor_D
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 preprocessors = {
# ----> 2     'A': pipe_preprocessor_A,
#       3     'B': pipe_preprocessor_B,
#       4     'C': pipe_preprocessor,
#       5     'D': pipe_preprocessor_D
#       6 }
#       8 models = {
#       9     'RF': RandomForestRegressor(**best_param_rf),
#      10     'RF_baseline': RandomForestRegressor(),
#    (...)
#      14     'Ridge_baseline': Ridge()
#      15 }
#
# NameError: name 'pipe_preprocessor_A' is not defined

# %%
models = {
    'RF': RandomForestRegressor(**best_param_rf),
    'RF_baseline': RandomForestRegressor(),
    'LR_baseline': LinearRegression(),
    'NN_baseline': MLPRegressor(),
    'DT_baseline': DecisionTreeRegressor(),
    'Ridge_baseline': Ridge()
}

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=44)

results = []

for (prep_name, prep), (model_name, model) in product(preprocessors.items(), models.items()):
    
    mean_mae, std_mae = evaluate_pipeline(
        prep, model, X, y, kfold
    )
    
    results.append({
        'Preprocessor': prep_name,
        'Model': model_name,
        'Mean_MAE': mean_mae,
        'Std_MAE': std_mae
    })
    
    print(f"Prep {prep_name} | Model {model_name}: "
          f"MAE {mean_mae:.2f} (+/- {std_mae:.2f})")

# %%
results_df = pd.read_csv("../project_data/final_results/resultados_pipelines.csv")
#results_df = pd.DataFrame(results)
results_df.round(2)
# Out:
#     Unnamed: 0 Preprocessor           Model  Mean_MAE  Std_MAE
# 0            0            A              RF   1358.20    16.04
# 1            1            A     RF_baseline   1365.10    16.43
# 2            2            A     LR_baseline   2441.02    28.36
# 3            3            A     NN_baseline   1794.70    19.52
# 4            4            A     DT_baseline   1701.69     8.90
# 5            5            A  Ridge_baseline   2443.37    27.24
# 6            6            B              RF   1410.93    17.07
# 7            7            B     RF_baseline   1417.34    17.30
# 8            8            B     LR_baseline   2890.69    29.51
# 9            9            B     NN_baseline   2237.39    26.53
# 10          10            B     DT_baseline   1791.09    24.39
# 11          11            B  Ridge_baseline   2890.55    29.50
# 12          12            C              RF   1372.80    12.70
# 13          13            C     RF_baseline   1378.92    13.66
# ...

# %% [markdown]
# ### Pipeline comparison findings

# %% [markdown]
# - Despite the increasing sophistication of preprocessing strategies, the simplest pipeline (Pipeline A) consistently achieved the best predictive performance across models.
# - This result was unexpected (to say the least), given that Pipeline A relies on global imputation and does not incorporate domain-aware grouping. However, this pipeline differs from the others mainly in its treatment of numerical variables, preserving the original scale while mitigating the influence of extreme values through robust scaling rather than log-transformations.
# - With this being said, we will apply the same scaling strategy used in Pipeline A to Pipeline C, with the aim of isolating the effect of categorical preprocessing and assessing whether it accounts for the observed performance differences.

# %%
numeric_pipeline_c = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("RobustScaler", RobustScaler())
])

cats_c = []
cats_c.append(("cat",
                 Pipeline([("fallback_impute", SimpleImputer(strategy="most_frequent")),
                           ("ohe", OneHotEncoder(handle_unknown="ignore", drop="first", sparse_output=False))]),
                without_model))
cats_c.append(("model_collap",
                 Pipeline([("fallback_impute", SimpleImputer(strategy="most_frequent")),
                           ("rare", RareLabelGrouper(min_prop=0.005, column="model")),
                           ("ohe", OneHotEncoder(handle_unknown="ignore", drop="first", sparse_output=False))]),
                  ["model"] ))

preprocessor_c = ColumnTransformer([("num", numeric_pipeline_c, numeric_cols), *cats])
pipe_preprocessor_c = Pipeline([("Imput_model_mode_grouped", Mode_Imput_By_Brand(imput_cols=["model"], group_col="brand")),
                              ("Imput_overal_mode_grouped_by_brand_and_model", Imput_By_Brand_and_Model(imput_cols = without_model_brand)),
                              ("column_transformer",preprocessor_c)])

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=44)

results_pipe_c = []

for model_name, model in models.items():
    mean_mae, std_mae = evaluate_pipeline(
        pipe_preprocessor_c, model, X, y, kfold
    )

    results_pipe_c.append({
        'Preprocessor': 'C',
        'Model': model_name,
        'Mean_MAE': mean_mae,
        'Std_MAE': std_mae
    })

    print(
        f"Pipeline C | Model {model_name}: "
        f"MAE {mean_mae:.2f} (+/- {std_mae:.2f})"
    )
# Out:
# Pipeline C | Model RF: MAE 1371.36 (+/- 14.63)
# Pipeline C | Model RF_baseline: MAE 1378.80 (+/- 14.55)
# Pipeline C | Model LR_baseline: MAE 2832.95 (+/- 28.83)
# Pipeline C | Model NN_baseline: MAE 2157.80 (+/- 29.08)
# Pipeline C | Model DT_baseline: MAE 1699.49 (+/- 19.24)
# Pipeline C | Model Ridge_baseline: MAE 2832.40 (+/- 28.86)

# %%
results_pipe_c_df = pd.DataFrame(results_pipe_c)
results_pipe_c_df.to_csv("results_pipe_c_adjusted.csv")
results_pipe_c_df
# Out:
#   Preprocessor           Model     Mean_MAE    Std_MAE
# 0            C              RF  1371.358434  14.625763
# 1            C     RF_baseline  1378.800418  14.550035
# 2            C     LR_baseline  2832.949205  28.834482
# 3            C     NN_baseline  2157.800364  29.076241
# 4            C     DT_baseline  1699.487408  19.241396
# 5            C  Ridge_baseline  2832.400867  28.863437

# %% [markdown]
# ## Brand-Specific vs General Model Comparison
#
#
#
# We investigate whether training separate models for each brand improves
#
# predictions compared to a single general model.

# %%
brands = X['brand'].unique()

brand_results = []
kfold = KFold(n_splits=5, shuffle=True, random_state=44)

for brand in brands:    

    brand_mask = X['brand'] == brand
    X_brand = X[brand_mask]
    y_brand = y[brand_mask]
    
    brand_model = Pipeline([
        ('prep', clone(PreprocessAndRemoveByName(pipeline, features_to_remove))),
        ('rf', RandomForestRegressor(**best_param_rf))
    ])
    
    brand_cv_scores = cross_val_score(
        brand_model, X_brand, y_brand,
        cv=kfold, scoring='neg_mean_absolute_error', n_jobs=-1
    )
    brand_mae = -brand_cv_scores.mean()
    
    general_cv_scores = cross_val_score(
        best_rf, X_brand, y_brand,
        cv=kfold, scoring='neg_mean_absolute_error', n_jobs=-1
    )
    general_mae = -general_cv_scores.mean()
    
    brand_results.append({
        'Brand': brand,
        'N_Samples': len(X_brand),
        'Brand_Specific_MAE': round(brand_mae, 2),
        'General_Model_MAE': round(general_mae, 2),
        'Improvement': round(general_mae - brand_mae, 2)
    })
    
    print(f"  Brand-specific MAE: {brand_mae:.2f}, General MAE: {general_mae:.2f}")

brand_comparison_df = pd.DataFrame(brand_results)
brand_comparison_df.sort_values('Improvement', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 13
#       9 X_brand = X[brand_mask]
#      10 y_brand = y[brand_mask]
#      12 brand_model = Pipeline([
# ---> 13     ('prep', clone(PreprocessAndRemoveByName(pipeline, features_to_remove))),
#      14     ('rf', RandomForestRegressor(**best_param_rf))
#      15 ])
#      17 brand_cv_scores = cross_val_score(
#      18     brand_model, X_brand, y_brand,
#      19     cv=kfold, scoring='neg_mean_absolute_error', n_jobs=-1
#      20 )
#      21 brand_mae = -brand_cv_scores.mean()
#
# NameError: name 'pipeline' is not defined

# %% [markdown]
# ### Brand-Specific Model Insights

# %% [markdown]
# # 5. Deployment
#
#
#
# ## Final Model Training
#
#
#
# Train the final model on the complete training dataset for deployment.

# %%
final_model = clone(best_model)

final_model.fit(X, y)

# %%
# Save the model
joblib.dump(final_model, 'final_model.pkl')

# %% [markdown]
# ## Summary and Conclusions
#
#
#
# ### Key Findings
#
#
#
# 1. **Best Performing Model**: Random Forest with optimized hyperparameters achieved the lowest validation MAE???????
#
# 2. **Most Important Features**:
# COLOCAR TEXTOOOOO
#
#
# 3. **Preprocessing Strategy**:
#
#
#
# 5. **Model Performance**:
