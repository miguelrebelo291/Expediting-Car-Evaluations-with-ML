# %% [markdown]
# # Cars 4 You - Car Price Prediction
#
# ## Group Member Contribution
#
# | Number | Member | Contribution | Estimated % |
# |--------|--------|--------------|-------------|
# |20250391|Guilherme Vieira| Webscraping, EDA, Preprocessing, Neural Networks, Model Optimization and Deployment, Open-Ended Section|30%|
# |        | Miguel Rebelo | EDA, Preprocessing, Decision Trees, Model Optimization and Deployment,Open-Ended Section |30%|
# |20250371| João Roque | EDA, Random Forest, Model Optimization and Deployment,Open-Ended Section |25%|
# |        | Rita Escudeiro | EDA, Linear Regression, Ridge Regression |15%|

# %% [markdown]
# ## Abstract
#
# This project addresses the business challenge faced by Cars 4 You, an online car resale company seeking to expedite their car evaluation process. The primary objective is to develop a regression model capable of accurately predicting car prices based on user-provided features, eliminating the need for physical mechanic inspections.
#
# We employed a comprehensive machine learning pipeline incorporating data preprocessing with custom transformers for handling missing values through mode imputation grouped by brand and model, feature engineering including mileage per year calculations, and categorical encoding with rare label grouping. Five regression algorithms were benchmarked: Linear Regression, Ridge/Lasso Regression, Decision Trees, Random Forest, and Neural Networks.
#
# Our model assessment strategy utilized 10-fold cross-validation with Mean Absolute Error (MAE) as the primary metric, supplemented by RMSE and R² for comprehensive evaluation. Feature selection was performed using Recursive Feature Elimination (RFE) and Lasso-based coefficient analysis. Hyperparameter tuning was conducted through GridSearchCV and RandomizedSearchCV.
#
# The Random Forest model achieved the best generalization performance with a cross-validated MAE of approximately £X,XXX. Key predictive features included car age, engine size, mileage, and brand. The open-ended section explores feature importance analysis, brand-specific models comparison, and an interactive prediction interface. The final deployed model successfully generates predictions for the Kaggle competition test set.

# %% [markdown]
# # 0. Import Packages

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast
from math import ceil
from sklearn.feature_selection import RFE
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, FunctionTransformer, StandardScaler, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV, ElasticNetCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, make_scorer
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
from sklearn.impute import KNNImputer
from sklearn.model_selection import cross_val_score
from sklearn.utils.validation import check_is_fitted, _check_feature_names_in
from sklearn.model_selection import cross_validate
from sklearn.pipeline import make_pipeline
from sklearn.base import clone
#from sklearn.utils.validation import validate_data
import joblib
pd.set_option('display.max_columns', None)
import time

# %% [markdown]
# # Identifying Business Needs
#
#
#
# ## Business Context
#
#
#
# Cars 4 You is an online car resale company facing operational challenges due to growing waiting lists for car inspections. The current process requires physical mechanic evaluation before purchasing vehicles, creating bottlenecks that drive potential customers to competitors.
#
#
#
# ## Project Goals
#
#
#
# 1. **Primary Objective**: Develop a regression model to predict car prices (target: 'price') based on user-provided specifications
#
# 2. **Secondary Objectives**:
#
#    - Identify key features influencing car prices
#
#    - Compare multiple modeling approaches
#
#    - Create a deployable prediction pipeline
#
#
#
# ## Model Assessment Strategy
#
#
#
# We adopt the following assessment approach:
#
#
#
# - **Validation Method**: 5-Fold Cross-Validation
#
#   - Provides robust performance estimates
#
#   - Balances bias-variance tradeoff in model evaluation
#
#
#
# - **Primary Metric**: Mean Absolute Error (MAE)
#
#   - Directly interpretable in business terms (pounds)
#
#   - Less sensitive to outliers than RMSE
#
#   - Appropriate for price prediction where actual error magnitude matters
#
#
#
# - **Secondary Metrics**:
#
#   - RMSE: Penalizes larger errors more heavily
#
#   - R²: Proportion of variance explained
#
#
#
# - **Hyperparameter Tuning**:
#
#   - RandomizedSearchCV for initial exploration
#
#   - GridSearchCV for fine-tuning around best parameters

# %% [markdown]
# # 1. Read Data and Inspect

# %%
#importing original data and previously worked dataframe
df_train = pd.read_csv("../project_data/handout_data/training_handout.csv")

# %%
df_train.columns
# Out:
# Index(['Unnamed: 0', 'carID', 'brand', 'model', 'price', 'transmission',
#        'mileage', 'fuelType', 'tax', 'mpg', 'engineSize', 'paintQuality%',
#        'previousOwners', 'hasDamage', 'car_age'],
#       dtype='object')

# %%
df_train.shape
# Out:
# (75973, 15)

# %%
#remove unnamed 0 column
df_train = df_train.drop(columns=['Unnamed: 0'])
df_train
# Out:
#        carID     brand     model  price transmission  mileage fuelType    tax  \
# 0      69512        vw      golf  22290    semi-auto  28421.0   petrol    NaN
# 1      53000    toyota     yaris  13790       manual   4589.0   petrol  145.0
# 2       6366      audi        q2  24990    semi-auto   3624.0   petrol  145.0
# 3      29021      ford    fiesta  12500       manual   9102.0   petrol  145.0
# 4      10062       bmw  2 series  22995       manual   1000.0   petrol  145.0
# ...      ...       ...       ...    ...          ...      ...      ...    ...
# 75968  37194  mercedes   c class  13498       manual  14480.0   petrol  125.0
# 75969   6265      audi        q3  12495    semi-auto  52134.0   diesel  200.0
# 75970  54886    toyota      aygo   8399    automatic  11304.0   petrol  145.0
# 75971    860      audi        q3  12990       manual  69072.0   diesel  125.0
# 75972  15795      ford    fiesta  10495       manual  16709.0   petrol  145.0
#
#         mpg  engineSize  paintQuality%  previousOwners  hasDamage  car_age
# 0      11.4         2.0           63.0             4.0        0.0      4.0
# 1      47.9         1.5           50.0             1.0        0.0      1.0
# 2      40.9         1.5           56.0             4.0        0.0      1.0
# 3      65.7         1.0           50.0             NaN        0.0      2.0
# 4      42.8         1.5           97.0             3.0        0.0      1.0
# ...     ...         ...            ...             ...        ...      ...
# 75968  53.3         2.0           78.0             0.0        0.0      5.0
# 75969  47.9         2.0           38.0             2.0        0.0      7.0
# 75970  67.0         1.0           57.0             3.0        0.0      3.0
# 75971  60.1         2.0           74.0             2.0        0.0      5.0
# 75972  64.2         1.1           38.0             1.0        0.0      2.0
#
# [75973 rows x 14 columns]

# %% [markdown]
# ### Missing Data

# %%
miss = df_train.isna().sum()
mv = pd.DataFrame({"missing": miss[miss>0], "missing_%": (miss[miss>0]/len(df_train)*100).round(2)}).sort_values("missing_%", ascending=False)
if not mv.empty:
    print("\nMissing-values summary (non-zero):")
    print(mv.head(20))
# Out:
# Missing-values summary (non-zero):
#                 missing  missing_%
# tax                8282      10.90
# mpg                7970      10.49
# transmission       2263       2.98
# engineSize         2034       2.68
# previousOwners     1921       2.53
# car_age            1849       2.43
# mileage            1832       2.41
# model              1721       2.27
# fuelType           1678       2.21
# hasDamage          1548       2.04
# paintQuality%      1524       2.01
# brand                43       0.06

# %% [markdown]
# - There is not that much missing data in almost every feature besides tax and mpg.
# - In our case, if we have a car with some missing values and another of the same brand and model with those values filled we can pretty much use that car to fill the gaps of the 1st one, even tough same brand and model can have diferent specifications, we believe it's a logical and valid approach.

# %%
df_train[df_train["brand"].isnull()]
# Out:
#        carID brand model  price transmission  mileage fuelType    tax   mpg  \
# 442    16342   NaN   NaN   8600       manual  28820.0   diesel    0.0  74.4
# 2031   12064   NaN   NaN  21300    automatic  11258.0      NaN  145.0  64.2
# 2223   44351   NaN   NaN  12990    automatic  43000.0   diesel  145.0  54.3
# 4250   38960   NaN   NaN  25495    semi-auto   4255.0   petrol  145.0  44.8
# 5513   55454   NaN   NaN   8997       manual  11200.0   petrol   30.0  58.0
# 5967   74657   NaN   NaN  19750    semi-auto   9500.0   petrol  145.0  55.4
# 6233     669   NaN   NaN  29250    automatic  10055.0   diesel  145.0  47.9
# 7793   20208   NaN   NaN  15499    semi-auto  64315.0   diesel  145.0  54.3
# 12893  44161   NaN   NaN  14999       manual  29053.0   diesel   20.0  64.2
# 13087  65456   NaN   NaN  16500       manual   3000.0   diesel  145.0  57.7
# 13777  44380   NaN   NaN  25849    semi-auto  10977.0   petrol  145.0  47.1
# 14322   6742   NaN   NaN  35850    automatic   9788.0   petrol  145.0  32.1
# 17149  37901   NaN   NaN  25299    automatic   2838.0   diesel  145.0  64.2
# 20385  14098   NaN   NaN  11000    automatic  37905.0   diesel  165.0  52.3
# 27321  18511   NaN   NaN  15500       manual  40000.0   diesel  125.0  56.5
# 28760  45668   NaN   NaN  17899       manual  19300.0   diesel  145.0  68.9
# 28802  66181   NaN   NaN  49996    automatic    947.0   diesel  145.0  32.8
# 28905  19115   NaN   NaN   6180       manual  26105.0   petrol   30.0  54.3
# 30306  46984   NaN   NaN  21790    automatic   8326.0   petrol  145.0  36.7
# 30644   5908   NaN   NaN  14500    semi-auto  56875.0   diesel  150.0  53.3
# 31189  37395   NaN   NaN  22399    automatic  19000.0   diesel  145.0  65.7
# 32285   7254   NaN   NaN  19995    automatic  66000.0   diesel  300.0  38.2
# 32689   3739   NaN   NaN  34000    automatic   1000.0   petrol  145.0  31.4
# 36070  39694   NaN   NaN  25950    automatic   3168.0   diesel  145.0  55.4
# 38073  18121   NaN   NaN   8250       manual  25300.0   petrol    0.0  65.7
# 38180  65872   NaN   NaN  11995    semi-auto  31423.0   petrol  145.0   NaN
# 39772  59552   NaN   NaN  15000       manual   3159.0   diesel  145.0  58.9
# 40338  29268   NaN   NaN   9938       manual  13195.0   petrol    0.0  65.7
# 46068  74210   NaN   NaN  19450    semi-auto   3700.0   diesel  145.0  52.3
# 48769   4560   NaN   NaN  20488       manual  25576.0   diesel  145.0  54.3
# 53620  66941   NaN   NaN  26310    automatic   6000.0      NaN  145.0  37.7
# 57295  30941   NaN   NaN  14299    automatic  27199.0   petrol  240.0  38.2
# 57779   7855   NaN   NaN  17000    semi-auto  40750.0   diesel  160.0  50.4
# 57961  49814   NaN   NaN  21500    semi-auto   6521.0   petrol  145.0  43.5
# 58889  56869   NaN   NaN  11499       manual  32094.0   diesel  145.0  70.6
# 59616  74195   NaN   NaN  23500    semi-auto  22502.0   petrol  145.0  39.8
# 65401  21730   NaN   NaN  17295       manual  16634.0   diesel  125.0  56.5
# 67387  24435   NaN   NaN  17298       manual  12142.0   petrol    NaN   NaN
# 67565  31541   NaN   NaN   9691    automatic  29064.0   diesel  165.0  51.4
# 68006  61305   NaN   NaN  16999    semi-auto     10.0   petrol  145.0  44.1
# 71703  13026   NaN   NaN  15000    semi-auto  38689.0   petrol  235.0  37.7
# 72025  68226   NaN   NaN  10491       manual  22211.0   petrol  150.0  60.1
# 74428   4703   NaN   NaN  51990    automatic     10.0   petrol    NaN  30.4
#
#        engineSize  paintQuality%  previousOwners  hasDamage  car_age
# 442           1.5            NaN             0.0        0.0      3.0
# 2031          2.0           60.0             3.0        0.0      2.0
# 2223          2.1           78.0             0.0        0.0      7.0
# 4250          1.3           63.0             0.0        0.0      1.0
# 5513          1.3           91.0             2.0        0.0      3.0
# 5967          1.5           52.0             3.0        0.0      2.0
# 6233          2.0           70.0             1.0        0.0      1.0
# 7793          2.0           75.0             4.0        0.0      3.0
# 12893         2.1           42.0             NaN        0.0      5.0
# 13087         1.6           38.0             2.0        0.0      1.0
# 13777         1.5           52.0             0.0        0.0      1.0
# 14322         2.0           67.0             3.0        0.0      1.0
# 17149         2.1           73.0             4.0        0.0      1.0
# 20385         2.0           87.0             0.0        0.0      6.0
# 27321         2.0           31.0             4.0        0.0      4.0
# 28760         1.5           98.0             3.0        0.0      3.0
# 28802         2.0           36.0             0.0        0.0      1.0
# 28905         1.2           83.0             1.0        0.0      6.0
# 30306         NaN           45.0             6.0        0.0      1.0
# 30644         2.0           69.0             0.0        0.0      5.0
# 31189         2.0           42.0             4.0        0.0      3.0
# 32285         NaN           31.0             4.0        0.0      6.0
# 32689         2.0           71.0             3.0        0.0      0.0
# 36070         2.0           83.0             3.0        0.0      1.0
# 38073         1.0           98.0             1.0        0.0      NaN
# 38180         1.2           71.0             3.0        0.0      3.0
# 39772         1.6           64.0             1.0        0.0      1.0
# 40338         1.0           86.0             0.0        0.0      3.0
# 46068         2.0           87.0             3.0        0.0      1.0
# 48769         2.0           93.0             1.0        0.0      3.0
# 53620         1.5           70.0             3.0        0.0      1.0
# 57295         2.0           84.0             4.0        0.0      4.0
# 57779         3.0           83.0             3.0        0.0      5.0
# 57961         2.0           48.0             NaN        0.0      2.0
# 58889         1.6           53.0             2.0        0.0      3.0
# 59616         2.0           75.0             1.0        0.0      3.0
# 65401         2.0           69.0             4.0        0.0      3.0
# 67387         1.0           53.0             1.0        0.0      1.0
# 67565         1.6           31.0             2.0        0.0      6.0
# 68006         1.2           82.0             2.0        0.0      0.0
# 71703         3.0           96.0             3.0        0.0      6.0
# 72025         1.2           82.0             0.0        0.0      3.0
# 74428         2.9           54.0             1.0        0.0      1.0

# %% [markdown]
# Since the inputation that will take place later is made through at least one of the brand or model features, and since the lines above referenced represent 0.06% of the total data, the group decided to drop these lines.

# %%
df_train = df_train[~df_train["brand"].isnull()]
df_train
# Out:
#        carID     brand     model  price transmission  mileage fuelType    tax  \
# 0      69512        vw      golf  22290    semi-auto  28421.0   petrol    NaN
# 1      53000    toyota     yaris  13790       manual   4589.0   petrol  145.0
# 2       6366      audi        q2  24990    semi-auto   3624.0   petrol  145.0
# 3      29021      ford    fiesta  12500       manual   9102.0   petrol  145.0
# 4      10062       bmw  2 series  22995       manual   1000.0   petrol  145.0
# ...      ...       ...       ...    ...          ...      ...      ...    ...
# 75968  37194  mercedes   c class  13498       manual  14480.0   petrol  125.0
# 75969   6265      audi        q3  12495    semi-auto  52134.0   diesel  200.0
# 75970  54886    toyota      aygo   8399    automatic  11304.0   petrol  145.0
# 75971    860      audi        q3  12990       manual  69072.0   diesel  125.0
# 75972  15795      ford    fiesta  10495       manual  16709.0   petrol  145.0
#
#         mpg  engineSize  paintQuality%  previousOwners  hasDamage  car_age
# 0      11.4         2.0           63.0             4.0        0.0      4.0
# 1      47.9         1.5           50.0             1.0        0.0      1.0
# 2      40.9         1.5           56.0             4.0        0.0      1.0
# 3      65.7         1.0           50.0             NaN        0.0      2.0
# 4      42.8         1.5           97.0             3.0        0.0      1.0
# ...     ...         ...            ...             ...        ...      ...
# 75968  53.3         2.0           78.0             0.0        0.0      5.0
# 75969  47.9         2.0           38.0             2.0        0.0      7.0
# 75970  67.0         1.0           57.0             3.0        0.0      3.0
# 75971  60.1         2.0           74.0             2.0        0.0      5.0
# 75972  64.2         1.1           38.0             1.0        0.0      2.0
#
# [75930 rows x 14 columns]

# %% [markdown]
# Columns identified in the EDA to be removed:

# %%
df_train = df_train.drop(columns=['carID', 'previousOwners', 'paintQuality%', 'hasDamage'])

# %% [markdown]
# Correlation:

# %%
numeric_cols = df_train.select_dtypes(include=['int64', 'Int64', 'float64']).columns

# Compute correlation matrix
corr_matrix = df_train[numeric_cols].corr()

# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Matrix of Numeric Variables")
plt.show()

# %% [markdown]
# - On one hand it seems like a good opportunity to use a KNN imputer because the missing data is way below the common treshold of 30% and the missing data seems to be MAR
# - On the other, the correlations between numeric variables is not the best since in most cases the r is lower than 0.3 plus the imputation of mode grouped by brand and model seems to also make very sense, as the knn imputer would be prone to do something that is out of reality like imputing models to brands that don´t exist and values that also don´t exist

# %% [markdown]
# # 2. Modify the Data

# %% [markdown]
# ## Split the data

# %%
X = df_train.drop("price", axis=1).copy()
y = df_train["price"].copy()

# %% [markdown]
# ## Pipeline construction

# %% [markdown]
# ### Column Transformers

# %%
class RareLabelGrouper(BaseEstimator, TransformerMixin):
    
    """
    This class will be useful to identify and group rare instances in the model column as "other". 
    The minimal proportion needed to not be grouped is min_prop.
    
    """
   
    def __init__(self, min_prop=0.005, column=None): 
        self.min_prop = min_prop
        
        self.column = column
        
        self.keep_values_ = None  #This will be used to store the values to group
    
    
    def fit(self, X, y=None):
        s = X if isinstance(X, pd.Series) else pd.Series(X.iloc[:,0] if hasattr(X, "iloc") else X[:,0])  # 
        
        vc = s.value_counts(dropna=False) 
        
        total = len(s)  
        
        keep = vc[vc / total >= self.min_prop].index # Chooses the categories for which the minimum proportion is met
        
        self.keep_values_ = set(keep.tolist()) # Attributes them to an attribute of the class in the form of a list
        
        return self
    
    
    def transform(self, X):
        """
        np.where() works like an if-else statement. If s is in stored values to keep, then keep s, else attribute "Other".
        To attribute the name of the column, if it was passed and stored in the attribute .column, then use that name, else use the generic 'col' name.
        """
        s = X if isinstance(X, pd.Series) else pd.Series(X.iloc[:,0] if hasattr(X, "iloc") else X[:,0])  #Same pandas series problem
        return pd.DataFrame(np.where(s.isin(self.keep_values_), s, "Other"),  
                            columns=[self.column if self.column else "col"])

    
    def get_feature_names_out(self, input_features=None):

        if input_features is not None:
            return np.asarray(input_features, dtype=object)

        col_name = self.column if self.column else "col"
        return np.asarray([col_name], dtype=object)

# %%
class CustomWinsorizer(BaseEstimator, TransformerMixin):
    
    """
    Takes care of outliers by winsorizing selected numeric variables.
    During fit(), it learns the lower and upper quantile limits for each variable.
    During transform(), any value below the lower limit is replaced with that limit, and any value above the upper limit is capped at the upper limit.
    This reduces the influence of extreme values while keeping all observations in the dataset.
    """
    
    def __init__(self, variables, lower_bound=0.01, upper_bound=0.99):
        self.variables = variables  #is a list of the columns we want to apply the transformer to (Confirmable further)
        self.lower_bound = lower_bound
        self.upper_bound = upper_bound
        self.limits_ = {} #Will store the value of the limits calculated in fit() to apply in transform()


    def fit(self, X, y=None):
        for var in self.variables:  #Iterates over all columns specified in the list
            if var in X.columns:  #Makes sure it is one of the DataFrame's columns
                lower_limit = X[var].quantile(self.lower_bound)  #Calculates the lower-limit
                upper_limit = X[var].quantile(self.upper_bound)  #Calculates the upper-limit
                self.limits_[var] = (lower_limit, upper_limit)  #Stores the limits calculated for use in transform(). It's stored associated to a key with the name of the column
        
        return self


    def transform(self, X):
        X_transformed = X.copy()
        
        for var, (lower_limit, upper_limit) in self.limits_.items():  #Iterates over all columns chosen to transform
            if var in X.columns:  #Defensive programming to make sure the column is there
                X_transformed[var] = np.clip(X_transformed[var], lower_limit, upper_limit) #Replaces values in the series that are higher than lower_limit with the lower limit and the same for the upper limit
        
        return X_transformed

# %%
class Mode_Imput_By_Brand (BaseEstimator, TransformerMixin):

    """
    O objetivo com este transformer é preencher os valores nulos de cada coluna através da moda, mas primeiro, agrupar por brand.
    Como fallback, caso nao haja nenhuma linha preenchida daquela brand em especifico, depois de utilizar este transformer
    iremos utilzar o SimpleImputer.
    
    """
    
    def __init__(self, imput_cols = None , group_col = "brand"):       
        self.imput_cols = imput_cols  #Store the imputing values for each group
        self.group_col = group_col #Stores the variable name in which we want to group to input the value we need (for example, group by the brand to input the most likely model of a given car)

    # é obrigatorio colocar X e y em todos os metodos de fit do sklearn
    def fit(self , X, y = None):
        X = X.copy()  # em qualquer metodo do sklearn criamos uma copia do df original, pois no pipeline é usado o mesmo df nao modificado para os vários passos
        
        if self.imput_cols is None: # sklearn nao gosta de args obrigatórios entao fazemos isto para contornar
            self.imput_cols = [col for col in X.columns if col != self.group_col] #Iterates over all columns that are not group_col and stores their names in a list 
        
        self.mode_maps_ = {}

        for col in self.imput_cols:  #Iterate over all columns except the group_col
            mode_map = X.groupby(self.group_col)[col].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else np.nan)  #Calculates the mode for each group and if there isn't assume np.nan
            self.mode_maps_[col] = mode_map

        return self

        
    def transform(self, X):
        X = X.copy()

        for col in self.imput_cols:  #Iterate over all columns except the group_col
            X[col] = X[col].fillna(X[self.group_col].map(self.mode_maps_[col]))  #Fills all nans in one column (col) with the mode found in the mode_maps_ dict, which contains the mode for the different groups that were grouped through the group_col

        return X

# %%
class Imput_By_Brand_and_Model (BaseEstimator, TransformerMixin):

    """

    The goal with this transformer is to fullfill the Nans by the mode,  but 1st grouping by brand and model. Has a fallback
    in the pipeline, after using this transformer, it should be used a SimplImputer to guarantee that in the end, there is no missing
    values.

    =============================================================================================================================

    Parameters:

        imput_cols: List of cols you want to imput, if none is passed then it will assume all columns should be imputed besides the 
        ones on the group_cols

        group_cols: List of cols you want to groupby, it's defaulted to be brand and model

        .mode_maps: Dictionary for each imput column, where each key is an imput_col and each value is a dictionary where each key is
                    a combiantion of brand and model and each value is the mode

    ==============================================================================================================================

    Methods:
    
        .fit: Creates a loop that for each column to imput: 0. Creates an empty dict to store each imput col as a key
                                                            1. Groups the data by the group_cols
                                                            2. Calculates the mode, if more than 1 get´s the 1st one 
                                                            if there is no value it returns Nan
                                                            3. Stores the combination of brand and model (group_cols) and mode
                                                            as a key-value pair 
        
        .transform: 1. For each row of the dataset stores the pair of (brand,model) into a Series
                    2. Loops trough the imput_cols and for each one it uses the pairs created before as a key to get the value of 
                    the mode_maps, storing this value in a Series called mapped
                    3. Goes trough each line of the data, if the value is nan it fulfiles it with the corresponding value of the
                    mapped series

    ==============================================================================================================================

    Attributes:

        mode_maps_ : Dictionary of dictionarys that stores the mode for each pair in each column of X.

                     {{"feature_1:"("bmw","i8"): mode,
                     ('vw', 'up!'): mode},
                     {"feature_2": "("bmw","i8"): mode,
                     ('vw', 'up!'): mode}}
                     
    
    """

    def __init__(self, imput_cols = None , group_cols = ["brand", "model"]):       
        self.imput_cols = imput_cols
        self.group_cols = group_cols

    
    def fit(self , X, y = None):
        X = X.copy()  
        
        if self.imput_cols is None: 
            self.imput_cols = [col for col in X.columns if col != self.group_cols]
        
        self.mode_maps_ = {}

        for col in self.imput_cols:
            mode_map = X.groupby(self.group_cols)[col].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else np.nan) 
            self.mode_maps_[col] = mode_map.to_dict()

        return self 
    
    def transform(self, X):
        X = X.copy()

        keys = list(zip(*[X[g] for g in self.group_cols]))  # [(brand, model), ...]
        key_series = pd.Series(keys, index=X.index)

        for col in self.imput_cols:
            mapped = key_series.map(self.mode_maps_[col])
            X[col] = X[col].fillna(mapped)

        return X

# %%
class Log1pSkewed(BaseEstimator, TransformerMixin):

    """ 
    This transformer computes the natural logarithm of (1 + x) for the columns specified in log_candidates. 
    The goal is to reduce right-skewness and stabilise variance in those features.

     ========================================================================================================

    Parameters: 

        numeric_cols: list of str
                      Names of the numeric columns of X

        log_candidates: list of str
                        Names of the columns of X that are right_skewed

     ========================================================================================================

    Methods:

        .fit: Stores the name of all features the indices of the features that will
        undergo through the log1p transformation (log_candidates).

        .transform: Applies the log1p transformation to the selected columns.

        .get_feature_names_out: 
        
    ========================================================================================================

    Attributes:

        n_features_in_: number of features before applying the fit

        feature_names_in_: name of the features before applying the fit

        log_idx_: indices of the columns in log_candidates


    """
    
    def __init__(self, numeric_cols, log_candidates):
        self.numeric_cols = numeric_cols
        self.log_candidates = log_candidates

    def fit(self, X, y=None):
        
    #   X = validate_data(self, X, accept_sparse=False, reset=True) # guarantees a correct format and stores n_features_in_
        X = self._validate_data(X, accept_sparse=False, reset=True) # guarantees a correct format and stores n_features_in_

        if hasattr(X, "columns"): # here the intention is to give more flexibility, on the current pipeline, we know that it will receive an array.
            self.feature_names_in_ = np.array(X.columns, dtype=object) 
        else:
            self.feature_names_in_ = np.array(self.numeric_cols, dtype=object)

        self.log_idx_ = [self.numeric_cols.index(c) for c in self.log_candidates]

        return self

    
    def transform(self, X):
        
        X = np.asarray(X).copy() # turn X into an array just in case 
       
        X[:, self.log_idx_] = np.log1p(X[:, self.log_idx_]) 
        
        return X

    
    def get_feature_names_out(self, input_features=None):
        
        if input_features is not None:
            return np.asarray(input_features, dtype=object)
        
        elif hasattr(self, "feature_names_in_"): # just in case this is the 1st transformer, even tough it probably never will
            return self.feature_names_in_

# %%
class ColumnSelector(BaseEstimator, TransformerMixin):
    """
    Selects a single column from the incoming DataFrame X, based on the column name provided at initialization.
    This column is returned as a DataFrame
    """
    
    def __init__(self, column): 
        self.column = column
    
    
    def fit(self, X, y=None): 
        return self
    
    
    def transform(self, X): 
        return pd.DataFrame(X[self.column])


    def get_feature_names_out(self, input_features=None):
        return np.asarray([self.column], dtype=object)
    
class ColumnDropper(BaseEstimator, TransformerMixin):
    """Drop specified columns."""
    def __init__(self, columns):
        self.columns = columns
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        X = X.copy()
        cols_to_drop = [c for c in self.columns if c in X.columns]
        return X.drop(columns=cols_to_drop)

# %%
class PreprocessAndRemoveByName(BaseEstimator, TransformerMixin):

    """
    Wrapper transformer that applies a given preprocessing pipeline and removes a predefined set of output features by name.

    ========================================================================================================

    Parameters: 

        preprocessor: sklearn.pipeline
                    A preprocessing pipeline

        removed_features: list of str
                        list of undesired features

        feature_name_step: str, default="column_transformer"
                         Name of the step within the preprocessing pipeline from which output 
                         feature names are extracted.
                        

     ========================================================================================================

    Methods:

        .fit: Stores the name of all features the indices of the features that will
        undergo through the log1p transformation (log_candidates).

        .transform: Applies the log1p transformation to the selected columns.

        .get_feature_names_out: 
        
    ========================================================================================================

    Attributes:

        self.preprocessor_: sklearn.pipeline
                            Fitted clone of the preprocessing pipeline provided at initialization.
                            This instance is created during `fit` to avoid sharing fitted state
                            across cross-validation folds
                            

        keep_indices_ : list of int
                        Indices of the output features retained after preprocessing.
                        These indices correspond to the features whose names are not included
                        in 'removed_features' and are used to slice the transformed feature
                        matrix during 'transform'.


        removed_found_: list of str
                        Subset of `removed_features` that were found among the output features
                        of the preprocessing pipeline. This attribute is useful for debugging 
                        and verification of the feature-removal process.
    """

    
    def __init__(self, preprocessor, removed_features, feature_name_step="column_transformer"):
        self.preprocessor = preprocessor
        self.removed_features = removed_features
        self.feature_name_step = feature_name_step  # this is the step inside de preprocessor that has the names of the features, which will be "column_transformer" or any other name given to the ColumnTransformer

    def fit(self, X, y=None):
        # this prevents from using the same fitted preprocessor in different folds, in each fold it creates a clone of the "exterior" pipeline which in this case is PreprocessAndRemoveByName so we need to force a new clone of the pipeline inside it  
        self.preprocessor_ = clone(self.preprocessor) 
        self.preprocessor_.fit(X, y)

        # We go to the inside pipeline and to the specific step (Column Transformer name) to get the features names
        feature_names = self.preprocessor_.named_steps[self.feature_name_step].get_feature_names_out()
        feature_names = list(feature_names)

        self.keep_indices_ = [i for i, f in enumerate(feature_names) if f not in self.removed_features]

        self.feature_names_out_ = [feature_names[i] for i in self.keep_indices_] # update the fetures that will be kepted
        return self

    def transform(self, X):
        Xt = self.preprocessor_.transform(X)
        return Xt[:, self.keep_indices_]

    def get_feature_names_out(self, input_features=None):
        return np.array(self.feature_names_out_)

# %%
class KNNMileageImputer(BaseEstimator, TransformerMixin):
    """
    Impute mileage using KNN based on relevant features.
    Uses car_age, engineSize, and other correlated features.
    """

    def __init__(self, n_neighbors=5):
        self.n_neighbors = n_neighbors
        self.knn_imputer = None
        self.feature_cols = ['car_age', 'engineSize', 'mpg', 'tax']

        

    def fit(self, X, y=None):
        X = X.copy()
        available_cols = [col for col in self.feature_cols if col in X.columns]
        available_cols.append('mileage')

        
        self.knn_imputer = KNNImputer(n_neighbors=self.n_neighbors)

        # Pre-impute the helper columns with median for KNN to work
        temp_df = X[available_cols].copy()
        for col in available_cols:
            if col != 'mileage':
                temp_df[col] = temp_df[col].fillna(temp_df[col].median())
        self.knn_imputer.fit(temp_df)
        self.available_cols_ = available_cols
        return self

    

    def transform(self, X):
        X = X.copy()
        if X['mileage'].isnull().sum() > 0:
            temp_df = X[self.available_cols_].copy()
            for col in self.available_cols_:
                if col != 'mileage':
                    temp_df[col] = temp_df[col].fillna(temp_df[col].median())         

            # Apply KNN imputation
            imputed = self.knn_imputer.transform(temp_df)
            mileage_idx = self.available_cols_.index('mileage')
            X['mileage'] = imputed[:, mileage_idx]

        return X

# %%
class ModelPredictorImputer(BaseEstimator, TransformerMixin):
    """
    Impute missing 'model' values using a classifier trained within each brand.
    Uses features like engineSize, mpg, transmission, fuelType to predict model.
    """

    def __init__(self, n_estimators=50):
        self.n_estimators = n_estimators
        self.brand_classifiers_ = {}
        self.brand_model_modes_ = {}
        self.feature_cols = ['transmission', 'fuelType', 'tax', 'mpg', 'engineSize', 'car_age']
        

    def fit(self, X, y=None):
        X = X.copy()
        for brand in X['brand'].dropna().unique():
            brand_data = X[X['brand'] == brand].copy()

            # Store mode as fallback
            if not brand_data['model'].mode().empty:
                self.brand_model_modes_[brand] = brand_data['model'].mode().iloc[0]           

            # Only train if we have enough complete cases
            complete_data = brand_data.dropna(subset=['model'] + self.feature_cols)
            if len(complete_data) >= 20 and complete_data['model'].nunique() > 1:
                X_train = complete_data[self.feature_cols]
                y_train = complete_data['model']

                clf = RandomForestClassifier(
                    n_estimators=self.n_estimators,
                    random_state=44,
                    n_jobs=-1
                )
                clf.fit(X_train, y_train)
                self.brand_classifiers_[brand] = clf
        
        return self

    

    def transform(self, X):
        X = X.copy()
        missing_model_idx = X[X['model'].isnull()].index     

        for idx in missing_model_idx:
            brand = X.loc[idx, 'brand']

            if brand in self.brand_classifiers_:
                features = X.loc[[idx], self.feature_cols]
                if not features.isnull().any().any():
                    predicted_model = self.brand_classifiers_[brand].predict(features)[0]
                    X.loc[idx, 'model'] = predicted_model
                    continue        

            # Fallback to brand mode
            if brand in self.brand_model_modes_:
                X.loc[idx, 'model'] = self.brand_model_modes_[brand]

        return X


class FrequencyEncoder(BaseEstimator, TransformerMixin):
    def __init__(self, col='model'):
        self.col = col
        self.freq_map = {}

    def fit(self, X, y=None):
        self.freq_map = X[self.col].value_counts(normalize=True).to_dict()
        return self

    def transform(self, X):
        X_copy = X.copy()
        X_copy[self.col] = X_copy[self.col].map(self.freq_map).fillna(0)
        return X_copy

# %% [markdown]
# # Rever texto abaixo!!!!

# %% [markdown]
# ### Scalling Logic

# %% [markdown]
# - **Why scale:** Linear/regularized models are scale-sensitive. Numeric features can have very different ranges (ex: mileage vs engine size), which biases coefficients.
#
# - **Choice:** **StandardScaler** for numeric columns (after imputation and outlier capping).
#
# - **StandardScaler over MinMaxScaler:** Standardization centers and normalizes variance—well-aligned with Ridge/Lasso penalties and keeps One-Hot Enconding interpretable. All scaling is fit on the training fold only within the pipeline to ensure that there are **no leakage**.

# %% [markdown]
# ### Imputation Logic

# %% [markdown]
# - **Car specifications columns**
#     - For these we consider the following columns: "brand", "model", "transmission", "fuelType", "tax", "mpg", "engineSize" and "car_age".
#     - Overall, we believe these columns can be imputated by the mode grouped by brand and model, as we expect the same car to have similar caractheristics, from the ones we checked on descriptive analisys we saw in most cases a clear mode for each categories even tought that may not be it in all cases.
#
# - **Car usage columns**
#     - For these we consider the following columns: "mileage" and "mileage_per_year"

# %% [markdown]
# ### Implementation

# %%
numeric_cols = X.select_dtypes(include=[np.number]).columns.tolist()
num_cols_whitout_mileage = numeric_cols.copy()
num_cols_whitout_mileage.remove("mileage")
categorical_cols = [c for c in X.columns if c not in numeric_cols]
without_model = [c for c in X.columns if c not in numeric_cols + ['model']]
without_model_brand = [c for c in X.columns if c not in ["model", "brand"]]
without_model_brand_mileage = [c for c in X.columns if c not in ["model", "brand", "mileage"]]
log_candidates = ['mpg', 'car_age', 'mileage', 'engineSize', 'tax']

# %%
numeric_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("log1p_skewed", Log1pSkewed(numeric_cols, log_candidates)),  
    ("scaler", StandardScaler())
])

# %%
cats = []
cats.append(("cat",
                 Pipeline([("fallback_impute", SimpleImputer(strategy="most_frequent")),
                           ("ohe", OneHotEncoder(handle_unknown="ignore", drop="first", sparse_output=False))]),
                without_model))
cats.append(("model_collap",
                 Pipeline([("fallback_impute", SimpleImputer(strategy="most_frequent")),
                           ("rare", RareLabelGrouper(min_prop=0.005, column="model")),
                           ("ohe", OneHotEncoder(handle_unknown="ignore", drop="first", sparse_output=False))]),
                  ["model"] ))

# %%
preprocessor = ColumnTransformer([("num", numeric_pipeline, numeric_cols), *cats])
pipe_preprocessor = Pipeline([("Imput_model_mode_grouped", Mode_Imput_By_Brand(imput_cols=["model"], group_col="brand")),
                              ("Imput_overal_mode_grouped_by_brand_and_model", Imput_By_Brand_and_Model(imput_cols = without_model_brand)),
                              ("Imput_overal_mode_grouped_by_brand", Imput_By_Brand_and_Model(imput_cols= without_model_brand, group_cols=["brand"])),
                              ('impute_mileage_knn', KNNMileageImputer(n_neighbors=5)),
                              ("column_transformer",preprocessor)])

# %%
pipe_preprocessor
# Out:
# Pipeline(steps=[('Imput_model_mode_grouped',
#                  Mode_Imput_By_Brand(imput_cols=['model'])),
#                 ('Imput_overal_mode_grouped_by_brand_and_model',
#                  Imput_By_Brand_and_Model(imput_cols=['transmission', 'mileage',
#                                                       'fuelType', 'tax', 'mpg',
#                                                       'engineSize',
#                                                       'car_age'])),
#                 ('Imput_overal_mode_grouped_by_brand',
#                  Imput_By_Brand_and_Model(group_cols=['brand'],
#                                           imput_cols=['transmi...
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['brand', 'transmission',
#                                                    'fuelType']),
#                                                  ('model_collap',
#                                                   Pipeline(steps=[('fallback_impute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('rare',
#                                                                    RareLabelGrouper(column='model')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['model'])]))])

# %%
pipe_preprocessor.fit(X)
n_total = pipe_preprocessor.transform(X).shape[1]
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(

# %%
# this indicates us the amount of features obtained to then uset it as max in the rfe
n_total
# Out:
# 64

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# In this section, we tested different ways of performing feature selection. First, we used a single data split (hold-out). We decided to keep this approach, as we believe it was correctly applied, although incomplete since it only has one method of feture selection (Recursive Feature Selection). But this still provided a minor insight to the next RFE applied in the cross-validation.
#
# As we became more comfortable using pipelines, we chose to apply cross-validation, which we consider a more reliable approach. The reasons for this choice are explained in the corresponding section.

# %% [markdown]
# ### Feature Selection using HoldOut

# %% [markdown]
# Following initial data preprocessing steps, which included the removal of several irrelevant columns , we employed Recursive Feature Elimination (RFE) to determine the optimal feature subset for our linear regression model.
#
# A holdout validation approach was utilized to evaluate model performance with varying numbers of features, using the Mean Absolute Error (MAE) as the primary evaluation metric.

# %%
#Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.2, random_state=44
)

# %%
grid = np.arange(1,n_total+1)

# %%
# Create variables to store the records for training and validation
records = []
best_model = None
high_score = None
n_feat = 0
selected_features = None

# %%
for n_sel in grid:
    model = LinearRegression()
    pipe = Pipeline([
        ("prep", preprocessor),
        ("rfe", RFE(estimator=model, n_features_to_select=n_sel)),
        ("linreg", LinearRegression()),
    ])
    
    pipe.fit(X_train, y_train) 

    # results of training dataset
    train_pred = pipe.predict(X_train)
    train_mae = mean_absolute_error(y_train, train_pred)

    # results of validation dataset
    val_pred = pipe.predict(X_val)
    val_mae = mean_absolute_error(y_val, val_pred)

    # append both records to then plot
    records.append({"n_selected": n_sel,
    "train_MAE": train_mae,
    "val_MAE": val_mae})

    if (high_score is None) or (val_mae < high_score):
        high_score = val_mae
        best_model = pipe
        n_feat = n_sel
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(

# %%
# Checking the scores for each iteration
records
# Out:
# [{'n_selected': np.int64(1),
#   'train_MAE': 6902.665965731731,
#   'val_MAE': 6958.430076895676},
#  {'n_selected': np.int64(2),
#   'train_MAE': 6831.9885600798725,
#   'val_MAE': 6885.627928657054},
#  {'n_selected': np.int64(3),
#   'train_MAE': 5641.068358634682,
#   'val_MAE': 5688.161133066128},
#  {'n_selected': np.int64(4),
#   'train_MAE': 3805.612118286989,
#   'val_MAE': 3847.0613524964792},
#  {'n_selected': np.int64(5),
#   'train_MAE': 3619.720847196629,
#   'val_MAE': 3645.207384345101},
#  {'n_selected': np.int64(6),
#   'train_MAE': 3586.185671363734,
#   'val_MAE': 3614.1222109358673},
#  {'n_selected': np.int64(7),
#   'train_MAE': 3559.0464325474913,
#   'val_MAE': 3593.8718841642803},
#  {'n_selected': np.int64(8),
#   'train_MAE': 3530.071337489417,
#   'val_MAE': 3570.3086981539336},
#  {'n_selected': np.int64(9),
#   'train_MAE': 3496.370777392196,
#   'val_MAE': 3534.42653809907},
#  {'n_selected': np.int64(10),
#   'train_MAE': 3489.380170628351,
#   'val_MAE': 3527.0351058736583},
#  {'n_selected': np.int64(11),
#   'train_MAE': 3410.0509144045,
#   'val_MAE': 3437.3276694046353},
#  {'n_selected': np.int64(12),
#   'train_MAE': 3347.2495460654545,
#   'val_MAE': 3375.4716652804636},
#  {'n_selected': np.int64(13),
#   'train_MAE': 3333.5689014122863,
#   'val_MAE': 3367.70539208469},
#  {'n_selected': np.int64(14),
#   'train_MAE': 3330.6356699149073,
#   'val_MAE': 3364.3072808421025},
#  {'n_selected': np.int64(15),
#   'train_MAE': 3330.7288099880698,
#   'val_MAE': 3365.7696225218583},
#  {'n_selected': np.int64(16),
#   'train_MAE': 3318.4935536405374,
#   'val_MAE': 3359.6706229464035},
#  {'n_selected': np.int64(17),
#   'train_MAE': 3319.772389674877,
#   'val_MAE': 3362.072365921427},
#  {'n_selected': np.int64(18),
#   'train_MAE': 3310.1063778265366,
#   'val_MAE': 3352.045866800854},
#  {'n_selected': np.int64(19),
#   'train_MAE': 3308.010900925661,
#   'val_MAE': 3350.8420959704627},
#  {'n_selected': np.int64(20),
#   'train_MAE': 3301.150752148523,
#   'val_MAE': 3343.807849646473},
#  {'n_selected': np.int64(21),
#   'train_MAE': 3293.2114881879324,
#   'val_MAE': 3335.014099397815},
#  {'n_selected': np.int64(22),
#   'train_MAE': 3288.454698112364,
#   'val_MAE': 3330.4044290610746},
#  {'n_selected': np.int64(23),
#   'train_MAE': 3283.847642558972,
#   'val_MAE': 3327.8263264183333},
#  {'n_selected': np.int64(24),
#   'train_MAE': 3275.155140794339,
#   'val_MAE': 3318.4774484701725},
#  {'n_selected': np.int64(25),
#   'train_MAE': 3274.395625256878,
#   'val_MAE': 3317.8180856274453},
#  {'n_selected': np.int64(26),
#   'train_MAE': 3271.313535306044,
#   'val_MAE': 3314.066840426743},
#  {'n_selected': np.int64(27),
#   'train_MAE': 3263.3408941337284,
#   'val_MAE': 3306.496557806742},
#  {'n_selected': np.int64(28),
#   'train_MAE': 3260.496155180683,
#   'val_MAE': 3302.1770059473374},
#  {'n_selected': np.int64(29),
#   'train_MAE': 3254.3568776080874,
#   'val_MAE': 3292.539878506251},
#  {'n_selected': np.int64(30),
#   'train_MAE': 3237.0779648226185,
#   'val_MAE': 3279.698017480506},
#  {'n_selected': np.int64(31),
#   'train_MAE': 3228.3513300551467,
#   'val_MAE': 3269.6663957137157},
#  {'n_selected': np.int64(32),
#   'train_MAE': 3223.8238723975405,
#   'val_MAE': 3262.0118983500693},
#  {'n_selected': np.int64(33),
#   'train_MAE': 3217.434221366971,
#   'val_MAE': 3254.9672326806703},
#  {'n_selected': np.int64(34),
#   'train_MAE': 3213.0347836227547,
#   'val_MAE': 3250.6548211983777},
#  {'n_selected': np.int64(35),
#   'train_MAE': 3212.9884379851205,
#   'val_MAE': 3247.2396148414946},
#  {'n_selected': np.int64(36),
#   'train_MAE': 3206.5905831538353,
#   'val_MAE': 3241.47220848448},
#  {'n_selected': np.int64(37),
#   'train_MAE': 3200.5667515458663,
#   'val_MAE': 3238.6053625753284},
#  {'n_selected': np.int64(38),
#   'train_MAE': 3189.071774765873,
#   'val_MAE': 3224.8072473507923},
#  {'n_selected': np.int64(39),
#   'train_MAE': 3083.7058788120485,
#   'val_MAE': 3132.960877488074},
#  {'n_selected': np.int64(40),
#   'train_MAE': 3076.2777250998715,
#   'val_MAE': 3119.426855484452},
#  {'n_selected': np.int64(41),
#   'train_MAE': 2978.9760383393923,
#   'val_MAE': 3029.877992605943},
#  {'n_selected': np.int64(42),
#   'train_MAE': 2974.898724100502,
#   'val_MAE': 3027.1869213902114},
#  {'n_selected': np.int64(43),
#   'train_MAE': 2954.2502342392436,
#   'val_MAE': 3002.650404544594},
#  {'n_selected': np.int64(44),
#   'train_MAE': 2956.6259928790796,
#   'val_MAE': 3002.2546448223006},
#  {'n_selected': np.int64(45),
#   'train_MAE': 2956.1732270652,
#   'val_MAE': 3003.5498402986827},
#  {'n_selected': np.int64(46),
#   'train_MAE': 2943.1929678450197,
#   'val_MAE': 2991.73265362587},
#  {'n_selected': np.int64(47),
#   'train_MAE': 2939.7589188463203,
#   'val_MAE': 2989.0728706607397},
#  {'n_selected': np.int64(48),
#   'train_MAE': 2936.6742518414317,
#   'val_MAE': 2984.302984885847},
#  {'n_selected': np.int64(49),
#   'train_MAE': 2934.055495016628,
#   'val_MAE': 2979.6240182278802},
#  {'n_selected': np.int64(50),
#   'train_MAE': 2932.08287947429,
#   'val_MAE': 2978.130595659757},
#  {'n_selected': np.int64(51),
#   'train_MAE': 2928.8874096475133,
#   'val_MAE': 2973.415957164796},
#  {'n_selected': np.int64(52),
#   'train_MAE': 2926.3757361447965,
#   'val_MAE': 2970.736878006847},
#  {'n_selected': np.int64(53),
#   'train_MAE': 2924.2153990208817,
#   'val_MAE': 2967.3121457667753},
#  {'n_selected': np.int64(54),
#   'train_MAE': 2862.3430205728037,
#   'val_MAE': 2887.1658719328434},
#  {'n_selected': np.int64(55),
#   'train_MAE': 2860.665124235096,
#   'val_MAE': 2885.271714501949},
#  {'n_selected': np.int64(56),
#   'train_MAE': 2859.246458307898,
#   'val_MAE': 2882.436489550806},
#  {'n_selected': np.int64(57),
#   'train_MAE': 2858.796445875662,
#   'val_MAE': 2883.3937029594267},
#  {'n_selected': np.int64(58),
#   'train_MAE': 2847.927846272644,
#   'val_MAE': 2871.4675792934713},
#  {'n_selected': np.int64(59),
#   'train_MAE': 2844.173712737711,
#   'val_MAE': 2866.390866256458},
#  {'n_selected': np.int64(60),
#   'train_MAE': 2844.197558715968,
#   'val_MAE': 2866.391596208544},
#  {'n_selected': np.int64(61),
#   'train_MAE': 2843.819619179909,
#   'val_MAE': 2865.905442446413},
#  {'n_selected': np.int64(62),
#   'train_MAE': 2829.4596956763244,
#   'val_MAE': 2853.1639503556203},
#  {'n_selected': np.int64(63),
#   'train_MAE': 2829.42009455571,
#   'val_MAE': 2853.174426478325},
#  {'n_selected': np.int64(64),
#   'train_MAE': 2829.416162390315,
#   'val_MAE': 2853.172779428624}]

# %%
# extract to list to then plot
train_score_list = [record["train_MAE"] for record in records]
val_score_list = [record["val_MAE"] for record in records]

len(val_score_list)
# Out:
# 65

# %%
plt.plot(list(range(1,66)), train_score_list, label="Score on Training Set", color='yellowgreen')
plt.plot(list(range(1,66)), val_score_list, label="Score on Validation Set", color='dimgray')
plt.xlabel("Number of features")
plt.ylabel("Score")
plt.legend()
plt.show()

print("Lowest score of MAE is with number of features: %d" %n_feat)
print("Score with %d features: %f" % (n_feat, high_score))
# Out:
# Lowest score of MAE is with number of features: 62
# Score with 62 features: 2853.163950

# %% [markdown]
# - Altough the lowest score is with 62 features, we can say that using the Linear Regression with the RFE, the model reaches his plateu at 57 features.
# - The model does not seem to be overfitting neither underfitting, since  the difference on training and validation score is very low.
# - The MAE got lower as we increased the number of features, however the error is still high with 2.8k, wich may indicate that the relathionship between X and Y is not that linear.

# %% [markdown]
# ### Feature Selection using KFold Cross-Validation

# %% [markdown]
# - We will perform feature selection using the CV method, as we believe it´s overal a better way of doing it, since the metrics of each method will not only be based on one segmentation of the data, rather 10 different ones (number of folds), which reduces the risk of selecting features that perform well only on one particular data segmentation.
# - We will implement several methods and in the end chose the features that most of them indicated to keep.
# - Even tought each model implementation had it's own feature selection (to better select the best features specific for each one), the main goal of this feature selection is to select a subset of features and then use them to compare differente models, under the same preprocessing and feature selection.

# %% [markdown]
# #### Recursive Feature Elimination (RFE)

# %% [markdown]
# - We apply an RFE using Linear Regression as an estimator, this is a wrapper method that starts with all available features and eliminates the "least important" wich in our case will be the feature with the smallest absolute regression coefficient until it reaches the number of features that we previously estabilshed.
# - Based on the hold out performed previously, even tought the final decisions will not be made according to those results, we can say that the performance really decreased as the number of features goes down, because of this we will set the minimum number of features to be 45 and the maximium to be all features (67), if the results indicate that we should try a lower number of features (this means the MAE is not decreasing) we will perform it again.

# %%
# %%time

pipeline = Pipeline([
    ('prep', pipe_preprocessor),                    
    ('rfe',  RFE(estimator=LinearRegression())),  
    ('model', LinearRegression())
])


param_grid = {
    'rfe__n_features_to_select': list(range(45,68))
    
}

grid = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    scoring='neg_mean_absolute_error',
    cv=10,
    n_jobs=-1,
    return_train_score = True,
    verbose=1
)

grid.fit(X, y)

print("Best number of features:", grid.best_params_['rfe__n_features_to_select'])
print("Best MAE:", -grid.best_score_)
# Out:
# Fitting 10 folds for each of 23 candidates, totalling 230 fits
# Best number of features: 66
# Best MAE: 2805.048389031385
# Wall time: 25min 6s

# %%
pd.DataFrame(grid.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       67.851721      2.278809         0.963828        0.327670
# 1       66.607696      2.462216         0.961720        0.419807
# 2       66.173630      2.015854         0.754219        0.179564
# 3       58.592630      4.288830         0.869152        0.439944
# 4       67.121333      2.664792         1.233293        0.595675
# 5       68.331188      1.958811         1.147001        0.261787
# 6       67.038159      4.041477         0.995774        0.292938
# 7       64.398943      2.883726         1.156567        0.360186
# 8       69.665683      4.395426         1.411286        0.550725
# 9       55.879254      5.734318         0.962858        0.258968
# 10      47.850188      2.091979         1.118773        0.669919
# 11      47.810230      3.243775         0.856864        0.313320
# 12      37.293779      1.831585         1.083471        0.305306
# 13      36.292537      1.371762         1.027720        0.541871
# 14      39.282318      2.924812         0.921617        0.435480
# 15      37.070624      3.920884         0.998299        0.707855
# 16      28.098254      3.937773         1.176709        0.737179
# 17      31.565943      2.724100         1.051251        0.327785
# 18      30.387557      1.122235         1.154860        0.572772
# 19      30.910000      4.156058         1.287544        0.920524
# 20      23.829641      2.266897         1.062886        0.362798
# 21      18.997103      2.593135         0.840677        0.246280
# 22      14.295128      2.394599         0.721804        0.251097
#
#    param_rfe__n_features_to_select                             params  \
# 0                               45  {'rfe__n_features_to_select': 45}
# 1                               46  {'rfe__n_features_to_select': 46}
# 2                               47  {'rfe__n_features_to_select': 47}
# 3                               48  {'rfe__n_features_to_select': 48}
# 4                               49  {'rfe__n_features_to_select': 49}
# 5                               50  {'rfe__n_features_to_select': 50}
# 6                               51  {'rfe__n_features_to_select': 51}
# 7                               52  {'rfe__n_features_to_select': 52}
# 8                               53  {'rfe__n_features_to_select': 53}
# 9                               54  {'rfe__n_features_to_select': 54}
# 10                              55  {'rfe__n_features_to_select': 55}
# 11                              56  {'rfe__n_features_to_select': 56}
# 12                              57  {'rfe__n_features_to_select': 57}
# 13                              58  {'rfe__n_features_to_select': 58}
# 14                              59  {'rfe__n_features_to_select': 59}
# 15                              60  {'rfe__n_features_to_select': 60}
# 16                              61  {'rfe__n_features_to_select': 61}
# 17                              62  {'rfe__n_features_to_select': 62}
# 18                              63  {'rfe__n_features_to_select': 63}
# 19                              64  {'rfe__n_features_to_select': 64}
# 20                              65  {'rfe__n_features_to_select': 65}
# 21                              66  {'rfe__n_features_to_select': 66}
# 22                              67  {'rfe__n_features_to_select': 67}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0        -2933.619891       -2988.227115       -3009.760573
# 1        -2937.966479       -2893.046057       -2917.202509
# 2        -2937.396772       -2893.051356       -2911.681252
# 3        -2935.169188       -2884.809268       -2905.668916
# 4        -2917.941326       -2880.574260       -2903.032550
# 5        -2915.116233       -2878.939494       -2900.339933
# 6        -2910.682141       -2875.525269       -2896.222214
# 7        -2908.337686       -2872.849801       -2896.231539
# 8        -2904.437202       -2864.226110       -2897.154631
# 9        -2896.926132       -2861.309248       -2895.630240
# 10       -2894.231424       -2859.644695       -2893.982998
# 11       -2891.675098       -2857.628141       -2893.378104
# 12       -2889.187520       -2855.524149       -2887.194641
# 13       -2857.050326       -2853.904674       -2824.329471
# 14       -2855.429364       -2810.603479       -2821.659472
# 15       -2854.717093       -2811.114335       -2821.988382
# 16       -2850.126135       -2806.568126       -2820.830548
# 17       -2850.005030       -2806.234916       -2820.746730
# 18       -2849.589640       -2806.149936       -2820.311879
# 19       -2849.590506       -2795.218941       -2803.655275
# 20       -2845.871747       -2794.979540       -2803.423797
# 21       -2845.963273       -2794.988611       -2803.901127
# 22       -2845.881978       -2794.737329       -2804.026197
#
#     split3_test_score  split4_test_score  split5_test_score  \
# 0        -2909.932180       -3010.196639       -2967.445331
# 1        -2909.941898       -2923.931967       -2952.869002
# 2        -2905.254691       -2920.269419       -2868.591979
# 3        -2902.136607       -2914.835977       -2868.615273
# 4        -2898.231334       -2912.408315       -2859.793266
# 5        -2892.861280       -2910.087939       -2855.744258
# 6        -2892.079455       -2906.667539       -2852.079976
# 7        -2888.373332       -2904.159748       -2847.997960
# 8        -2886.419827       -2901.980021       -2842.809795
# 9        -2884.978661       -2901.277890       -2839.161015
# 10       -2885.313729       -2901.010005       -2837.552942
# 11       -2870.195013       -2885.382696       -2834.430461
# 12       -2821.056811       -2851.014971       -2832.685363
# 13       -2819.887917       -2849.473544       -2814.793559
# 14       -2819.775655       -2849.512042       -2781.287368
# 15       -2817.110586       -2849.285784       -2780.191201
# 16       -2817.104437       -2849.184805       -2779.457382
# 17       -2816.932086       -2848.907581       -2772.695504
# 18       -2816.854619       -2848.501443       -2772.342624
# 19       -2798.926267       -2835.635641       -2772.601235
# 20       -2799.382727       -2835.633062       -2772.652998
# 21       -2799.950307       -2835.717470       -2751.341536
# 22       -2800.077503       -2835.836040       -2751.440673
#
#     split6_test_score  split7_test_score  split8_test_score  \
# 0        -3113.634699       -2904.753342       -2924.166957
# 1        -3111.540323       -2902.486815       -2924.188600
# 2        -3091.229702       -2882.996285       -2919.926766
# 3        -3010.460129       -2883.002181       -2911.472438
# 4        -3005.422240       -2878.982853       -2909.072966
# 5        -3002.030157       -2876.608102       -2903.181038
# 6        -2997.592383       -2872.696639       -2898.141771
# 7        -2994.734083       -2868.267505       -2893.735768
# 8        -2990.327824       -2865.242817       -2892.481839
# 9        -2987.753733       -2864.917750       -2892.318493
# 10       -2984.251996       -2863.384657       -2890.642062
# 11       -2984.434769       -2861.385589       -2887.763053
# 12       -2982.886831       -2858.335868       -2870.354548
# 13       -2970.704362       -2835.638926       -2828.034344
# 14       -2933.793176       -2837.267950       -2822.063227
# 15       -2931.650625       -2789.574695       -2821.167225
# 16       -2931.160603       -2781.759466       -2821.515093
# 17       -2924.456887       -2781.562873       -2821.300706
# 18       -2924.301650       -2772.864678       -2821.163884
# 19       -2923.817061       -2773.000845       -2800.892407
# 20       -2923.772172       -2772.692669       -2801.189781
# 21       -2896.541032       -2772.901625       -2800.765486
# 22       -2896.632615       -2772.949183       -2800.597990
#
#     split9_test_score  mean_test_score  std_test_score  rank_test_score  \
# 0        -2941.136790     -2970.287352       60.239574               23
# 1        -2858.601014     -2933.177467       64.264658               22
# 2        -2858.623334     -2918.902156       61.969584               21
# 3        -2850.343403     -2906.651338       41.659089               20
# 4        -2847.697380     -2901.315649       41.034456               19
# 5        -2844.580372     -2897.948881       40.963614               18
# 6        -2842.090482     -2894.377787       40.548158               17
# 7        -2838.516378     -2891.320380       40.896409               16
# 8        -2835.638092     -2888.071816       41.121718               15
# 9        -2833.771809     -2885.804497       41.006964               14
# 10       -2833.538819     -2884.355333       40.386333               13
# 11       -2830.716838     -2879.698976       40.937491               12
# 12       -2813.481077     -2866.172178       45.770183               11
# 13       -2770.311704     -2842.412883       48.890993               10
# 14       -2769.255388     -2830.064712       43.045702                9
# 15       -2769.009214     -2824.580914       44.183784                8
# 16       -2766.460452     -2822.416705       44.968792                7
# 17       -2766.123482     -2820.896579       44.111336                6
# 18       -2765.758496     -2819.783885       44.949439                5
# 19       -2765.672203     -2811.901038       45.099499                4
# 20       -2748.234846     -2809.783334       46.848960                3
# 21       -2748.413423     -2805.048389       42.729069                1
# 22       -2748.305914     -2805.048542       42.753556                2
#
#     split0_train_score  split1_train_score  split2_train_score  \
# 0         -2913.523165        -2998.241860        -3002.542833
# 1         -2916.202174        -2907.838527        -2911.736424
# 2         -2914.348187        -2907.911695        -2904.943068
# 3         -2910.302717        -2901.475199        -2901.223662
# 4         -2894.841018        -2897.536144        -2898.274755
# 5         -2891.720223        -2894.471763        -2894.350813
# 6         -2887.892129        -2890.513308        -2890.907743
# 7         -2884.277786        -2886.862519        -2890.968125
# 8         -2881.298324        -2871.974231        -2887.394429
# 9         -2867.570004        -2870.411569        -2885.396416
# 10        -2865.923372        -2868.686967        -2883.958815
# 11        -2864.151948        -2866.818854        -2882.247726
# 12        -2862.081094        -2864.717680        -2867.474169
# 13        -2817.788935        -2863.110170        -2827.231797
# 14        -2816.356306        -2819.864294        -2826.177271
# 15        -2816.293132        -2819.709978        -2826.071528
# 16        -2812.090943        -2815.311740        -2821.505730
# 17        -2812.020505        -2814.987520        -2821.437842
# 18        -2811.871475        -2814.899364        -2821.227016
# 19        -2811.804281        -2798.843563        -2805.834265
# 20        -2795.412599        -2798.832609        -2805.684311
# 21        -2795.381554        -2798.861429        -2805.589337
# 22        -2795.353735        -2798.841949        -2805.566454
#
#     split3_train_score  split4_train_score  split5_train_score  \
# 0         -2909.388448        -2997.674203        -3026.478162
# 1         -2909.462942        -2905.678495        -3008.649848
# 2         -2902.417645        -2898.660036        -2917.674788
# 3         -2898.128736        -2894.414698        -2917.748737
# 4         -2895.151255        -2890.841421        -2911.425673
# 5         -2891.611921        -2886.745784        -2907.506808
# 6         -2887.769263        -2883.165574        -2904.002559
# 7         -2884.719543        -2880.142143        -2900.838652
# 8         -2882.879077        -2878.348564        -2897.655080
# 9         -2881.385940        -2876.671087        -2894.634223
# 10        -2879.542195        -2874.861483        -2892.720241
# 11        -2865.466374        -2860.630001        -2891.583794
# 12        -2824.096804        -2817.166964        -2889.923771
# 13        -2822.580694        -2815.739622        -2876.607064
# 14        -2822.430036        -2815.683195        -2833.102127
# 15        -2817.846167        -2811.202776        -2831.464277
# 16        -2817.787525        -2810.610543        -2830.883952
# 17        -2817.588379        -2810.585882        -2826.816757
# 18        -2817.540162        -2810.366846        -2826.150345
# 19        -2802.431482        -2794.990417        -2826.477769
# 20        -2802.482879        -2794.917186        -2826.379681
# 21        -2802.432928        -2794.898503        -2810.962372
# 22        -2802.395242        -2794.847418        -2811.153567
#
#     split6_train_score  split7_train_score  split8_train_score  \
# 0         -3012.172110        -2919.477200        -2903.637497
# 1         -3012.103401        -2917.779852        -2903.714630
# 2         -2994.672010        -2902.838933        -2899.754009
# 3         -2902.971423        -2902.912581        -2892.940213
# 4         -2896.216135        -2899.308716        -2889.635374
# 5         -2892.335396        -2895.618396        -2886.138224
# 6         -2888.949677        -2892.856181        -2882.784063
# 7         -2886.008707        -2889.404859        -2879.903199
# 8         -2882.586072        -2886.217127        -2877.914577
# 9         -2879.440440        -2884.179060        -2875.987047
# 10        -2877.712481        -2882.483956        -2874.381532
# 11        -2875.948674        -2880.999675        -2872.713616
# 12        -2874.255838        -2879.273857        -2859.570631
# 13        -2860.534949        -2866.050364        -2817.086431
# 14        -2816.559115        -2865.771044        -2813.003085
# 15        -2815.235063        -2822.528954        -2812.861496
# 16        -2815.130387        -2818.483088        -2812.767135
# 17        -2811.063032        -2818.325579        -2812.449703
# 18        -2810.567044        -2801.581595        -2812.331865
# 19        -2810.348860        -2801.427973        -2797.647936
# 20        -2810.267856        -2801.405719        -2797.683270
# 21        -2793.956862        -2801.431689        -2797.678263
# 22        -2794.009719        -2801.341403        -2797.663813
#
#     split9_train_score  mean_train_score  std_train_score
# 0         -3016.629851      -2969.976533        48.564427
# 1         -2924.690027      -2931.785632        39.738780
# 2         -2924.774570      -2916.799494        27.157682
# 3         -2918.429762      -2904.054773         8.378137
# 4         -2914.577618      -2898.780811         7.703647
# 5         -2911.322189      -2895.182152         7.743284
# 6         -2907.237190      -2891.607769         7.654346
# 7         -2903.719088      -2888.684462         7.584186
# 8         -2900.620268      -2884.688775         8.357829
# 9         -2898.843438      -2881.451922         9.330610
# 10        -2897.209345      -2879.748039         9.320534
# 11        -2895.606781      -2875.616744        11.280556
# 12        -2881.483416      -2862.004423        22.578410
# 13        -2840.839821      -2840.756985        22.456237
# 14        -2839.413553      -2826.836003        15.208619
# 15        -2839.370692      -2821.258406         8.388054
# 16        -2835.405146      -2818.997619         7.771209
# 17        -2835.055379      -2818.033058         7.479507
# 18        -2834.858018      -2816.139373         8.882596
# 19        -2834.773575      -2808.458012        12.309709
# 20        -2818.705575      -2805.177168         9.885573
# 21        -2818.737316      -2801.993025         7.492065
# 22        -2818.685115      -2801.985841         7.506271

# %%
# obtaining all results to plot
results = grid.cv_results_

train_score_list = -results['mean_train_score']
val_score_list   = -results['mean_test_score']

n_features = param_grid['rfe__n_features_to_select']

# %%
plt.plot(list(range(45,68)), train_score_list, label="MAE on Training Set", color='yellowgreen')
plt.plot(list(range(45,68)), val_score_list, label="MAE on Validation Set", color='dimgray')
plt.xlabel("Number of Features")
plt.ylabel("MAE")
plt.legend()
plt.show()

# %% [markdown]
# - As expected, the ideal number of features is around the maximum number of features.
# - The scores got worst than in the hold out meaning probably it got a partition (the holdout)  that really favored our model.
# - The difference between training and validation keeps being minimal, wich means no overfitting.

# %%
pipe_66 = Pipeline([
    ('prep', pipe_preprocessor),
    ('rfe', RFE(estimator=LinearRegression(), n_features_to_select=66)),
    ('model', LinearRegression())
]).fit(X, y)

feature_names = pipe_66.named_steps["prep"].named_steps["column_transformer"].get_feature_names_out() # array with feauture names
mask = pipe_66.named_steps["rfe"].support_  # bol array saying if each feature was kept [true,true, false, etc]

removed_66 = feature_names[~mask]

# %%
removed_66
# Out:
# array(['num__paintQuality%', 'num__previousOwners'], dtype=object)

# %% [markdown]
# - In the cross-validation the maximum number of features achivied was 66 and not 67 like in the hold-out split.
# - The discrepancy in the number of features is a consequence from data partitioning effects. An additional dummy variable was created in the hold-out split due to category frequency thresholds being met, but not within the cross-validation folds. The selection of features will be made exclusively based on the methods that are included in the cross-validation, so this dummy variable is disregarded.

# %%
pipe_65 = Pipeline([
    ('prep', pipe_preprocessor),
    ('rfe', RFE(estimator=LinearRegression(), n_features_to_select=65)),
    ('model', LinearRegression())
]).fit(X, y)

feature_names = pipe_65.named_steps["prep"].named_steps["column_transformer"].get_feature_names_out()
mask = pipe_65.named_steps["rfe"].support_

removed_65 = feature_names[~mask]

# %%
removed_65
# Out:
# array(['num__paintQuality%', 'num__previousOwners',
#        'model_collap__model_2 series'], dtype=object)

# %% [markdown]
# - Based on the cross-validation results we should be using either 65 or 66 features (all).
# - The inclusion of the feature that was removed when selecting 65 features ("model_collap__model_2 series") will be further assess based on the other selection methods.

# %% [markdown]
# #### Decision Tree

# %%
dt_pipe_mse = Pipeline([
    ("prep", pipe_preprocessor),
    ("dt", DecisionTreeRegressor(random_state=42))
])

# this is a dict containing several keys one of which is estimator
cv_out_mse = cross_validate(
    dt_pipe_mse,
    X, y,
    cv=10,
    return_estimator=True,
    n_jobs=-1
)

# %%
# doing the same for mae
dt_pipe_mae = Pipeline([
    ("prep", pipe_preprocessor),
    ("dt", DecisionTreeRegressor(criterion='absolute_error', random_state=42))
])

cv_out_mae = cross_validate(
    dt_pipe_mae,
    X, y,
    cv=10,
    return_estimator=True,
    n_jobs=-1
)

# %%
series_list_mse = []
# estimator is the pipeline trained in each fold (in total 10 estimators)
for est in cv_out_mse["estimator"]:
    feat_names = est.named_steps["prep"].named_steps["column_transformer"].get_feature_names_out() # from the column transformer get the names for all features
    importance_vector = est.named_steps["dt"].feature_importances_ # from the dt get vector containing each feature importance
    series_list_mse.append(pd.Series(importance_vector, index=feat_names)) # create a series with the names from feat_names and importance from importance vector

series_list_mae = []
for est in cv_out_mae["estimator"]:
    feat_names = est.named_steps["prep"].named_steps["column_transformer"].get_feature_names_out()
    importance_vector = est.named_steps["dt"].feature_importances_
    series_list_mae.append(pd.Series(importance_vector, index=feat_names))

series_list_mae
# Out:
# [num__carID                    0.065522
#  num__mileage                  0.092952
#  num__tax                      0.016353
#  num__mpg                      0.077160
#  num__engineSize               0.170241
#                                  ...
#  model_collap__model_tucson    0.001285
#  model_collap__model_up!       0.001269
#  model_collap__model_x1        0.000555
#  model_collap__model_yaris     0.004112
#  model_collap__model_zafira    0.000105
#  Length: 68, dtype: float64,
#  num__carID                    0.066533
#  num__mileage                  0.094295
#  num__tax                      0.017485
#  num__mpg                      0.075267
#  num__engineSize               0.169494
#                                  ...
#  model_collap__model_tucson    0.001588
#  model_collap__model_up!       0.001215
#  model_collap__model_x1        0.000587
#  model_collap__model_yaris     0.004434
#  model_collap__model_zafira    0.000080
#  Length: 68, dtype: float64,
#  num__carID                    0.067463
#  num__mileage                  0.093876
#  num__tax                      0.016736
#  num__mpg                      0.077103
#  num__engineSize               0.169647
#                                  ...
#  model_collap__model_tucson    0.001909
#  model_collap__model_up!       0.001353
#  model_collap__model_x1        0.000652
#  model_collap__model_yaris     0.004361
#  model_collap__model_zafira    0.000159
#  Length: 68, dtype: float64,
#  num__carID                    0.062598
#  num__mileage                  0.092942
#  num__tax                      0.015479
#  num__mpg                      0.075107
#  num__engineSize               0.171586
#                                  ...
#  model_collap__model_tucson    0.001466
#  model_collap__model_up!       0.001273
#  model_collap__model_x1        0.000620
#  model_collap__model_yaris     0.005146
#  model_collap__model_zafira    0.000107
#  Length: 67, dtype: float64,
#  num__carID                    0.063360
#  num__mileage                  0.093324
#  num__tax                      0.017079
#  num__mpg                      0.074282
#  num__engineSize               0.168637
#                                  ...
#  model_collap__model_tucson    0.001492
#  model_collap__model_up!       0.001288
#  model_collap__model_x1        0.000539
#  model_collap__model_yaris     0.004271
#  model_collap__model_zafira    0.000159
#  Length: 67, dtype: float64,
#  num__carID                    0.065079
#  num__mileage                  0.099694
#  num__tax                      0.018196
#  num__mpg                      0.074160
#  num__engineSize               0.167891
#                                  ...
#  model_collap__model_tucson    0.001464
#  model_collap__model_up!       0.001894
#  model_collap__model_x1        0.000615
#  model_collap__model_yaris     0.003977
#  model_collap__model_zafira    0.000192
#  Length: 69, dtype: float64,
#  num__carID                    0.067146
#  num__mileage                  0.093184
#  num__tax                      0.016406
#  num__mpg                      0.076395
#  num__engineSize               0.170279
#                                  ...
#  model_collap__model_tucson    0.001452
#  model_collap__model_up!       0.001241
#  model_collap__model_x1        0.000664
#  model_collap__model_yaris     0.004750
#  model_collap__model_zafira    0.000164
#  Length: 69, dtype: float64,
#  num__carID                    0.068143
#  num__mileage                  0.093215
#  num__tax                      0.016814
#  num__mpg                      0.077539
#  num__engineSize               0.167979
#                                  ...
#  model_collap__model_tucson    0.001344
#  model_collap__model_up!       0.001274
#  model_collap__model_x1        0.000648
#  model_collap__model_yaris     0.004548
#  model_collap__model_zafira    0.000127
#  Length: 68, dtype: float64,
#  num__carID                    0.064738
#  num__mileage                  0.094893
#  num__tax                      0.016956
#  num__mpg                      0.077573
#  num__engineSize               0.168995
#                                  ...
#  model_collap__model_tucson    0.001468
#  model_collap__model_up!       0.001326
#  model_collap__model_x1        0.000606
#  model_collap__model_yaris     0.004667
#  model_collap__model_zafira    0.000145
#  Length: 67, dtype: float64,
#  num__carID                    0.063464
#  num__mileage                  0.097801
#  num__tax                      0.016936
#  num__mpg                      0.077896
#  num__engineSize               0.168062
#                                  ...
#  model_collap__model_tucson    0.001591
#  model_collap__model_up!       0.001951
#  model_collap__model_x1        0.000661
#  model_collap__model_yaris     0.004800
#  model_collap__model_zafira    0.000092
#  Length: 68, dtype: float64]

# %%
# transform to dataframe, each series becomes a column
feature_importance_mse = pd.concat(series_list_mse, axis=1)
feature_importance_mse.columns = [f"fold_{i+1}" for i in range(10)]

feature_importance_mae = pd.concat(series_list_mae, axis=1)
feature_importance_mae.columns = [f"fold_{i+1}" for i in range(10)]

feature_importance_mae
# Out:
#                               fold_1    fold_2    fold_3    fold_4    fold_5  \
# num__carID                  0.065522  0.066533  0.067463  0.062598  0.063360
# num__mileage                0.092952  0.094295  0.093876  0.092942  0.093324
# num__tax                    0.016353  0.017485  0.016736  0.015479  0.017079
# num__mpg                    0.077160  0.075267  0.077103  0.075107  0.074282
# num__engineSize             0.170241  0.169494  0.169647  0.171586  0.168637
# ...                              ...       ...       ...       ...       ...
# model_collap__model_up!     0.001269  0.001215  0.001353  0.001273  0.001288
# model_collap__model_x1      0.000555  0.000587  0.000652  0.000620  0.000539
# model_collap__model_yaris   0.004112  0.004434  0.004361  0.005146  0.004271
# model_collap__model_zafira  0.000105  0.000080  0.000159  0.000107  0.000159
# model_collap__model_i30          NaN       NaN       NaN       NaN       NaN
#
#                               fold_6    fold_7    fold_8    fold_9   fold_10
# num__carID                  0.065079  0.067146  0.068143  0.064738  0.063464
# num__mileage                0.099694  0.093184  0.093215  0.094893  0.097801
# num__tax                    0.018196  0.016406  0.016814  0.016956  0.016936
# num__mpg                    0.074160  0.076395  0.077539  0.077573  0.077896
# num__engineSize             0.167891  0.170279  0.167979  0.168995  0.168062
# ...                              ...       ...       ...       ...       ...
# model_collap__model_up!     0.001894  0.001241  0.001274  0.001326  0.001951
# model_collap__model_x1      0.000615  0.000664  0.000648  0.000606  0.000661
# model_collap__model_yaris   0.003977  0.004750  0.004548  0.004667  0.004800
# model_collap__model_zafira  0.000192  0.000164  0.000127  0.000145  0.000092
# model_collap__model_i30     0.000290  0.000225       NaN       NaN  0.000293
#
# [69 rows x 10 columns]

# %%
# create df with just mean for each feature importance
mse_summary = pd.DataFrame({
    "Feature": feature_importance_mse.index,
    "mean_importance": feature_importance_mse.mean(axis=1, skipna=True)})

mae_summary = pd.DataFrame({
    "Feature": feature_importance_mae.index,
    "mean_importance": feature_importance_mae.mean(axis=1, skipna=True)})

importance_comparison = mse_summary.merge(
    mae_summary,
    on="Feature",
    suffixes=("_MSE", "_MAE")
)

importance_comparison
# Out:
#                        Feature  mean_importance_MSE  mean_importance_MAE
# 0                   num__carID             0.027886             0.065405
# 1                 num__mileage             0.052770             0.094618
# 2                     num__tax             0.009412             0.016844
# 3                     num__mpg             0.054211             0.076248
# 4              num__engineSize             0.246596             0.169281
# ..                         ...                  ...                  ...
# 64     model_collap__model_up!             0.000659             0.001408
# 65      model_collap__model_x1             0.000179             0.000615
# 66   model_collap__model_yaris             0.002013             0.004507
# 67  model_collap__model_zafira             0.000026             0.000133
# 68     model_collap__model_i30             0.000071             0.000269
#
# [69 rows x 3 columns]

# %%
importance_melted = importance_comparison.melt(
    id_vars='Feature',
    value_vars=['mean_importance_MSE', 'mean_importance_MAE'],
    var_name='Criterion',
    value_name='Importance'
)

avg_order = importance_melted.groupby('Feature')['Importance'].mean().sort_values()

plt.figure(figsize=(12, 8))
sns.barplot(
    data=importance_melted,
    y='Feature',
    x='Importance',
    hue='Criterion',
    order=avg_order.index
)
plt.title('Feature importance comparison (MSE vs MAE)')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.tight_layout()
plt.show()

# %% [markdown]
# - Although the graph is not the most readable (because there is too many features) , we can see that most of the dummy variables representing the car model column, don't contribute much for the performance model's in either MSE or MAE.
# - However we feel like this is a "trap" in the sense that these results will probably hapen everytime we have a lot of dummie variables, in the sense that it's normal that the value of the column model is diluted in several smaller ones and in each one the value is not that big.
# - We will still define a very conservative treshold, every feature wich does not achieve 0.005 in either MSE or MAE will be flagged.
# - The goal is to reduce the dimensionality, but keeping in mind that we are not really sure about the contribution of these columns. Results from other feature selection methods will be crucial in deciding whether to keep the features identified here.

# %%
flagged_features = importance_comparison[
    (importance_comparison["mean_importance_MSE"] < 0.0005) |
    (importance_comparison["mean_importance_MAE"] < 0.0005)
]

# %%
flagged_features
# Out:
#                             Feature  mean_importance_MSE  mean_importance_MAE
# 10               cat__brand_hyundai         4.661618e-04         1.436461e-03
# 18           cat__fuelType_electric         6.855110e-09         9.594771e-08
# 22     model_collap__model_3 series         3.277519e-04         9.384200e-04
# 23     model_collap__model_4 series         1.825469e-04         5.899210e-04
# 27           model_collap__model_a1         2.867043e-04         6.845830e-04
# 29           model_collap__model_a4         3.003900e-04         7.280720e-04
# 30           model_collap__model_a5         1.220029e-04         5.118796e-04
# 31           model_collap__model_a6         2.362150e-04         8.270100e-04
# 32        model_collap__model_astra         1.555703e-04         7.035983e-04
# 33        model_collap__model_auris         2.544323e-05         1.939055e-04
# 34         model_collap__model_aygo         2.234701e-04         1.412930e-03
# 35      model_collap__model_b class         2.582320e-04         8.471997e-04
# 37        model_collap__model_c max         7.923060e-05         3.317484e-04
# 39  model_collap__model_crossland x         6.552111e-05         2.768150e-04
# 41     model_collap__model_ecosport         5.118317e-05         3.152996e-04
# 42        model_collap__model_fabia         6.635990e-05         6.303242e-04
# 45    model_collap__model_gla class         2.300771e-04         5.145948e-04
# 47         model_collap__model_golf         3.628752e-04         2.648719e-03
# 50     model_collap__model_insignia         4.909008e-05         2.004209e-04
# 52        model_collap__model_mokka         2.678098e-05         1.969342e-04
# 53      model_collap__model_mokka x         5.982371e-05         3.364394e-04
# 55       model_collap__model_passat         1.423634e-04         5.650441e-04
# 57           model_collap__model_q2         2.100004e-04         5.999153e-04
# 60       model_collap__model_superb         1.590094e-04         5.196148e-04
# 63       model_collap__model_tucson         3.238013e-04         1.505963e-03
# 65           model_collap__model_x1         1.786697e-04         6.148851e-04
# 67       model_collap__model_zafira         2.609265e-05         1.329750e-04
# 68          model_collap__model_i30         7.115946e-05         2.692561e-04

# %% [markdown]
# #### Lasso Regression

# %% [markdown]
# Given our problem of having many dummy variables for the car model, we chose Lasso (L1 regularization) as the last method of feature selection,  because it can set the coefficients of less important features to zero, as a form of penalization, helping to remove redundant features and reduce dimensionality.

# %%
lasso_pipe = Pipeline([
    ("prep", pipe_preprocessor),
    ("lasso", LassoCV())
])

cv_out_lasso = cross_validate(
    lasso_pipe,
    X, y,
    cv=10,
    return_estimator=True,
    n_jobs=-1
)

# %%
cv_out_lasso
# Out:
# {'fit_time': array([11.34178305, 11.47480536, 25.78051805, 25.55309582, 25.36553359,
#         25.0593667 , 25.32373881, 24.3696537 , 24.27768898, 25.82624602]),
#  'score_time': array([0.31131148, 0.22595167, 0.26221418, 0.33866239, 0.41348386,
#         0.54069519, 0.43429279, 0.97039771, 1.21816802, 0.35963464]),
#  'estimator': [Pipeline(steps=[('prep',
#                    Pipeline(steps=[('Imput_model_mode_grouped',
#                                     Mode_Imput_By_Brand(imput_cols=['model'])),
#                                    ('Imput_overal_mode_grouped_by_brand_and_model',
#                                     Imput_By_Brand_and_Model(imput_cols=['carID',
#                                                                          'transmission',
#                                                                          'mileage',
#                                                                          'fuelType',
#                                                                          'tax',
#                                                                          'mpg',
#                                                                          'engineSize',
#                                                                          'paintQuality%',
#                                                                          'previousOwners',
#                                                                          'car_age'])),
#                                    ('Imput_overal_mode_grouped_by_brand',
#                                     I...
#                                                                                       OneHotEncoder(drop='first',
#                                                                                                     handle_unknown='ignore',
#                                                                                                     sparse_output=False))]),
#                                                                      ['brand',
#                                                                       'transmission',
#                                                                       'fuelType']),
#                                                                     ('model_collap',
#                                                                      Pipeline(steps=[('fallback_impute',
#                                                                                       SimpleImputer(strategy='most_frequent')),
#                                                                                      ('rare',
#                                                                                       RareLabelGrouper(column='model')),
#                                                                                      ('ohe',
#                                                                                       OneHotEncoder(drop='first',
#                                                                                                     handle_unknown='ignore',
#                                                                                                     sparse_output=False))]),
#                                                                      ['model'])]))])),
#                   ('lasso', LassoCV())]),
#   Pipeline(steps=[('prep',
#                    Pipeline(steps=[('Imput_model_mode_grouped',
#                                     Mode_Imput_By_Brand(imput_cols=['model'])),
#                                    ('Imput_overal_mode_grouped_by_brand_and_model',
#                                     Imput_By_Brand_and_Model(imput_cols=['carID',
#                                                                          'transmission',
#                                                                          'mileage',
#                                                                          'fuelType',
#                                                                          'tax',
#                                                                          'mpg',
#                                                                          'engineSize',
#                                                                          'paintQuality%',
#                                                                          'previousOwners',
#                                                                          'car_age'])),
#                                    ('Imput_overal_mode_grouped_by_brand',
#                                     I...
#                                                                                       OneHotEncoder(drop='first',
#                                                                                                     handle_unknown='ignore',
#                                                                                                     sparse_output=False))]),
#                                                                      ['brand',
#                                                                       'transmission',
#                                                                       'fuelType']),
#                                                                     ('model_collap',
#                                                                      Pipeline(steps=[('fallback_impute',
#                                                                                       SimpleImputer(strategy='most_frequent')),
#                                                                                      ('rare',
#                                                                                       RareLabelGrouper(column='model')),
#                                                                                      ('ohe',
#                                                                                       OneHotEncoder(drop='first',
#                                                                                                     handle_unknown='ignore',
#                                                                                                     sparse_output=False))]),
#                                                                      ['model'])]))])),
#                   ('lasso', LassoCV())]),
#   Pipeline(steps=[('prep',
#                    Pipeline(steps=[('Imput_model_mode_grouped',
#                                     Mode_Imput_By_Brand(imput_cols=['model'])),
#                                    ('Imput_overal_mode_grouped_by_brand_and_model',
#                                     Imput_By_Brand_and_Model(imput_cols=['carID',
#                                                                          'transmission',
#                                                                          'mileage',
#                                                                          'fuelType',
#                                                                          'tax',
#                                                                          'mpg',
#                                                                          'engineSize',
#                                                                          'paintQuality%',
#                                                                          'previousOwners',
#                                                                          'car_age'])),
#                                    ('Imput_overal_mode_grouped_by_brand',
#                                     I...
#                                                                                       OneHotEncoder(drop='first',
#                                                                                                     handle_unknown='ignore',
#                                                                                                     sparse_output=False))]),
#                                                                      ['brand',
#                                                                       'transmission',
#                                                                       'fuelType']),
#                                                                     ('model_collap',
#                                                                      Pipeline(steps=[('fallback_impute',
#                                                                                       SimpleImputer(strategy='most_frequent')),
#                                                                                      ('rare',
#                                                                                       RareLabelGrouper(column='model')),
#                                                                                      ('ohe',
#                                                                                       OneHotEncoder(drop='first',
#                                                                                                     handle_unknown='ignore',
#                                                                                                     sparse_output=False))]),
#                                                                      ['model'])]))])),
#                   ('lasso', LassoCV())]),
#   Pipeline(steps=[('prep',
#                    Pipeline(steps=[('Imput_model_mode_grouped',
#                                     Mode_Imput_By_Brand(imput_cols=['model'])),
#                                    ('Imput_overal_mode_grouped_by_brand_and_model',
#                                     Imput_By_Brand_and_Model(imput_cols=['carID',
#                                                                          'transmission',
#                                                                          'mileage',
#                                                                          'fuelType',
#                                                                          'tax',
#                                                                          'mpg',
#                                                                          'engineSize',
#                                                                          'paintQuality%',
#                                                                          'previousOwners',
#                                                                          'car_age'])),
#                                    ('Imput_overal_mode_grouped_by_brand',
#                                     I...
#                                                                                       OneHotEncoder(drop='first',
#                                                                                                     handle_unknown='ignore',
#                                                                                                     sparse_output=False))]),
#                                                                      ['brand',
#                                                                       'transmission',
#                                                                       'fuelType']),
#                                                                     ('model_collap',
#                                                                      Pipeline(steps=[('fallback_impute',
#                                                                                       SimpleImputer(strategy='most_frequent')),
#                                                                                      ('rare',
#                                                                                       RareLabelGrouper(column='model')),
#                                                                                      ('ohe',
#                                                                                       OneHotEncoder(drop='first',
#                                                                                                     handle_unknown='ignore',
#                                                                                                     sparse_output=False))]),
#                                                                      ['model'])]))])),
#                   ('lasso', LassoCV())]),
#   Pipeline(steps=[('prep',
#                    Pipeline(steps=[('Imput_model_mode_grouped',
#                                     Mode_Imput_By_Brand(imput_cols=['model'])),
#                                    ('Imput_overal_mode_grouped_by_brand_and_model',
#                                     Imput_By_Brand_and_Model(imput_cols=['carID',
#                                                                          'transmission',
#                                                                          'mileage',
#                                                                          'fuelType',
#                                                                          'tax',
#                                                                          'mpg',
#                                                                          'engineSize',
#                                                                          'paintQuality%',
#                                                                          'previousOwners',
#                                                                          'car_age'])),
#                                    ('Imput_overal_mode_grouped_by_brand',
#                                     I...
#                                                                                       OneHotEncoder(drop='first',
#                                                                                                     handle_unknown='ignore',
#                                                                                                     sparse_output=False))]),
#                                                                      ['brand',
#                                                                       'transmission',
#                                                                       'fuelType']),
#                                                                     ('model_collap',
#                                                                      Pipeline(steps=[('fallback_impute',
#                                                                                       SimpleImputer(strategy='most_frequent')),
#                                                                                      ('rare',
#                                                                                       RareLabelGrouper(column='model')),
#                                                                                      ('ohe',
#                                                                                       OneHotEncoder(drop='first',
#                                                                                                     handle_unknown='ignore',
#                                                                                                     sparse_output=False))]),
#                                                                      ['model'])]))])),
#                   ('lasso', LassoCV())]),
#   Pipeline(steps=[('prep',
#                    Pipeline(steps=[('Imput_model_mode_grouped',
#                                     Mode_Imput_By_Brand(imput_cols=['model'])),
#                                    ('Imput_overal_mode_grouped_by_brand_and_model',
#                                     Imput_By_Brand_and_Model(imput_cols=['carID',
#                                                                          'transmission',
#                                                                          'mileage',
#                                                                          'fuelType',
#                                                                          'tax',
#                                                                          'mpg',
#                                                                          'engineSize',
#                                                                          'paintQuality%',
#                                                                          'previousOwners',
#                                                                          'car_age'])),
#                                    ('Imput_overal_mode_grouped_by_brand',
#                                     I...
#                                                                                       OneHotEncoder(drop='first',
#                                                                                                     handle_unknown='ignore',
#                                                                                                     sparse_output=False))]),
#                                                                      ['brand',
#                                                                       'transmission',
#                                                                       'fuelType']),
#                                                                     ('model_collap',
#                                                                      Pipeline(steps=[('fallback_impute',
#                                                                                       SimpleImputer(strategy='most_frequent')),
#                                                                                      ('rare',
#                                                                                       RareLabelGrouper(column='model')),
#                                                                                      ('ohe',
#                                                                                       OneHotEncoder(drop='first',
#                                                                                                     handle_unknown='ignore',
#                                                                                                     sparse_output=False))]),
#                                                                      ['model'])]))])),
#                   ('lasso', LassoCV())]),
#   Pipeline(steps=[('prep',
#                    Pipeline(steps=[('Imput_model_mode_grouped',
#                                     Mode_Imput_By_Brand(imput_cols=['model'])),
#                                    ('Imput_overal_mode_grouped_by_brand_and_model',
#                                     Imput_By_Brand_and_Model(imput_cols=['carID',
#                                                                          'transmission',
#                                                                          'mileage',
#                                                                          'fuelType',
#                                                                          'tax',
#                                                                          'mpg',
#                                                                          'engineSize',
#                                                                          'paintQuality%',
#                                                                          'previousOwners',
#                                                                          'car_age'])),
#                                    ('Imput_overal_mode_grouped_by_brand',
#                                     I...
#                                                                                       OneHotEncoder(drop='first',
#                                                                                                     handle_unknown='ignore',
#                                                                                                     sparse_output=False))]),
#                                                                      ['brand',
#                                                                       'transmission',
#                                                                       'fuelType']),
#                                                                     ('model_collap',
#                                                                      Pipeline(steps=[('fallback_impute',
#                                                                                       SimpleImputer(strategy='most_frequent')),
#                                                                                      ('rare',
#                                                                                       RareLabelGrouper(column='model')),
#                                                                                      ('ohe',
#                                                                                       OneHotEncoder(drop='first',
#                                                                                                     handle_unknown='ignore',
#                                                                                                     sparse_output=False))]),
#                                                                      ['model'])]))])),
#                   ('lasso', LassoCV())]),
#   Pipeline(steps=[('prep',
#                    Pipeline(steps=[('Imput_model_mode_grouped',
#                                     Mode_Imput_By_Brand(imput_cols=['model'])),
#                                    ('Imput_overal_mode_grouped_by_brand_and_model',
#                                     Imput_By_Brand_and_Model(imput_cols=['carID',
#                                                                          'transmission',
#                                                                          'mileage',
#                                                                          'fuelType',
#                                                                          'tax',
#                                                                          'mpg',
#                                                                          'engineSize',
#                                                                          'paintQuality%',
#                                                                          'previousOwners',
#                                                                          'car_age'])),
#                                    ('Imput_overal_mode_grouped_by_brand',
#                                     I...
#                                                                                       OneHotEncoder(drop='first',
#                                                                                                     handle_unknown='ignore',
#                                                                                                     sparse_output=False))]),
#                                                                      ['brand',
#                                                                       'transmission',
#                                                                       'fuelType']),
#                                                                     ('model_collap',
#                                                                      Pipeline(steps=[('fallback_impute',
#                                                                                       SimpleImputer(strategy='most_frequent')),
#                                                                                      ('rare',
#                                                                                       RareLabelGrouper(column='model')),
#                                                                                      ('ohe',
#                                                                                       OneHotEncoder(drop='first',
#                                                                                                     handle_unknown='ignore',
#                                                                                                     sparse_output=False))]),
#                                                                      ['model'])]))])),
#                   ('lasso', LassoCV())]),
#   Pipeline(steps=[('prep',
#                    Pipeline(steps=[('Imput_model_mode_grouped',
#                                     Mode_Imput_By_Brand(imput_cols=['model'])),
#                                    ('Imput_overal_mode_grouped_by_brand_and_model',
#                                     Imput_By_Brand_and_Model(imput_cols=['carID',
#                                                                          'transmission',
#                                                                          'mileage',
#                                                                          'fuelType',
#                                                                          'tax',
#                                                                          'mpg',
#                                                                          'engineSize',
#                                                                          'paintQuality%',
#                                                                          'previousOwners',
#                                                                          'car_age'])),
#                                    ('Imput_overal_mode_grouped_by_brand',
#                                     I...
#                                                                                       OneHotEncoder(drop='first',
#                                                                                                     handle_unknown='ignore',
#                                                                                                     sparse_output=False))]),
#                                                                      ['brand',
#                                                                       'transmission',
#                                                                       'fuelType']),
#                                                                     ('model_collap',
#                                                                      Pipeline(steps=[('fallback_impute',
#                                                                                       SimpleImputer(strategy='most_frequent')),
#                                                                                      ('rare',
#                                                                                       RareLabelGrouper(column='model')),
#                                                                                      ('ohe',
#                                                                                       OneHotEncoder(drop='first',
#                                                                                                     handle_unknown='ignore',
#                                                                                                     sparse_output=False))]),
#                                                                      ['model'])]))])),
#                   ('lasso', LassoCV())]),
#   Pipeline(steps=[('prep',
#                    Pipeline(steps=[('Imput_model_mode_grouped',
#                                     Mode_Imput_By_Brand(imput_cols=['model'])),
#                                    ('Imput_overal_mode_grouped_by_brand_and_model',
#                                     Imput_By_Brand_and_Model(imput_cols=['carID',
#                                                                          'transmission',
#                                                                          'mileage',
#                                                                          'fuelType',
#                                                                          'tax',
#                                                                          'mpg',
#                                                                          'engineSize',
#                                                                          'paintQuality%',
#                                                                          'previousOwners',
#                                                                          'car_age'])),
#                                    ('Imput_overal_mode_grouped_by_brand',
#                                     I...
#                                                                                       OneHotEncoder(drop='first',
#                                                                                                     handle_unknown='ignore',
#                                                                                                     sparse_output=False))]),
#                                                                      ['brand',
#                                                                       'transmission',
#                                                                       'fuelType']),
#                                                                     ('model_collap',
#                                                                      Pipeline(steps=[('fallback_impute',
#                                                                                       SimpleImputer(strategy='most_frequent')),
#                                                                                      ('rare',
#                                                                                       RareLabelGrouper(column='model')),
#                                                                                      ('ohe',
#                                                                                       OneHotEncoder(drop='first',
#                                                                                                     handle_unknown='ignore',
#                                                                                                     sparse_output=False))]),
#                                                                      ['model'])]))])),
#                   ('lasso', LassoCV())])],
#  'test_score': array([0.76236003, 0.79290828, 0.77375944, 0.77899118, 0.75311835,
#         0.77914275, 0.77360785, 0.77636216, 0.77447441, 0.78127583])}

# %%
series_list_lasso = []
# estimator is the pipeline trained in each fold (in total 10 estimators)
for est in cv_out_lasso["estimator"]:
    feat_names = est.named_steps["prep"].named_steps["column_transformer"].get_feature_names_out() # from the column transformer get the names for all features
    coeff = est.named_steps["lasso"].coef_# from the dt get vector containing each feature coefficient
    series_list_lasso.append(pd.Series(coeff, index=feat_names)) # create a series with the names from feat_names and importance from importance vector

series_list_lasso
# Out:
# [num__carID                   -2466.904597
#  num__mileage                  -875.211904
#  num__tax                      -201.937038
#  num__mpg                     -1431.649070
#  num__engineSize               6951.677739
#                                   ...
#  model_collap__model_tucson    1688.160962
#  model_collap__model_up!       -240.202088
#  model_collap__model_x1          -0.000000
#  model_collap__model_yaris     -524.317064
#  model_collap__model_zafira       0.000000
#  Length: 68, dtype: float64,
#  num__carID                   -2411.736195
#  num__mileage                  -888.634959
#  num__tax                      -199.684883
#  num__mpg                     -1404.272284
#  num__engineSize               6941.759615
#                                   ...
#  model_collap__model_tucson    1762.899822
#  model_collap__model_up!       -151.899156
#  model_collap__model_x1          -0.000000
#  model_collap__model_yaris     -361.191963
#  model_collap__model_zafira       0.000000
#  Length: 68, dtype: float64,
#  num__carID                   -2483.745843
#  num__mileage                  -858.886882
#  num__tax                      -205.046224
#  num__mpg                     -1315.545541
#  num__engineSize               7014.857266
#                                   ...
#  model_collap__model_tucson    1748.051131
#  model_collap__model_up!        -99.817240
#  model_collap__model_x1          -0.000000
#  model_collap__model_yaris     -445.708565
#  model_collap__model_zafira       0.000000
#  Length: 68, dtype: float64,
#  num__carID                   -2535.512421
#  num__mileage                  -878.107161
#  num__tax                      -201.559497
#  num__mpg                     -1277.658028
#  num__engineSize               7023.641668
#                                   ...
#  model_collap__model_tucson    1739.764337
#  model_collap__model_up!       -121.328348
#  model_collap__model_x1          -0.000000
#  model_collap__model_yaris     -351.600248
#  model_collap__model_zafira       0.000000
#  Length: 67, dtype: float64,
#  num__carID                   -2537.025318
#  num__mileage                  -869.962199
#  num__tax                      -199.176272
#  num__mpg                     -1272.307946
#  num__engineSize               6984.673260
#                                   ...
#  model_collap__model_tucson    1812.350828
#  model_collap__model_up!       -161.756754
#  model_collap__model_x1          -0.000000
#  model_collap__model_yaris     -403.871856
#  model_collap__model_zafira       0.000000
#  Length: 67, dtype: float64,
#  num__carID                   -2572.937142
#  num__mileage                  -884.133042
#  num__tax                      -198.797609
#  num__mpg                     -1383.597583
#  num__engineSize               7050.523807
#                                   ...
#  model_collap__model_tucson    1316.224056
#  model_collap__model_up!       -248.025563
#  model_collap__model_x1          -0.000000
#  model_collap__model_yaris     -422.049565
#  model_collap__model_zafira       0.000000
#  Length: 69, dtype: float64,
#  num__carID                   -2537.039918
#  num__mileage                  -878.083765
#  num__tax                      -195.312901
#  num__mpg                     -1332.074000
#  num__engineSize               7022.957687
#                                   ...
#  model_collap__model_tucson    1287.936880
#  model_collap__model_up!        -57.785016
#  model_collap__model_x1          -0.000000
#  model_collap__model_yaris     -478.904534
#  model_collap__model_zafira       0.000000
#  Length: 69, dtype: float64,
#  num__carID                   -2414.984866
#  num__mileage                  -883.231405
#  num__tax                      -197.370363
#  num__mpg                     -1262.292066
#  num__engineSize               6966.089884
#                                   ...
#  model_collap__model_tucson    1707.722856
#  model_collap__model_up!       -253.287019
#  model_collap__model_x1          -0.000000
#  model_collap__model_yaris     -453.740670
#  model_collap__model_zafira       0.000000
#  Length: 68, dtype: float64,
#  num__carID                   -2516.220597
#  num__mileage                  -888.749319
#  num__tax                      -195.860645
#  num__mpg                     -1265.552757
#  num__engineSize               6975.292056
#                                   ...
#  model_collap__model_tucson    1803.371770
#  model_collap__model_up!       -102.226335
#  model_collap__model_x1          -0.000000
#  model_collap__model_yaris     -326.274556
#  model_collap__model_zafira      15.918028
#  Length: 67, dtype: float64,
#  num__carID                   -2444.589197
#  num__mileage                  -868.005608
#  num__tax                      -200.774379
#  num__mpg                     -1298.991930
#  num__engineSize               7009.943986
#                                   ...
#  model_collap__model_tucson    1223.523142
#  model_collap__model_up!       -235.070354
#  model_collap__model_x1          -0.000000
#  model_collap__model_yaris     -429.295063
#  model_collap__model_zafira       0.000000
#  Length: 68, dtype: float64]

# %%
lasso = pd.concat(series_list_lasso, axis = 1)
lasso.columns = [f"fold_{i+1}" for i in range(10)]
lasso
# Out:
#                                  fold_1       fold_2       fold_3  \
# num__carID                 -2466.904597 -2411.736195 -2483.745843
# num__mileage                -875.211904  -888.634959  -858.886882
# num__tax                    -201.937038  -199.684883  -205.046224
# num__mpg                   -1431.649070 -1404.272284 -1315.545541
# num__engineSize             6951.677739  6941.759615  7014.857266
# ...                                 ...          ...          ...
# model_collap__model_up!     -240.202088  -151.899156   -99.817240
# model_collap__model_x1        -0.000000    -0.000000    -0.000000
# model_collap__model_yaris   -524.317064  -361.191963  -445.708565
# model_collap__model_zafira     0.000000     0.000000     0.000000
# model_collap__model_i30             NaN          NaN          NaN
#
#                                  fold_4       fold_5       fold_6  \
# num__carID                 -2535.512421 -2537.025318 -2572.937142
# num__mileage                -878.107161  -869.962199  -884.133042
# num__tax                    -201.559497  -199.176272  -198.797609
# num__mpg                   -1277.658028 -1272.307946 -1383.597583
# num__engineSize             7023.641668  6984.673260  7050.523807
# ...                                 ...          ...          ...
# model_collap__model_up!     -121.328348  -161.756754  -248.025563
# model_collap__model_x1        -0.000000    -0.000000    -0.000000
# model_collap__model_yaris   -351.600248  -403.871856  -422.049565
# model_collap__model_zafira     0.000000     0.000000     0.000000
# model_collap__model_i30             NaN          NaN     0.000000
#
#                                  fold_7       fold_8       fold_9      fold_10
# num__carID                 -2537.039918 -2414.984866 -2516.220597 -2444.589197
# num__mileage                -878.083765  -883.231405  -888.749319  -868.005608
# num__tax                    -195.312901  -197.370363  -195.860645  -200.774379
# num__mpg                   -1332.074000 -1262.292066 -1265.552757 -1298.991930
# num__engineSize             7022.957687  6966.089884  6975.292056  7009.943986
# ...                                 ...          ...          ...          ...
# model_collap__model_up!      -57.785016  -253.287019  -102.226335  -235.070354
# model_collap__model_x1        -0.000000    -0.000000    -0.000000    -0.000000
# model_collap__model_yaris   -478.904534  -453.740670  -326.274556  -429.295063
# model_collap__model_zafira     0.000000     0.000000    15.918028     0.000000
# model_collap__model_i30        0.000000          NaN          NaN     0.000000
#
# [69 rows x 10 columns]

# %%
lasso_summary = pd.DataFrame({
    "mean_coeff": lasso.mean(axis=1, skipna=True)
})
lasso_summary
# Out:
#                              mean_coeff
# num__carID                 -2492.069609
# num__mileage                -877.300624
# num__tax                    -199.551981
# num__mpg                   -1324.394121
# num__engineSize             6994.141697
# ...                                 ...
# model_collap__model_up!     -167.139787
# model_collap__model_x1         0.000000
# model_collap__model_yaris   -419.695408
# model_collap__model_zafira     1.591803
# model_collap__model_i30        0.000000
#
# [69 rows x 1 columns]

# %%
# checking which features lasso punished coeff to be 0 
lasso_removed = lasso_summary[lasso_summary["mean_coeff"] == 0]
lasso_removed
# Out:
#                                  mean_coeff
# cat__fuelType_electric                  0.0
# model_collap__model_5 series            0.0
# model_collap__model_a5                  0.0
# model_collap__model_a6                  0.0
# model_collap__model_auris               0.0
# model_collap__model_c class             0.0
# model_collap__model_c max               0.0
# model_collap__model_crossland x         0.0
# model_collap__model_i10                 0.0
# model_collap__model_insignia            0.0
# model_collap__model_mokka x             0.0
# model_collap__model_passat              0.0
# model_collap__model_q2                  0.0
# model_collap__model_q3                  0.0
# model_collap__model_superb              0.0
# model_collap__model_x1                  0.0
# model_collap__model_i30                 0.0

# %% [markdown]
# #### Final Decision

# %% [markdown]
# Several features were identified as irrelevant or redundant by the three feature selection methods. We focus on these features, and the final exclusion criterion is that a feature is removed by at least two out of the three methods.

# %%
type(flagged_features["Feature"])
# Out:
# pandas.core.series.Series

# %%
# features removed on each method
dt_removed= set(flagged_features["Feature"])
rfe_removed = set(removed_65)
lasso_removed_set = set(lasso_removed.index)
# checking if some feature is at least in two
features_in_at_least_two = ((dt_removed & rfe_removed) |(dt_removed & lasso_removed_set) |(rfe_removed & lasso_removed_set))
features_in_at_least_two
# Out:
# {'cat__fuelType_electric',
#  'model_collap__model_a5',
#  'model_collap__model_a6',
#  'model_collap__model_auris',
#  'model_collap__model_c max',
#  'model_collap__model_crossland x',
#  'model_collap__model_i30',
#  'model_collap__model_insignia',
#  'model_collap__model_mokka x',
#  'model_collap__model_passat',
#  'model_collap__model_q2',
#  'model_collap__model_superb',
#  'model_collap__model_x1'}

# %%
features_to_remove = list(features_in_at_least_two)

# %% [markdown]
# - For the final set of excluded features, we observe that most of them are dummy variables derived from the model column. These dummies likely have limited predictive value due to their very low representation in the dataset.
#
# - Additionally, the feature fueltype_electric was also excluded. This result was expected based on the univariate analysis, as only 4 cars out of approximately 75,000 in the dataset have this specification.

# %% [markdown]
# # 3. Modeling and evaluation

# %% [markdown]
# The project focuses on a regression problem with the objective of predicting used car prices. The following ML algorithms were selected for evaluation:
# - **Linear Regression:** Used as a baseline model due to its simplicity and interpretability.
# - **Ridge Regression:**
# - **Decision Tree Regressor:**
# - **RandomForestRegressor:**
# - **Neural Network:**
#
# **Assessment Strategy:**
#
# We implement a consistent evaluation framework using:
#
# - **5-Fold Cross-Validation**: For robust performance estimation
#
# - **Primary Metric**: MAE (Mean Absolute Error) - interpretable
#
# - **Secondary Metrics**: RMSE, R²
#
# - **Reporting**: Both training and validation scores for overfitting detection

# %% [markdown]
# #### Metrics

# %% [markdown]
# - Primary metric: **MAE**, because it is in price units, offering direct interpretability, and is less sensitive to outliers compared with other metrics (ex:MSE).
#
# - Secondary: **RMSE** (penalizes large errors) and **R²** (variance explained, for context).

# %% [markdown]
# ## Model Benchmarking

# %%
models = {
    'Linear Regression': LinearRegression(),
    'Ridge': Ridge(alpha=1.0),
    'Decision Tree': DecisionTreeRegressor(random_state=44),
    'Random Forest': RandomForestRegressor(random_state=44, n_jobs=-1),
    'Neural Network': MLPRegressor(max_iter=500, random_state=42, early_stopping=True)
}

# %%
def evaluate_model_cv(model, X, y, cv=5, pipeline=None):
    """
    Evaluate model using cross-validation with multiple metrics.
    Returns both train and validation scores.
    """

    if pipeline is not None:
        full_model = Pipeline([
            ('prep', clone(pipeline)),
            ('model', model)
        ])

    else:
        full_model = model

    # Define scoring metrics

    scoring = {
        'MAE': 'neg_mean_absolute_error',
        'RMSE': 'neg_root_mean_squared_error',
        'R2': 'r2'
    }

    kfold = KFold(n_splits=cv, shuffle=True, random_state=42)

    cv_results = cross_validate(
        full_model, X, y,
        cv=kfold,
        scoring=scoring,
        return_train_score=True,
        n_jobs=-1
    )  

    results = {
        'Train_MAE': -cv_results['train_MAE'].mean(),
        'Train_MAE_std': cv_results['train_MAE'].std(),
        'Val_MAE': -cv_results['test_MAE'].mean(),
        'Val_MAE_std': cv_results['test_MAE'].std(),
        'Train_RMSE': -cv_results['train_RMSE'].mean(),
        'Val_RMSE': -cv_results['test_RMSE'].mean(),
        'Train_R2': cv_results['train_R2'].mean(),
        'Val_R2': cv_results['test_R2'].mean(),
    }

    return results

# %%
def run_baseline_comparison(models_dict, X, y, pipeline, cv=5):
    """
    Run baseline comparison for multiple models.
    """

    results = []

    for name, model in models_dict.items():
        start_time = time.time()

        scores = evaluate_model_cv(model, X, y, cv=cv, pipeline=pipeline)
        scores['Model'] = name
        scores['Time (s)'] = round(time.time() - start_time, 2)

        results.append(scores)
        print(f"{name}:")
        print(f"  Val MAE: {scores['Val_MAE']:.2f} (+/- {scores['Val_MAE_std']:.2f})")    

    return pd.DataFrame(results).set_index('Model')

# %%
baseline_results = run_baseline_comparison(
    models, X_train, y_train, 
    pipeline=PreprocessAndRemoveByName(pipe_preprocessor, features_to_remove), cv=5
)

# Display baseline results
display_cols = ['Train_MAE', 'Val_MAE', 'Val_MAE_std', 'Train_R2', 'Val_R2', 'Time (s)']
baseline_results_display = baseline_results[display_cols].round(2)
baseline_results_display = baseline_results_display.sort_values('Val_MAE')

print("\nBaseline Model Comparison Results:")

baseline_results_display
# Out:
# Linear Regression:
#   Val MAE: 2885.32 (+/- 4.48)
# Ridge:
#   Val MAE: 2884.86 (+/- 4.52)
# Decision Tree:
#   Val MAE: 1893.51 (+/- 5.48)
# Random Forest:
#   Val MAE: 1505.91 (+/- 6.26)
# Neural Network:
#   Val MAE: 2150.46 (+/- 0.81)
#
# Baseline Model Comparison Results:
#                    Train_MAE  Val_MAE  Val_MAE_std  Train_R2  Val_R2  Time (s)
# Model
# Random Forest         568.41  1505.91         6.26      0.99    0.92     27.80
# Decision Tree          21.91  1893.51         5.48      1.00    0.87      6.00
# Neural Network       2133.76  2150.46         0.81      0.86    0.86     95.19
# Ridge                2878.92  2884.86         4.52      0.78    0.78      5.37
# Linear Regression    2879.39  2885.32         4.48      0.78    0.78      6.70

# %% [markdown]
# ### Baseline Observations
#
# From the baseline comparison:
#
# 1. **Random Forest** shows the best validation performance with lowest MAE even tho it shows signs of overfitting
#
# 2. **Decision Tree** shows signs of overfitting (large gap between train/val)
#
# 3. **Neural Network** shows competitive performance but requires more tuning
#
# 4. **Linear models** (LR, Ridge) serve as interpretable baselines

# %% [markdown]
# # Implementing Decision Tree Regressor

# %% [markdown]
# ### Hyperparameter Tuning
#
#
#
# We apply the following tuning approach:
#
# - Doing a RandomizedSearchCV trying to cover the most parameter space possible given our computing resources;
#
# - Interpreting and choosing a specific area of the parameter space, based on a selection that performed quite well and also did not overfit too much (since DTs are very prone to);
#
# - Doing a GridSearchCV around that area;
#
# - Chosing and deploying the model.

# %% [markdown]
# ## Hyperparameter Tuning

# %%
dt_pipe = Pipeline([
    ("prep", pipe_preprocessor),
    ("dt", DecisionTreeRegressor(random_state=42))
])

# %%
param_dist = {
    "dt__criterion": ["squared_error", "absolute_error"],
    "dt__max_depth": [5, 8, 15, 30, None],
    "dt__min_samples_split": [5, 10, 20, 30, 40],
    "dt__min_samples_leaf": [5, 10, 20, 30],
    "dt__max_features": [None, "sqrt", "log2"],
    "dt__ccp_alpha": [0.0001, 0.001, 0.01]
    }

# %%
# %%time

search_dt = RandomizedSearchCV(
    estimator=dt_pipe,
    param_distributions=param_dist,
    n_iter=40,                         
    scoring="neg_mean_absolute_error",
    cv=5,
    random_state=42,
    n_jobs=-1,
    verbose=1,
    return_train_score=True
)

search_dt.fit(X, y)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# CPU times: total: 12.6 s
# Wall time: 30min 23s
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('prep',
#                                               Pipeline(steps=[('Imput_model_mode_grouped',
#                                                                Mode_Imput_By_Brand(imput_cols=['model'])),
#                                                               ('Imput_overal_mode_grouped_by_brand_and_model',
#                                                                Imput_By_Brand_and_Model(imput_cols=['transmission',
#                                                                                                     'mileage',
#                                                                                                     'fuelType',
#                                                                                                     'tax',
#                                                                                                     'mpg',
#                                                                                                     'engineSize',
#                                                                                                     'car_age',
#                                                                                                     'mileage_per_year'])),
#                                                               ('Imput_overal_mode_grouped...
#                    n_iter=40, n_jobs=-1,
#                    param_distributions={'dt__ccp_alpha': [0.0001, 0.001, 0.01],
#                                         'dt__criterion': ['squared_error',
#                                                           'absolute_error'],
#                                         'dt__max_depth': [5, 8, 15, 30, None],
#                                         'dt__max_features': [None, 'sqrt',
#                                                              'log2'],
#                                         'dt__min_samples_leaf': [5, 10, 20, 30],
#                                         'dt__min_samples_split': [5, 10, 20, 30,
#                                                                   40]},
#                    random_state=42, return_train_score=True,
#                    scoring='neg_mean_absolute_error', verbose=1)

# %%
#cv_results = pd.read_excel("../project_data/model_results/DT_RandomSearch_top_20_results_1.xlsx")
cv_results = pd.DataFrame(search_dt.cv_results_)
cv_results = cv_results.sort_values("mean_test_score", ascending = False)
#cv_results.head(20).to_excel("DT_RandomSearch_top_20_results_1.xlsx", index = False)
cv_results.head(20)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        2.414979      0.525363         0.168950        0.042106
# 1        1.782053      0.498370         0.140303        0.047915
# 2      736.172451     82.577760         0.125870        0.015737
# 3      710.404581     55.074566         0.102155        0.015944
# 4      562.133224     23.973827         0.113188        0.019525
# 5      167.878376     39.152509         0.159397        0.052821
# 6        1.304289      0.069507         0.175073        0.055018
# 7      147.423120     29.474118         0.149808        0.055523
# 8      617.526843     18.466473         0.102566        0.021145
# 9      674.773715     25.487763         0.110371        0.015873
# 10       2.066109      0.582481         0.216795        0.070006
# 11       1.478509      0.206618         0.134285        0.020805
# 12       2.248241      0.479674         0.198567        0.047546
# 13       1.601093      0.179362         0.138345        0.035814
# 14     164.426202     33.950950         0.202461        0.033311
# 15       1.737860      0.397451         0.150843        0.050637
# 16       1.463985      0.461511         0.165225        0.050151
# 17     165.215416     36.612213         0.149745        0.048236
# 18     173.182013     47.001186         0.183992        0.066964
# 19       1.329821      0.409897         0.185283        0.057106
#
#     param_dt__min_samples_split  param_dt__min_samples_leaf  \
# 0                            20                          10
# 1                            10                           5
# 2                            40                          20
# 3                             5                          30
# 4                            30                          20
# 5                            10                           5
# 6                            40                          10
# 7                            30                           5
# 8                            10                           5
# 9                            30                          20
# 10                            5                           5
# 11                           30                          20
# 12                            5                          20
# 13                           10                          20
# 14                           40                          10
# 15                           20                          10
# 16                           40                          10
# 17                           40                          30
# 18                           10                          20
# 19                           40                           5
#
#    param_dt__max_features  param_dt__max_depth param_dt__criterion  \
# 0                     NaN                  NaN       squared_error
# 1                     NaN                 15.0       squared_error
# 2                     NaN                  NaN      absolute_error
# 3                     NaN                 30.0      absolute_error
# 4                     NaN                 15.0      absolute_error
# 5                    sqrt                  NaN      absolute_error
# 6                    sqrt                  NaN       squared_error
# 7                    log2                 30.0      absolute_error
# 8                     NaN                  8.0      absolute_error
# 9                     NaN                  8.0      absolute_error
# 10                    NaN                  8.0       squared_error
# 11                    NaN                  8.0       squared_error
# 12                    NaN                  8.0       squared_error
# 13                    NaN                  8.0       squared_error
# 14                   log2                 30.0      absolute_error
# 15                   log2                 30.0       squared_error
# 16                   log2                  NaN       squared_error
# 17                   sqrt                 30.0      absolute_error
# 18                   log2                  NaN      absolute_error
# 19                   sqrt                 15.0       squared_error
#
#     param_dt__ccp_alpha                                             params  \
# 0                0.0001  {'dt__min_samples_split': 20, 'dt__min_samples...
# 1                0.0010  {'dt__min_samples_split': 10, 'dt__min_samples...
# 2                0.0001  {'dt__min_samples_split': 40, 'dt__min_samples...
# 3                0.0001  {'dt__min_samples_split': 5, 'dt__min_samples_...
# 4                0.0100  {'dt__min_samples_split': 30, 'dt__min_samples...
# 5                0.0001  {'dt__min_samples_split': 10, 'dt__min_samples...
# 6                0.0010  {'dt__min_samples_split': 40, 'dt__min_samples...
# 7                0.0100  {'dt__min_samples_split': 30, 'dt__min_samples...
# 8                0.0100  {'dt__min_samples_split': 10, 'dt__min_samples...
# 9                0.0100  {'dt__min_samples_split': 30, 'dt__min_samples...
# 10               0.0010  {'dt__min_samples_split': 5, 'dt__min_samples_...
# 11               0.0100  {'dt__min_samples_split': 30, 'dt__min_samples...
# 12               0.0001  {'dt__min_samples_split': 5, 'dt__min_samples_...
# 13               0.0100  {'dt__min_samples_split': 10, 'dt__min_samples...
# 14               0.0001  {'dt__min_samples_split': 40, 'dt__min_samples...
# 15               0.0100  {'dt__min_samples_split': 20, 'dt__min_samples...
# 16               0.0001  {'dt__min_samples_split': 40, 'dt__min_samples...
# 17               0.0100  {'dt__min_samples_split': 40, 'dt__min_samples...
# 18               0.0001  {'dt__min_samples_split': 10, 'dt__min_samples...
# 19               0.0100  {'dt__min_samples_split': 40, 'dt__min_samples...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0        -1681.720427       -1680.856445       -1703.978488
# 1        -1704.313944       -1736.278221       -1762.436271
# 2        -1800.925535       -1776.167358       -1776.783580
# 3        -1847.679105       -1849.609576       -1854.317966
# 4        -1852.491971       -1843.966305       -1849.689075
# 5        -2064.481343       -1999.151859       -2106.187364
# 6        -2238.684185       -2283.631107       -2310.603193
# 7        -2441.857223       -2404.347318       -2261.946298
# 8        -2390.286509       -2401.273939       -2421.800000
# 9        -2406.662488       -2409.737776       -2430.920237
# 10       -2430.126485       -2440.747768       -2438.292994
# 11       -2450.998832       -2460.246034       -2443.603914
# 12       -2450.998832       -2460.246034       -2443.603914
# 13       -2450.998832       -2460.246034       -2443.603914
# 14       -2427.223955       -2496.120072       -2358.486311
# 15       -2385.519370       -2482.110121       -2313.218766
# 16       -2599.335202       -2564.709553       -2455.991136
# 17       -2615.443731       -2590.171438       -2570.090819
# 18       -2463.449128       -2803.647614       -2426.813491
# 19       -2571.011667       -2407.755636       -2818.976614
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0        -1679.435171       -1677.794176     -1684.756941        9.702613
# 1        -1718.379519       -1702.224648     -1724.726521       22.444416
# 2        -1769.803113       -1742.901770     -1773.316271       18.546194
# 3        -1825.905028       -1822.792681     -1840.060871       13.046519
# 4        -1853.927274       -1819.679907     -1843.950906       12.605443
# 5        -1965.823121       -1989.560616     -2025.040861       52.107841
# 6        -2219.295458       -2274.516182     -2265.346025       32.551976
# 7        -2268.872022       -2334.649763     -2342.334525       71.649726
# 8        -2375.532282       -2379.658484     -2393.710243       16.648460
# 9        -2388.565190       -2388.217026     -2404.820543       15.803033
# 10       -2421.248705       -2436.394578     -2433.362106        7.003731
# 11       -2437.680669       -2446.360580     -2447.778006        7.579100
# 12       -2437.680669       -2446.360580     -2447.778006        7.579100
# 13       -2437.680669       -2446.360580     -2447.778006        7.579100
# 14       -2610.257964       -2404.269350     -2459.271530       87.595280
# 15       -2611.523952       -2541.370374     -2466.748516      106.708843
# 16       -2633.519431       -2442.278390     -2539.166742       76.786252
# 17       -2442.287252       -2607.044952     -2565.007638       63.293418
# 18       -2654.800513       -2578.237001     -2585.389550      136.030479
# 19       -2746.332079       -2428.185535     -2594.452306      165.244292
#
#     rank_test_score  split0_train_score  split1_train_score  \
# 0                 1        -1374.083984        -1362.417366
# 1                 2        -1414.291968        -1418.570710
# 2                 3        -1558.372437        -1542.740449
# 3                 4        -1678.749070        -1679.367337
# 4                 5        -1656.191336        -1651.130820
# 5                 6        -1759.593652        -1690.550446
# 6                 7        -2095.582117        -2158.240176
# 7                 8        -2269.794514        -2199.019168
# 8                 9        -2328.382836        -2331.083435
# 9                10        -2344.306311        -2351.334661
# 10               11        -2362.783092        -2365.804944
# 11               12        -2386.855939        -2385.182322
# 12               12        -2386.855939        -2385.182322
# 13               12        -2386.855939        -2385.182322
# 14               15        -2284.033450        -2366.867830
# 15               16        -2264.093633        -2348.423330
# 16               17        -2463.653010        -2459.500592
# 17               18        -2513.969282        -2496.300207
# 18               19        -2330.075504        -2723.345092
# 19               20        -2478.291856        -2322.393310
#
#     split2_train_score  split3_train_score  split4_train_score  \
# 0         -1368.910874        -1377.702871        -1375.920165
# 1         -1430.010301        -1409.346034        -1402.597855
# 2         -1550.451808        -1564.825548        -1560.207851
# 3         -1687.439764        -1693.509321        -1681.655062
# 4         -1668.710438        -1683.313348        -1670.014939
# 5         -1768.528728        -1690.794386        -1658.528752
# 6         -2157.143334        -2097.692234        -2173.100447
# 7         -2003.332884        -2089.595930        -2148.220092
# 8         -2337.987660        -2340.712236        -2326.644598
# 9         -2355.614087        -2362.496718        -2345.977558
# 10        -2372.084556        -2378.732178        -2368.617865
# 11        -2391.913085        -2404.488391        -2390.080243
# 12        -2391.913085        -2404.488391        -2390.080243
# 13        -2391.913085        -2404.488391        -2390.080243
# 14        -2270.865609        -2483.903898        -2278.580612
# 15        -2183.247843        -2496.386942        -2458.526300
# 16        -2306.770573        -2530.072434        -2329.081973
# 17        -2502.425318        -2391.564488        -2517.123875
# 18        -2328.045444        -2554.257062        -2475.747758
# 19        -2739.810330        -2647.051302        -2329.384795
#
#     mean_train_score  std_train_score
# 0       -1371.807052         5.539257
# 1       -1414.963373         9.212320
# 2       -1555.319619         7.816755
# 3       -1684.144111         5.597998
# 4       -1665.872176        11.317588
# 5       -1713.599193        42.934372
# 6       -2136.351662        32.919845
# 7       -2141.992518        91.209724
# 8       -2332.962153         5.472307
# 9       -2351.945867         6.620172
# 10      -2369.604527         5.502852
# 11      -2391.703996         6.814058
# 12      -2391.703996         6.814058
# 13      -2391.703996         6.814058
# 14      -2336.850280        81.320069
# 15      -2350.135610       116.957834
# 16      -2417.815716        85.609530
# 17      -2484.276634        46.968240
# 18      -2482.294172       148.519529
# 19      -2503.386319       167.451887

# %%
cv_results["overfit"] = (cv_results["mean_test_score"] - cv_results["mean_train_score"]) *-1
cv_results["overfit%"] =  cv_results["overfit"] / cv_results["mean_test_score"] * -100
# Out:
# 0     312.949889
# 1     309.763147
# 2     217.996652
# 3     155.916760
# 4     178.078730
# 5     311.441668
# 6     128.994363
# 7     200.342007
# 8      60.748090
# 9      52.874676
# 10     63.757579
# 11     56.074010
# 12     56.074010
# 13     56.074010
# 14    122.421251
# 15    116.612907
# 16    121.351026
# 17     80.731004
# 18    103.095377
# 19     91.065988
# Name: overfit, dtype: float64
# 0     18.575373
# 1     17.960131
# 2     12.293163
# 3      8.473457
# 4      9.657455
# 5     15.379525
# 6      5.694245
# 7      8.553091
# 8      2.537821
# 9      2.198695
# 10     2.620144
# 11     2.290813
# 12     2.290813
# 13     2.290813
# 14     4.977948
# 15     4.727393
# 16     4.779167
# 17     3.147398
# 18     3.987615
# 19     3.510027
# Name: overfit%, dtype: float64

# %% [markdown]
# - By looking at the results, even tought the best performance tree in validation has an mean MAE of ~ 1690 it also has the most amount of overfit with 312 on difference between validation score and training score.
# - The 3rd in the rank has 90 more units in val mae than the best performer and minus 90 on "overfit.
# -
# We will now do an hyperparameter tuning, using an extensive search of combinations around the parameter space of these 2 models, and look for the best model under the4000 difference between val score and train scree

# %%
param_gridcv = {
    "dt__max_depth": [30, 33, None],
    "dt__min_samples_leaf": [2, 5, 10, 20],
    "dt__min_samples_split": [5, 10, 20, 40],
    "dt__ccp_alpha": [0.0, 0.0001, 0.0002],
    "dt__criterion": ["absolute_error", "squared_error"],
    "dt__max_features": [None]
}

# %%
# %%time

grid_search_dt = GridSearchCV(
    estimator=dt_pipe,
    param_grid =param_gridcv,                         
    scoring="neg_mean_absolute_error",
    cv=5,
    n_jobs=-1,
    verbose=1,
    return_train_score=True
)

grid_search_dt.fit(X, y)

grid_results_dt = pd.DataFrame(grid_search_dt.cv_results_)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# CPU times: total: 9min 26s
# Wall time: 7h 24min

# %%
grid_results_dt = grid_results_dt.sort_values("mean_test_score", ascending = False)
grid_results_dt["overfit"] = (grid_results_dt["mean_test_score"] - grid_results_dt["mean_train_score"]) *-1
#grid_results_dt.to_excel("GridSearchCV_DT_3_Results.xlsx", index=False)

# %% [markdown]
# ## Chosing Final DT Model

# %%
#grid_results_dt = pd.read_excel("../project_data/model_results/GridSearchCV_DT_3_Results.xlsx")

# %%
train_scores = -grid_results_dt["mean_train_score"]  
test_scores = -grid_results_dt["mean_test_score"]    
overfit = grid_results_dt["overfit"] 


fig, ax = plt.subplots(figsize=(10, 10))

ax.set_xlabel("Overfit", fontsize=15)
ax.set_ylabel("Validation MAE", fontsize=15)
ax.set_title("Validation MAE vs Overfit")


ax.axvline(
    x=400,
    linestyle="--",
    linewidth=2,
    color="green",
    label="Overfit threshold (400)"
)

ax.plot(
    overfit,
    test_scores,
    marker="o",
    label="Validation MAE",
    drawstyle="steps-post"
)

ax.invert_yaxis()
ax.legend()
plt.show()

# %% [markdown]
# - Based on the results of the extensive parameter search, there is a range of viable candidates, with validation MAE between 1625 and 1660, and under the 400 "overfit" treshold.
# - This indicates a region of acceptable trade-off between predictive performance and model generalization, altough we can´t be sure if there is a better tree outside of this range.

# %%
cols_for_chosing = ['params', 'mean_test_score', 'overfit', 'std_test_score']
filtered_grid = grid_results_dt[(grid_results_dt['overfit'] < 400) & (grid_results_dt['mean_test_score'] > -1660)]
filtered_grid = filtered_grid[cols_for_chosing]

# %%
filtered_grid
# Out:
#                                                 params  mean_test_score  \
# 45   {'dt__ccp_alpha': 0.0002, 'dt__criterion': 'sq...     -1625.545617
# 46   {'dt__ccp_alpha': 0.0001, 'dt__criterion': 'sq...     -1625.545617
# 47   {'dt__ccp_alpha': 0.0, 'dt__criterion': 'squar...     -1625.545617
# 48   {'dt__ccp_alpha': 0.0, 'dt__criterion': 'squar...     -1625.890942
# 49   {'dt__ccp_alpha': 0.0002, 'dt__criterion': 'sq...     -1625.890942
# 50   {'dt__ccp_alpha': 0.0001, 'dt__criterion': 'sq...     -1625.890942
# 51   {'dt__ccp_alpha': 0.0001, 'dt__criterion': 'sq...     -1626.011788
# 52   {'dt__ccp_alpha': 0.0002, 'dt__criterion': 'sq...     -1626.011788
# 53   {'dt__ccp_alpha': 0.0, 'dt__criterion': 'squar...     -1626.011788
# 54   {'dt__ccp_alpha': 0.0002, 'dt__criterion': 'ab...     -1627.232610
# 55   {'dt__ccp_alpha': 0.0001, 'dt__criterion': 'ab...     -1627.238843
# 56   {'dt__ccp_alpha': 0.0, 'dt__criterion': 'absol...     -1627.241100
# 57   {'dt__ccp_alpha': 0.0002, 'dt__criterion': 'ab...     -1628.338799
# 58   {'dt__ccp_alpha': 0.0001, 'dt__criterion': 'ab...     -1628.344939
# 59   {'dt__ccp_alpha': 0.0, 'dt__criterion': 'absol...     -1628.346604
# 60   {'dt__ccp_alpha': 0.0002, 'dt__criterion': 'ab...     -1628.599329
# 61   {'dt__ccp_alpha': 0.0, 'dt__criterion': 'absol...     -1628.601817
# 62   {'dt__ccp_alpha': 0.0001, 'dt__criterion': 'ab...     -1628.603422
# 69   {'dt__ccp_alpha': 0.0001, 'dt__criterion': 'sq...     -1637.638023
# 70   {'dt__ccp_alpha': 0.0002, 'dt__criterion': 'sq...     -1637.638023
# 71   {'dt__ccp_alpha': 0.0, 'dt__criterion': 'squar...     -1637.638023
# 78   {'dt__ccp_alpha': 0.0, 'dt__criterion': 'squar...     -1638.089132
# 79   {'dt__ccp_alpha': 0.0002, 'dt__criterion': 'sq...     -1638.089132
# 80   {'dt__ccp_alpha': 0.0001, 'dt__criterion': 'sq...     -1638.089132
# 81   {'dt__ccp_alpha': 0.0, 'dt__criterion': 'squar...     -1638.156424
# 82   {'dt__ccp_alpha': 0.0001, 'dt__criterion': 'sq...     -1638.156424
# 83   {'dt__ccp_alpha': 0.0002, 'dt__criterion': 'sq...     -1638.156424
# 117  {'dt__ccp_alpha': 0.0002, 'dt__criterion': 'ab...     -1652.686073
# 118  {'dt__ccp_alpha': 0.0, 'dt__criterion': 'absol...     -1652.689798
# 119  {'dt__ccp_alpha': 0.0001, 'dt__criterion': 'ab...     -1652.690035
# 120  {'dt__ccp_alpha': 0.0002, 'dt__criterion': 'ab...     -1653.096432
# 121  {'dt__ccp_alpha': 0.0, 'dt__criterion': 'absol...     -1653.100157
# 122  {'dt__ccp_alpha': 0.0001, 'dt__criterion': 'ab...     -1653.100394
# 123  {'dt__ccp_alpha': 0.0002, 'dt__criterion': 'ab...     -1653.110068
# 124  {'dt__ccp_alpha': 0.0, 'dt__criterion': 'absol...     -1653.113793
# 125  {'dt__ccp_alpha': 0.0001, 'dt__criterion': 'ab...     -1653.114030
# 126  {'dt__ccp_alpha': 0.0001, 'dt__criterion': 'sq...     -1655.789568
# 127  {'dt__ccp_alpha': 0.0002, 'dt__criterion': 'sq...     -1655.789568
# 128  {'dt__ccp_alpha': 0.0, 'dt__criterion': 'squar...     -1655.789568
# 129  {'dt__ccp_alpha': 0.0, 'dt__criterion': 'squar...     -1655.869586
# 130  {'dt__ccp_alpha': 0.0001, 'dt__criterion': 'sq...     -1655.869586
# 131  {'dt__ccp_alpha': 0.0002, 'dt__criterion': 'sq...     -1655.869586
# 132  {'dt__ccp_alpha': 0.0001, 'dt__criterion': 'sq...     -1656.714494
# 133  {'dt__ccp_alpha': 0.0002, 'dt__criterion': 'sq...     -1656.714494
# 134  {'dt__ccp_alpha': 0.0, 'dt__criterion': 'squar...     -1656.714494
#
#         overfit  std_test_score
# 45   388.341662       11.310285
# 46   388.341662       11.310285
# 47   388.341662       11.310285
# 48   390.399376       11.322101
# 49   390.399376       11.322101
# 50   390.399376       11.322101
# 51   390.811408       11.411801
# 52   390.811408       11.411801
# 53   390.811408       11.411801
# 54   359.247108       15.584596
# 55   359.253511       15.579504
# 56   359.255815       15.582472
# 57   361.158456       14.276177
# 58   361.164768       14.271022
# 59   361.166495       14.273445
# 60   358.485084       14.631961
# 61   358.487720       14.630067
# 62   358.489270       14.627494
# 69   310.064997       16.141246
# 70   310.064997       16.141246
# 71   310.064997       16.141246
# 78   310.883053       15.693509
# 79   310.883053       15.693509
# 80   310.883053       15.693509
# 81   309.184223       16.443635
# 82   309.184223       16.443635
# 83   309.184223       16.443635
# 117  320.159399       15.897852
# 118  320.163265       15.891959
# 119  320.163453       15.892214
# 120  321.349660       16.443313
# 121  321.353526       16.437543
# 122  321.353714       16.437802
# 123  321.665105       16.209204
# 124  321.668971       16.203499
# 125  321.669159       16.203755
# 126  266.454778       13.972961
# 127  266.454778       13.972961
# 128  266.454778       13.972961
# 129  266.594280       14.040513
# 130  266.594280       14.040513
# 131  266.594280       14.040513
# 132  266.359095       13.423048
# 133  266.359095       13.423048
# 134  266.359095       13.423048

# %% [markdown]
# - Two final decision tree models were selected: one prioritizing minimal validation MAE under the overfitting treshold (tree 60), and a second model with slightly higher MAE but reduced overfitting, potentially offering better generalization (tree 126).

# %%
params_60 = ast.literal_eval(grid_results_dt["params"].iloc[60])
params_60
params_60 = {k.replace("dt__", ""): v for k, v in params.items()}
# Out:
# {'dt__ccp_alpha': 0.0002,
#  'dt__criterion': 'absolute_error',
#  'dt__max_depth': 30,
#  'dt__max_features': None,
#  'dt__min_samples_leaf': 2,
#  'dt__min_samples_split': 40}

# %%
params_126 = ast.literal_eval(grid_results_dt["params"].iloc[126])
params_126
# Out:
# {'dt__ccp_alpha': 0.0001,
#  'dt__criterion': 'squared_error',
#  'dt__max_depth': 33,
#  'dt__max_features': None,
#  'dt__min_samples_leaf': 5,
#  'dt__min_samples_split': 40}

# %%
final_dt_pipe = Pipeline([
    ("prep", pipe_preprocessor),
    ("dt", DecisionTreeRegressor(**params_60))
])

final_dt_pipe
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 3
#       1 final_dt_pipe = Pipeline([
#       2     ("prep", pipe_preprocessor),
# ----> 3     ("dt", DecisionTreeRegressor(**params_60))
#       4 ])
#       6 final_dt_pipe
#
# TypeError: DecisionTreeRegressor.__init__() got an unexpected keyword argument 'dt__ccp_alpha'

# %% [markdown]
# # Random Forest

# %% [markdown]
# ## Hyperparameter Tuning

# %%
dt_pipe = Pipeline([
    ("prep", pipe_preprocessor),
    ("rf", RandomForestRegressor(bootstrap = True, random_state=42))
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dt_pipe = Pipeline([
#       2     ("prep", pipe_preprocessor),
#       3     ("rf", RanRegressor(bootstrap = True, random_state=42))
#       4 ])
#
# NameError: name 'Pipeline' is not defined

# %%
n_esti = [i for i in range (100, 501, 50)]
max_depth = [i for i in range(0, 100, 10)]
lists = [n_esti, max_depth]
for l in lists:
    l.append(None)

# %%
param_dist = {
    "dt__criterion": ["squared_error", "absolute_error"],
    "rf__n_estimators": n_esti,
    "rf__max_samples": [0.2, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9],
    "rf__max_depth": [5, 10, 20, 30],
    "rf__max_features": [None, "sqrt", "log2"],
    "rf__oob_score": [True, False]
    }

# %%
# %%time

search_rf = RandomizedSearchCV(
    estimator=dt_pipe,
    param_distributions=param_dist,
    n_iter=100,                         
    scoring="neg_mean_absolute_error",
    cv=5,
    random_state=42,
    n_jobs=-1,
    verbose=1,
    return_train_score=True
)

search_dt.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:1
#
# NameError: name 'RandomizedSearchCV' is not defined

# %% [markdown]
# ## Chosing Final RF Model

# %% [markdown]
# ### Val MAE VS Overfit

# %%
grid_results_rf = pd.read_excel("../project_data/model_results/Random_Search_Results_RandomForest.xlsx")

# %%
train_scores = -grid_results_rf["mean_train_score"]  
test_scores = -grid_results_rf["mean_test_score"]    
overfit = grid_results_rf["overfit"] 


fig, ax = plt.subplots(figsize=(10, 10))

ax.set_xlabel("Validation MAE - Traning MAE", fontsize=15)
ax.set_xlim(0, max(overfit)+100)
ax.set_ylabel("Validation MAE", fontsize=15)
ax.set_ylim(0, max(test_scores)+100)
ax.set_title("Overfit Treshold")


ax.axvline(
    x=775,
    linestyle="--",
    linewidth=2,
    color="green",
    label="Overfit threshold (400)"
)

ax.plot(
    overfit,
    test_scores,
    marker="o",
    linestyle="None",
    label="Validation MAE",
    drawstyle="steps-post"
)

#ax.invert_yaxis()
ax.legend()
plt.show()

# %% [markdown]
# ### Val MAE VS Train MAE

# %%
fig, ax = plt.subplots(figsize=(10, 10))

ax.set_xlabel("Training MAE", fontsize=15)
ax.set_xlim(0, max(train_scores)+100)
ax.set_ylabel("Validation MAE", fontsize=15)
ax.set_ylim(0, max(test_scores)+100)
ax.set_title("Validation MAE vs Training MAE")

ax.axvline(
    x=-775+1500,
    linestyle="--",
    linewidth=2,
    color="green",
    label="Overfit threshold (400)"
)

ax.plot(
    train_scores,
    test_scores,
    marker="o",
    linestyle="None",
    label="Validation MAE",
    drawstyle="steps-post"
)

ax.legend()
plt.show()

# %%
best_param_rf = {'n_estimators': 200, 'max_samples': 0.4, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error'}

# %%
best_rf = Pipeline([
    ("prep", pipe_preprocessor),
    ("rf", RandomForestRegressor(**best_param_rf))
])

# %%
best_rf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('prep',
#                  Pipeline(steps=[('Imput_model_mode_grouped',
#                                   Mode_Imput_By_Brand(imput_cols=['model'])),
#                                  ('Imput_overal_mode_grouped_by_brand_and_model',
#                                   Imput_By_Brand_and_Model(imput_cols=['transmission',
#                                                                        'mileage',
#                                                                        'fuelType',
#                                                                        'tax',
#                                                                        'mpg',
#                                                                        'engineSize',
#                                                                        'car_age'])),
#                                  ('Imput_overal_mode_grouped_by_brand',
#                                   Imput_By_Brand_and_Model(group_cols=['bran...
#                                                                     'transmission',
#                                                                     'fuelType']),
#                                                                   ('model_collap',
#                                                                    Pipeline(steps=[('fallback_impute',
#                                                                                     SimpleImputer(strategy='most_frequent')),
#                                                                                    ('rare',
#                                                                                     RareLabelGrouper(column='model')),
#                                                                                    ('ohe',
#                                                                                     OneHotEncoder(drop='first',
#                                                                                                   handle_unknown='ignore',
#                                                                                                   sparse_output=False))]),
#                                                                    ['model'])]))])),
#                 ('rf',
#                  RandomForestRegressor(max_depth=20, max_features=None,
#                                        max_samples=0.4, n_estimators=200))])

# %% [markdown]
# ## Neural Network

# %% [markdown]
# For Neural Networks, we follow the same two-stage approach:
#
# 1. RandomizedSearchCV for broad exploration
#
# 2. GridSearchCV for fine-tuning

# %%
nn_pipe = Pipeline([
    ("prep", PreprocessAndRemoveByName(pipe_preprocessor, features_to_remove)),
    ("nn", MLPRegressor(max_iter=1000, early_stopping=True, random_state=44))
])

# %%
nn_params = {
    'nn__hidden_layer_sizes': [
        (50,), (100,), (150,),
        (50, 25), (100, 50), (100, 100),
        (100, 50, 25), (150, 100, 50)
    ],
    'nn__activation': ['relu', 'tanh'],
    'nn__solver': ['adam', 'sgd'],
    'nn__alpha': [0.0001, 0.001, 0.01, 0.1],
    'nn__learning_rate_init': [0.001, 0.01, 0.1],
    'nn__batch_size': [32, 64, 128, 256],
    'nn__max_iter': [500, 1000]
}


random_nn_search = RandomizedSearchCV(
    estimator= nn_pipe,
    param_distributions= nn_params,
    n_iter=30,
    cv=5,
    scoring="neg_mean_absolute_error",
    n_jobs=-1,
    verbose=1,
    random_state=44
)
random_nn_search.fit(X, y)

print(f'Best params: {random_nn_search.best_params_}')
print(f'Best MAE: {-random_nn_search.best_score_:,.2f}')
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# C:\Users\MasterG\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 32 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\MasterG\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\MasterG\anaconda3\lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "C:\Users\MasterG\anaconda3\lib\site-packages\sklearn\pipeline.py", line 427, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\MasterG\anaconda3\lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "C:\Users\MasterG\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 753, in fit
#     return self._fit(X, y, incremental=False)
#   File "C:\Users\MasterG\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 476, in _fit
#     self._fit_stochastic(
#   File "C:\Users\MasterG\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 660, in _fit_stochastic
#     self._update_no_improvement_count(early_stopping, X_val, y_val)
#   File "C:\Users\MasterG\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 709, in _update_no_improvement_count
#     self.validation_scores_.append(self._score(X_val, y_val))
#   File "C:\Users\MasterG\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 1612, in _score
#     return r2_score(y, y_pred)
#   File "C:\Users\MasterG\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py", line 187, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\MasterG\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 989, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\MasterG\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 101, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\MasterG\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 957, in check_array
#     _assert_all_finite(
#   File "C:\Users\MasterG\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 122, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\MasterG\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 171, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\MasterG\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [ -7554.71171485  -3458.11017389             nan             nan
#   -1705.56020522  -1603.99327996  -4539.47770398  -3417.12060143
#  -11403.83040322  -1921.78630714             nan  -6969.51085702
#   -3392.75568832             nan  -4872.08633938  -3013.68907688
#   -5016.9942987              nan  -6243.03290347             nan
#   -1642.43728558  -4134.76190629  -3596.24664291  -1636.21979214
#   -1688.56367765  -2218.10269437  -5008.62963121  -3451.87232732
#   -3777.76184508             nan]
#   warnings.warn(
# Best params: {'nn__solver': 'adam', 'nn__max_iter': 500, 'nn__learning_rate_init': 0.001, 'nn__hidden_layer_sizes': (150, 100, 50), 'nn__batch_size': 32, 'nn__alpha': 0.0001, 'nn__activation': 'relu'}
# Best MAE: 1,603.99

# %%
# Save NN RandomizedSearch results
nn_random_results = pd.DataFrame(random_nn_search.cv_results_)
nn_random_results = nn_random_results.sort_values('rank_test_score')
nn_random_results.to_csv('nn_randomized_search_results.csv', index=False)

# %%
#random_results_nn = pd.read_excel("../project_data/model_results/nn_randomized_search_results.csv")

# %%
# Neural Network - GridSearchCV (fine-tuning)

best_nn_params = random_nn_search.best_params_

# %%
best_nn_params
# Out:
# {'nn__solver': 'adam',
#  'nn__max_iter': 500,
#  'nn__learning_rate_init': 0.001,
#  'nn__hidden_layer_sizes': (150, 100, 50),
#  'nn__batch_size': 32,
#  'nn__alpha': 0.0001,
#  'nn__activation': 'relu'}

# %%
best_hidden = best_nn_params.get('nn__hidden_layer_sizes', (100,))
best_alpha = best_nn_params.get('nn__alpha', 0.001)
best_lr = best_nn_params.get('nn__learning_rate_init', 0.001)

nn_param_grid = {
    'nn__hidden_layer_sizes': [(150, 100, 50), (160, 120, 60)],
    'nn__activation': ['relu'],
    'nn__solver': ['adam'],
    'nn__alpha': [0.00005, 0.0001, 0.0002],
    'nn__learning_rate_init': [0.0005, 0.001, 0.002],
    'nn__batch_size': [32, 35],
    'nn__max_iter': [500, 650]
}

# %%
nn_param_grid
# Out:
# {'nn__hidden_layer_sizes': [(150, 100, 50)],
#  'nn__activation': ['relu'],
#  'nn__solver': ['adam'],
#  'nn__alpha': [5e-05, 0.0001, 0.0002],
#  'nn__learning_rate_init': [0.0005, 0.001, 0.002],
#  'nn__batch_size': [32],
#  'nn__max_iter': [500]}

# %%
nn_grid_search = GridSearchCV(
    nn_pipe,
    param_grid=nn_param_grid,
    cv=5,
    scoring='neg_mean_absolute_error',
    n_jobs=-1,
    verbose=1
)

nn_grid_search.fit(X_train, y_train)

print(f"\nBest MAE (GridSearch): £{-nn_grid_search.best_score_:.2f}")
print(f"Best parameters: {nn_grid_search.best_params_}")

# %%
# Save NN GridSearch results
nn_grid_results = pd.DataFrame(nn_grid_search.cv_results_)
nn_grid_results = nn_grid_results.sort_values('rank_test_score')
nn_grid_results.to_csv('nn_grid_search_results.csv', index=False)

# %%
nn_grid_results.head(15)

# %%
# Store best NN model
best_nn = nn_grid_search.best_estimator_

# %% [markdown]
# ## Final Model Comparison
#
#
#
# Compare all tuned models and select the best performer.

# %%
final_models = {
    'Linear Regression': Pipeline([
        ('prep', clone(PreprocessAndRemoveByName(pipe_preprocessor, features_to_remove))),
        ('model', LinearRegression())
    ]),
    'Ridge Regression': Pipeline([
        ('prep', clone(pipeline=PreprocessAndRemoveByName(pipe_preprocessor, features_to_remove))),
        ('model', RidgeCV(cv=5))
    ]),
    'Decision Tree (Tuned)': best_dt,
    'Random Forest (Tuned)': best_rf,
    'Neural Network (Tuned)': best_nn
}

final_results = []
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

for name, model in final_models.items()    
    cv_results = cross_validate(
        model, X_train, y_train,
        cv=kfold,
        scoring={
            'MAE': 'neg_mean_absolute_error',
            'RMSE': 'neg_root_mean_squared_error',
            'R2': 'r2'
        },
        return_train_score=True,
        n_jobs=-1
    )
    
    results = {
        'Model': name,
        'Train_MAE': -cv_results['train_MAE'].mean(),
        'Val_MAE': -cv_results['test_MAE'].mean(),
        'Val_MAE_std': cv_results['test_MAE'].std(),
        'Train_RMSE': -cv_results['train_RMSE'].mean(),
        'Val_RMSE': -cv_results['test_RMSE'].mean(),
        'Train_R2': cv_results['train_R2'].mean(),
        'Val_R2': cv_results['test_R2'].mean()
    }
    final_results.append(results)
    print(f"{name}:")
    print(f"  Val MAE: {results['Val_MAE']:.2f} (+/- {results['Val_MAE_std']:.2f})")

final_comparison_df = pd.DataFrame(final_results).set_index('Model')
final_comparison_df.round(2).sort_values('Val_MAE')

# %%
best_model_name = final_comparison_df['Val_MAE'].idxmin()
best_model = final_models[best_model_name]

# %% [markdown]
# ### Model Selection Rationale
#
# Based on the final comparison:
#
# 1. **Random Forest (Tuned)** typically achieves the best validation MAE
# 2. The gap between train and validation scores indicates good generalization
# 3. Tree-based models (DT, RF) outperform linear models due to non-linear relationships
# 4. Neural Network performance is  ESCREVER AQUII
#
# We proceed with the best-performing model for deployment.

# %% [markdown]
# # Open-Ended Section
#
# ## Objectives
#
# 1. **Comparison of Imputation Strategies:** Analyze how different imputation strategies impacts model performance.
# 2. **Feature Importance Analysis:** Analyze how different features contribute to price predictions
# 3. **Brand-Specific Models:** Compare general model vs brand-specific models
# 4. **Prediction Interface:** Create an interactive prediction function

# %% [markdown]
# ##  Comparison of Imputation Strategies
#
# ### Objectives
#
# The objective of this section is to compare different imputation strategies and evaluate how the handling of missing values impacts model performance and stability.
# Given the presence of missing values and a large number of categorical variables, we aim to assess whether incorporating domain knowledge into the imputation process leads to improvements when compared to a more naive approach. Additionally, we assess whether increased imputation complexity or reduced sample size (through row removal) results in better model performance.
#
# ---
#
# ### Comparison of Different Imputation Strategies
#
# To isolate the effect of imputation decisions, multiple pipelines are defined where the modeling stage is kept fixed, and only the imputation strategy is modified.
#
# The following imputation approaches are compared:
#
# - **Pipeline A — Naive Global Imputation**
#   Missing values are imputed using global statistics only:
#   - Numerical features are filled with the global mean
#   - Categorical features are filled with the global mode
#
#   No grouping or domain-specific information is used.
#   This pipeline serves as a simple baseline.
#
# - **Pipeline B — Outlier and variable 'model' treatment**
#
#     Outlier treatment: log transformation was performed on high-skewness data, while the rest were handled using winsorization (capping and flooring).
#   Missing Values are imputed using global statistics:
#   - Numerical features are filled with the global mean
#   - Categorical features are filled with the global mode
#
#   'model' column rare observations are grouped as "other" before aplying one hot encoding to avoid high cardinality
#
#
# - **Pipeline C — Group-aware Imputation (Used in the project)**
#   Missing values are imputed using a hierarchical, domain-aware strategy:
#   - Imputation by *(brand, model)* group
#   - If not possible, imputation by *brand*
#   - As a fallback, global mean or mode is used
#   - mileage imputed by KNN
#
#   This approach represents the imputation strategy used throughout the rest of the project.
#
#
# - **Pipeline D — Model-based Imputation**
#   - 'model' missing values are imputed using baseline predictive models
#   - mileage imputed by KNN
#   - Other Variables imputed by mode within specific brand and model
#
#   This pipeline is included to evaluate whether increased imputation complexity
#
# All pipelines share the same encoding strategy, normalization method, and predictive model, ensuring that observed differences are driven solely by the imputation choices.

# %% [markdown]
# #### Pipeline A

# %%
numeric_pipeline_A = make_pipeline(
    SimpleImputer(strategy="mean"),
    Log1pSkewed(numeric_cols,log_candidates),
    RobustScaler()
)

categorical_pipe = make_pipeline(
    SimpleImputer(strategy="most_frequent"),
    OneHotEncoder(handle_unknown="ignore")
)

preprocessor_A = ColumnTransformer(
    transformers=[
        ("num", numeric_pipeline_A, numeric_cols),
        ("cat", categorical_pipe, categorical_cols)
    ]
)
pipe_preprocessor_A = Pipeline([("column_transformer", preprocessor_A)])

# %% [markdown]
# #### Pipeline B

# %%
numeric_pipeline_B = Pipeline([('winsor', CustomWinsorizer(variables=outlier_variable, lower_bound=0.01, upper_bound=0.99)), ("imputer", SimpleImputer(strategy="median")),Log1pSkewed(numeric_cols, log_candidates),  ("scaler", StandardScaler())])

cats_B = []

cats_B.append(("cat",
                 Pipeline([("fallback_impute", SimpleImputer(strategy="most_frequent")),
                           ("ohe", OneHotEncoder(handle_unknown="ignore", drop="first", sparse_output=False))]),
                without_model))
cats_B.append(("model_collap",
                 Pipeline([("select", ColumnSelector("model")),
                           ("fallback_impute", SimpleImputer(strategy="most_frequent")),
                           ("rare", RareLabelGrouper(min_prop=0.005, column="model")),
                           ("ohe", OneHotEncoder(handle_unknown="ignore", drop="first", sparse_output=False))]),
                 ["model"]))

# %%
preprocessor_B = ColumnTransformer([("num", numeric_pipeline_B, numeric_cols), *cats_B], remainder="drop")

pipe_preprocessor_B = Pipeline([("column_transformer", preprocessor_B)])

# %% [markdown]
# #### Pipeline D

# %%
numeric_pipeline_D =  Pipeline([
    ('winsor', CustomWinsorizer(variables=outlier_variable, lower_bound=0.01, upper_bound=0.99)),
    ("imputer", SimpleImputer(strategy="median")),
    ("log1p_skewed", Log1pSkewed(numeric_cols, log_candidates)),  
    ("scaler", StandardScaler())
])

categorical_pipeline_D = Pipeline(steps=[
    ('fallback_impute', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# %%
preprocessor_D = ColumnTransformer(
    transformers=[
        ('num', numeric_pipeline_D, numeric_cols),
        ('cat', categorical_pipeline_D, categorical_cols),
        ('model_freq', StandardScaler(), ['model']) 
    ]
)


pipe_preprocessor_D = Pipeline([
    ('impute_mileage_knn', KNNMileageImputer(n_neighbors=5)),
    ('inputer_model', HierarchicalModelImputer(target_col='model', group_col='brand')),
    ('freq_encoder', FrequencyEncoder(col='model')),
    ('preprocessor', preprocessor_D)
])

# %%
#Comparing different pipeline configurations

pipeline_configs = {
    'Pipeline A': pipe_preprocessor_A,
    'Pipeline B': pipe_preprocessor_B,
    'Pipeline C': pipe_preprocessor,
    'Pipeline D': pipe_preprocessor_D
}

pip_results = []
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

for name, pipeline in pipeline_configs.items():
    
    # Use best model for comparison
    model = Pipeline([
        ('prep', clone(PreprocessAndRemoveByName(pipeline, features_to_remove))),
        ('best_model', RandomForestRegressor(**best_param_rf))
    ])
    
    cv_scores = cross_val_score(
        model, X_train, y_train,
        cv=kfold,
        scoring='neg_mean_absolute_error',
        n_jobs=-1
    )
    
    results = {
        'Pipeline': name,
        'Mean_MAE': -cv_scores.mean(),
        'Std_MAE': cv_scores.std()
    }

    pip_results.append(results)
    print(f"  MAE: {-cv_scores.mean():.2f} (+/- {cv_scores.std():.2f})")

pip:df = pd.DataFrame(pip_results).set_index('Pipeline')
print("\n" + "Results:")
ablation_df.round(2)

# %%
# Visualize ablation results
fig, ax = plt.subplots(figsize=(10, 6))

x = np.arange(len(ablation_df))
bars = ax.bar(x, ablation_df['Mean_MAE'], yerr=ablation_df['Std_MAE'],
              capsize=5, color=['#3498db', '#2ecc71', '#f39c12', '#e74c3c'])

ax.set_xlabel('Pipeline Configuration')
ax.set_ylabel('Mean Absolute Error (£)')
ax.set_title('Pipeline Ablation Study - Impact on MAE')
ax.set_xticks(x)
ax.set_xticklabels(ablation_df.index, rotation=45, ha='right')

# Add value labels
for i, (v, e) in enumerate(zip(ablation_df['Mean_MAE'], ablation_df['Std_MAE'])):
    ax.text(i, v + e + 20, f'£{v:.0f}', ha='center', fontsize=10)

plt.tight_layout()
plt.savefig('pipeline_ablation.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Pipeline comparison findings

# %% [markdown]
# Escrever aqui!!!!

# %% [markdown]
# ## Feature Importance Analysis
#
#
#
# We analyze feature importance using the best Random Forest model to understand
#
# which features contribute most to price predictions.

# %%
# Extract feature importances from Random Forest

best_rf.fit(X_train, y_train)

try:
    prep_fitted = best_rf.named_steps['prep']
    feature_names = prep_fitted.named_steps['preprocessor'].get_feature_names_out()
except:
    feature_names = [f'feature_{i}' for i in range(len(best_rf.named_steps['rf'].feature_importances_))]

rf_importances = pd.DataFrame({
    'feature': feature_names,
    'importance': best_rf.named_steps['rf'].feature_importances_
}).sort_values('importance', ascending=False)

print(f"\nTotal features: {len(rf_importances)}")
print(f"\nTop 15 Most Important Features:")
rf_importances.head(15)

# %%
# Visualize feature importance
fig, ax = plt.subplots(figsize=(12, 8))

top_n = 20
top_features = rf_importances.head(top_n)

ax.barh(range(top_n), top_features['importance'], color='#2ecc71')
ax.set_yticks(range(top_n))
ax.set_yticklabels(top_features['feature'])
ax.invert_yaxis()
ax.set_xlabel('Feature Importance')
ax.set_title('Top 20 Features by Random Forest Importance')

plt.tight_layout()
plt.savefig('feature_importance_rf.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Feature Importance Insights
#
#
#
# Key findings from the feature importance analysis:
#
#
#
# 1. **Numeric features** (car_age, engineSize, mileage) are the strongest predictors
#
# 2. **Model** information provides significant predictive value
#
# 3. **Brand** contributes moderately to predictions
#
# 4. **Transmission and fuel type** have smaller but meaningful contributions

# %% [markdown]
# ## Brand-Specific vs General Model Comparison
#
#
#
# We investigate whether training separate models for each brand improves
#
# predictions compared to a single general model.

# %%
# Brand-Specific vs General Model Comparison

brand_counts = X_train['brand'].value_counts()
top_brands = brand_counts[brand_counts >= 1000].index.tolist()

brand_results = []
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

for brand in top_brands:    

    brand_mask = X_train['brand'] == brand
    X_brand = X_train[brand_mask]
    y_brand = y_train[brand_mask]
    
    brand_model = Pipeline([
        ('prep', clone(PreprocessAndRemoveByName(pipeline, features_to_remove))),
        ('rf', RandomForestRegressor(best_param_rf))
    ])
    
    brand_cv_scores = cross_val_score(
        brand_model, X_brand, y_brand,
        cv=kfold, scoring='neg_mean_absolute_error', n_jobs=-1
    )
    brand_mae = -brand_cv_scores.mean()
    
    general_cv_scores = cross_val_score(
        best_rf, X_brand, y_brand,
        cv=kfold, scoring='neg_mean_absolute_error', n_jobs=-1
    )
    general_mae = -general_cv_scores.mean()
    
    brand_results.append({
        'Brand': brand,
        'N_Samples': len(X_brand),
        'Brand_Specific_MAE': round(brand_mae, 2),
        'General_Model_MAE': round(general_mae, 2),
        'Improvement': round(general_mae - brand_mae, 2)
    })
    
    print(f"  Brand-specific MAE: {brand_mae:.2f}, General MAE: {general_mae:.2f}")

brand_comparison_df = pd.DataFrame(brand_results)
brand_comparison_df.sort_values('Improvement', ascending=False)

# %% [markdown]
# ### Brand-Specific Model Insights

# %% [markdown]
# ## Prediction Interface
#
#
#
# Creating an interactive prediction function for deployment.

# %%
def predict_car_price(model, car_data):
    '''
    Predict the price of a car based on its specifications.
    
    Parameters:
    -----------
    model : fitted sklearn pipeline
        The trained model pipeline
    car_data : dict
        Dictionary containing car specifications
    
    Returns:
    --------
    float : Predicted price
    '''
    df = pd.DataFrame([car_data])
    
    # Make prediction
    prediction = model.predict(df)[0]
    
    return round(prediction, 2)

# %%
# Example predictions
example_cars = [
    {
        'carID': 99999,
        'brand': 'bmw',
        'model': '3 series',
        'transmission': 'automatic',
        'mileage': 25000,
        'fuelType': 'diesel',
        'tax': 145,
        'mpg': 55.4,
        'engineSize': 2.0,
        'paintQuality%': 75,
        'previousOwners': 2,
        'hasDamage': 0,
        'car_age': 3
    },
    {
        'carID': 99998,
        'brand': 'ford',
        'model': 'fiesta',
        'transmission': 'manual',
        'mileage': 45000,
        'fuelType': 'petrol',
        'tax': 145,
        'mpg': 65.7,
        'engineSize': 1.0,
        'paintQuality%': 60,
        'previousOwners': 3,
        'hasDamage': 0,
        'car_age': 5
    },
    {
        'carID': 99997,
        'brand': 'audi',
        'model': 'a4',
        'transmission': 'semi-auto',
        'mileage': 15000,
        'fuelType': 'diesel',
        'tax': 145,
        'mpg': 60.1,
        'engineSize': 2.0,
        'paintQuality%': 85,
        'previousOwners': 1,
        'hasDamage': 0,
        'car_age': 2
    }
]

for i, car in enumerate(example_cars, 1):
    predicted_price = predict_car_price(best_model, car)
    print(f"\nCar {i}: {car['brand'].upper()} {car['model'].title()}")
    print(f" Age: {car['car_age']} years")
    print(f" Mileage: {car['mileage']:,} miles")
    print(f" Engine: {car['engineSize']}L {car['fuelType']}")
    print(f" Transmission: {car['transmission']}")
    print(f" Predicted Price: {predicted_price:,.2f}")

# %% [markdown]
# # Deployment
#
#
#
# ## Final Model Training
#
#
#
# Train the final model on the complete training dataset for deployment.

# %%
final_model = clone(best_model)

final_model.fit(X, y)

# %%
# Save the model
joblib.dump(final_model, 'final_model.pkl')

# %% [markdown]
# ## Summary and Conclusions
#
#
#
# ### Key Findings
#
#
#
# 1. **Best Performing Model**: Random Forest with optimized hyperparameters achieved the lowest validation MAE???????
#
# 2. **Most Important Features**:
# COLOCAR TEXTOOOOO
#
#
# 3. **Preprocessing Strategy**:
#
#
#
# 5. **Model Performance**:
