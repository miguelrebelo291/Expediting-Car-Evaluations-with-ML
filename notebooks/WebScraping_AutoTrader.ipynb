# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd
import time

# %% [markdown]
# Open driver e get url of website

# %%
URL = "https://www.autotrader.co.uk/cars"

driver = webdriver.Chrome()
driver.get(URL)

# %%
#Reject cookies
driver.implicitly_wait(10)
frame_0 = driver.find_element(By.CSS_SELECTOR, "iframe[src='https://cmpv2.autotrader.co.uk/index.html?message_id=1371540&consentUUID=undefined&preload_message=true&hasCsp=true&version=v1&consent_origin=https%3A%2F%2Fcmpv2.autotrader.co.uk%2Fconsent%2Ftcfv2&mms_origin=https%3A%2F%2Fcmpv2.autotrader.co.uk%2Fmms%2Fv2']")
driver.switch_to.frame(frame_0)
No_cookies = driver.find_element(By.XPATH, "//button[contains(text(), 'Reject All')]")
No_cookies.click()

# %%
driver.switch_to.default_content()

# %% [markdown]
# Scrap the form in website to first get all the make (brands) and then for each make get all the models

# %%
make_select = Select(WebDriverWait(driver, 20).until(
    EC.presence_of_element_located((By.ID, "make"))
))
makes = [(opt.get_attribute("value"))
         for opt in make_select.options
         if opt.text.strip()]

# %%
rows = []

# %%
for val in makes:
    make_select = Select(WebDriverWait(driver, 20).until(
    EC.presence_of_element_located((By.ID, "make"))
))
    make_select.select_by_value(val)
    time.sleep(1.2)

    model_select = Select(WebDriverWait(driver, 20).until(
    EC.presence_of_element_located((By.ID, "model"))
))
    models = [o.get_attribute("value") for o in model_select.options
              if o.text.strip() and o.text.strip().lower() not in {"any","todas","todos","selecionar"}]

    for md in models:
        rows.append({"make": val, "model": md})

driver.quit()

# %%
rows
# Out:
# [{'make': 'Abarth', 'model': '124 Spider'},
#  {'make': 'Abarth', 'model': '500'},
#  {'make': 'Abarth', 'model': '500C'},
#  {'make': 'Abarth', 'model': '500e'},
#  {'make': 'Abarth', 'model': '500e C'},
#  {'make': 'Abarth', 'model': '595'},
#  {'make': 'Abarth', 'model': '595C'},
#  {'make': 'Abarth', 'model': '600e'},
#  {'make': 'Abarth', 'model': '695'},
#  {'make': 'Abarth', 'model': '695C'},
#  {'make': 'Abarth', 'model': 'Grande Punto'},
#  {'make': 'Abarth', 'model': 'Punto Evo'},
#  {'make': 'AC', 'model': 'Cobra'},
#  {'make': 'AC', 'model': 'Dax Cobra'},
#  {'make': 'Aixam', 'model': 'Coupe'},
#  {'make': 'AK', 'model': 'Cobra'},
#  {'make': 'Alfa Romeo', 'model': '145'},
#  {'make': 'Alfa Romeo', 'model': '147'},
#  {'make': 'Alfa Romeo', 'model': '156'},
#  {'make': 'Alfa Romeo', 'model': '159'},
#  {'make': 'Alfa Romeo', 'model': '159 Sportwagon'},
#  {'make': 'Alfa Romeo', 'model': '164'},
#  {'make': 'Alfa Romeo', 'model': '2000'},
#  {'make': 'Alfa Romeo', 'model': '4C'},
#  {'make': 'Alfa Romeo', 'model': '75'},
#  {'make': 'Alfa Romeo', 'model': '8C'},
#  {'make': 'Alfa Romeo', 'model': 'Alfasud'},
#  {'make': 'Alfa Romeo', 'model': 'Brera'},
#  {'make': 'Alfa Romeo', 'model': 'Giulia'},
#  {'make': 'Alfa Romeo', 'model': 'Giulietta'},
#  {'make': 'Alfa Romeo', 'model': 'GT'},
#  {'make': 'Alfa Romeo', 'model': 'GTV'},
#  {'make': 'Alfa Romeo', 'model': 'Junior'},
#  {'make': 'Alfa Romeo', 'model': 'MiTo'},
#  {'make': 'Alfa Romeo', 'model': 'Spider'},
#  {'make': 'Alfa Romeo', 'model': 'Stelvio'},
#  {'make': 'Alfa Romeo', 'model': 'Tonale'},
#  {'make': 'Allard', 'model': 'L Type Tourer'},
#  {'make': 'Alpine', 'model': 'A110'},
#  {'make': 'Alpine', 'model': 'A290'},
#  {'make': 'Alvis', 'model': 'Ellis Tourer'},
#  {'make': 'Ariel', 'model': 'Atom'},
#  {'make': 'Ariel', 'model': 'Atom 4'},
#  {'make': 'Ariel', 'model': 'Nomad'},
#  {'make': 'Aston Martin', 'model': 'Cygnet'},
#  {'make': 'Aston Martin', 'model': 'DB11'},
#  {'make': 'Aston Martin', 'model': 'DB12'},
#  {'make': 'Aston Martin', 'model': 'DB2'},
#  {'make': 'Aston Martin', 'model': 'DB4'},
#  {'make': 'Aston Martin', 'model': 'DB5'},
#  {'make': 'Aston Martin', 'model': 'DB6'},
#  {'make': 'Aston Martin', 'model': 'DB7'},
#  {'make': 'Aston Martin', 'model': 'DB9'},
#  {'make': 'Aston Martin', 'model': 'DB AR1'},
#  {'make': 'Aston Martin', 'model': 'DBS'},
#  {'make': 'Aston Martin', 'model': 'DBX'},
#  {'make': 'Aston Martin', 'model': 'Rapide'},
#  {'make': 'Aston Martin', 'model': 'Rapide S'},
#  {'make': 'Aston Martin', 'model': 'V12 Zagato'},
#  {'make': 'Aston Martin', 'model': 'V8'},
#  {'make': 'Aston Martin', 'model': 'Valkyrie'},
#  {'make': 'Aston Martin', 'model': 'Vanquish'},
#  {'make': 'Aston Martin', 'model': 'Vantage'},
#  {'make': 'Aston Martin', 'model': 'Vantage N400'},
#  {'make': 'Aston Martin', 'model': 'Virage'},
#  {'make': 'Aston Martin', 'model': 'Vulcan'},
#  {'make': 'Audi', 'model': '100'},
#  {'make': 'Audi', 'model': '80'},
#  {'make': 'Audi', 'model': '90'},
#  {'make': 'Audi', 'model': 'A1'},
#  {'make': 'Audi', 'model': 'A2'},
#  {'make': 'Audi', 'model': 'A3'},
#  {'make': 'Audi', 'model': 'A3 Cabriolet'},
#  {'make': 'Audi', 'model': 'A4'},
#  {'make': 'Audi', 'model': 'A4 Allroad'},
#  {'make': 'Audi', 'model': 'A4 Avant'},
#  {'make': 'Audi', 'model': 'A4 Cabriolet'},
#  {'make': 'Audi', 'model': 'A5'},
#  {'make': 'Audi', 'model': 'A5 Avant'},
#  {'make': 'Audi', 'model': 'A5 Cabriolet'},
#  {'make': 'Audi', 'model': 'A6 Allroad'},
#  {'make': 'Audi', 'model': 'A6 Avant'},
#  {'make': 'Audi', 'model': 'A6 e-tron Avant'},
#  {'make': 'Audi', 'model': 'A6 e-tron Sportback'},
#  {'make': 'Audi', 'model': 'A6 Saloon'},
#  {'make': 'Audi', 'model': 'A6 Unspecified'},
#  {'make': 'Audi', 'model': 'A7'},
#  {'make': 'Audi', 'model': 'A8'},
#  {'make': 'Audi', 'model': 'Cabriolet'},
#  {'make': 'Audi', 'model': 'Coupe'},
#  {'make': 'Audi', 'model': 'e-tron'},
#  {'make': 'Audi', 'model': 'e-tron GT'},
#  {'make': 'Audi', 'model': 'e-tron S'},
#  {'make': 'Audi', 'model': 'Q2'},
#  {'make': 'Audi', 'model': 'Q3'},
#  {'make': 'Audi', 'model': 'Q4 e-tron'},
#  {'make': 'Audi', 'model': 'Q5'},
#  {'make': 'Audi', 'model': 'Q6 e-tron'},
#  {'make': 'Audi', 'model': 'Q7'},
#  {'make': 'Audi', 'model': 'Q8'},
#  {'make': 'Audi', 'model': 'Q8 e-tron'},
#  {'make': 'Audi', 'model': 'quattro'},
#  {'make': 'Audi', 'model': 'R8'},
#  {'make': 'Audi', 'model': 'RS3'},
#  {'make': 'Audi', 'model': 'RS4'},
#  {'make': 'Audi', 'model': 'RS4 Avant'},
#  {'make': 'Audi', 'model': 'RS4 Cabriolet'},
#  {'make': 'Audi', 'model': 'RS5'},
#  {'make': 'Audi', 'model': 'RS6'},
#  {'make': 'Audi', 'model': 'RS6 Avant'},
#  {'make': 'Audi', 'model': 'RS7'},
#  {'make': 'Audi', 'model': 'RS e-tron GT'},
#  {'make': 'Audi', 'model': 'RS Q3'},
#  {'make': 'Audi', 'model': 'RSQ8'},
#  {'make': 'Audi', 'model': 'S1'},
#  {'make': 'Audi', 'model': 'S3'},
#  {'make': 'Audi', 'model': 'S4'},
#  {'make': 'Audi', 'model': 'S4 Avant'},
#  {'make': 'Audi', 'model': 'S4 Cabriolet'},
#  {'make': 'Audi', 'model': 'S5'},
#  {'make': 'Audi', 'model': 'S5 Avant'},
#  {'make': 'Audi', 'model': 'S6 Avant'},
#  {'make': 'Audi', 'model': 'S6 e-tron Avant'},
#  {'make': 'Audi', 'model': 'S6 e-tron Sportback'},
#  {'make': 'Audi', 'model': 'S6 Saloon'},
#  {'make': 'Audi', 'model': 'S7'},
#  {'make': 'Audi', 'model': 'S8'},
#  {'make': 'Audi', 'model': 'S e-tron GT'},
#  {'make': 'Audi', 'model': 'SQ2'},
#  {'make': 'Audi', 'model': 'SQ5'},
#  {'make': 'Audi', 'model': 'SQ6 e-tron'},
#  {'make': 'Audi', 'model': 'SQ7'},
#  {'make': 'Audi', 'model': 'SQ8'},
#  {'make': 'Audi', 'model': 'SQ8 e-tron'},
#  {'make': 'Audi', 'model': 'TT'},
#  {'make': 'Audi', 'model': 'TT RS'},
#  {'make': 'Audi', 'model': 'TTS'},
#  {'make': 'Austin', 'model': 'Ambassador'},
#  {'make': 'Austin', 'model': 'Healey'},
#  {'make': 'Austin', 'model': 'Maestro'},
#  {'make': 'Austin', 'model': 'Mini'},
#  {'make': 'Austin', 'model': 'Mini Cooper S'},
#  {'make': 'Austin', 'model': 'Mini Moke'},
#  {'make': 'Austin', 'model': 'Seven'},
#  {'make': 'Austin', 'model': 'Twelve'},
#  {'make': 'BAC', 'model': 'Mono'},
#  {'make': 'Beauford', 'model': 'Open Tourer'},
#  {'make': 'Beauford', 'model': 'Series 3'},
#  {'make': 'Bentley', 'model': 'Arnage'},
#  {'make': 'Bentley', 'model': 'Azure'},
#  {'make': 'Bentley', 'model': 'Bentayga'},
#  {'make': 'Bentley', 'model': 'Brooklands'},
#  {'make': 'Bentley', 'model': 'Continental'},
#  {'make': 'Bentley', 'model': 'Eight'},
#  {'make': 'Bentley', 'model': 'Flying Spur'},
#  {'make': 'Bentley', 'model': 'Mulsanne'},
#  {'make': 'Bentley', 'model': 'Series III'},
#  {'make': 'Bentley', 'model': 'Turbo R'},
#  {'make': 'Bentley', 'model': 'Turbo RT'},
#  {'make': 'BMW', 'model': 'Arnage'},
#  {'make': 'BMW', 'model': '1 Series'},
#  {'make': 'BMW', 'model': '2002'},
#  {'make': 'BMW', 'model': '2 Series'},
#  {'make': 'BMW', 'model': '2 Series Active Tourer'},
#  {'make': 'BMW', 'model': '2 Series Gran Coupe'},
#  {'make': 'BMW', 'model': '2 Series Gran Tourer'},
#  {'make': 'BMW', 'model': '3 Series'},
#  {'make': 'BMW', 'model': '3 Series Gran Turismo'},
#  {'make': 'BMW', 'model': '4 Series'},
#  {'make': 'BMW', 'model': '4 Series Gran Coupe'},
#  {'make': 'Bowler', 'model': 'Defender 90'},
#  {'make': 'Bugatti', 'model': 'Chiron'},
#  {'make': 'Bugatti', 'model': 'Type'},
#  {'make': 'Bugatti', 'model': 'Veyron'},
#  {'make': 'Abarth', 'model': '124 Spider'},
#  {'make': 'Abarth', 'model': '500'},
#  {'make': 'Abarth', 'model': '500C'},
#  {'make': 'Abarth', 'model': '500e'},
#  {'make': 'Abarth', 'model': '500e C'},
#  {'make': 'Abarth', 'model': '595'},
#  {'make': 'Abarth', 'model': '595C'},
#  {'make': 'Abarth', 'model': '600e'},
#  {'make': 'Abarth', 'model': '695'},
#  {'make': 'Abarth', 'model': '695C'},
#  {'make': 'Abarth', 'model': 'Grande Punto'},
#  {'make': 'Abarth', 'model': 'Punto Evo'},
#  {'make': 'AC', 'model': 'Cobra'},
#  {'make': 'AC', 'model': 'Dax Cobra'},
#  {'make': 'Aixam', 'model': 'Coupe'},
#  {'make': 'AK', 'model': 'Cobra'},
#  {'make': 'Alfa Romeo', 'model': '145'},
#  {'make': 'Alfa Romeo', 'model': '147'},
#  {'make': 'Alfa Romeo', 'model': '156'},
#  {'make': 'Alfa Romeo', 'model': '159'},
#  {'make': 'Alfa Romeo', 'model': '159 Sportwagon'},
#  {'make': 'Alfa Romeo', 'model': '164'},
#  {'make': 'Alfa Romeo', 'model': '2000'},
#  {'make': 'Alfa Romeo', 'model': '4C'},
#  {'make': 'Alfa Romeo', 'model': '75'},
#  {'make': 'Alfa Romeo', 'model': '8C'},
#  {'make': 'Alfa Romeo', 'model': 'Alfasud'},
#  {'make': 'Alfa Romeo', 'model': 'Brera'},
#  {'make': 'Alfa Romeo', 'model': 'Giulia'},
#  {'make': 'Alfa Romeo', 'model': 'Giulietta'},
#  {'make': 'Alfa Romeo', 'model': 'GT'},
#  {'make': 'Alfa Romeo', 'model': 'GTV'},
#  {'make': 'Alfa Romeo', 'model': 'Junior'},
#  {'make': 'Alfa Romeo', 'model': 'MiTo'},
#  {'make': 'Alfa Romeo', 'model': 'Spider'},
#  {'make': 'Alfa Romeo', 'model': 'Stelvio'},
#  {'make': 'Alfa Romeo', 'model': 'Tonale'},
#  {'make': 'Allard', 'model': 'L Type Tourer'},
#  {'make': 'Alpine', 'model': 'A110'},
#  {'make': 'Alpine', 'model': 'A290'},
#  {'make': 'Alvis', 'model': 'Ellis Tourer'},
#  {'make': 'Ariel', 'model': 'Atom'},
#  {'make': 'Ariel', 'model': 'Atom 4'},
#  {'make': 'Ariel', 'model': 'Nomad'},
#  {'make': 'Aston Martin', 'model': 'Cygnet'},
#  {'make': 'Aston Martin', 'model': 'DB11'},
#  {'make': 'Aston Martin', 'model': 'DB12'},
#  {'make': 'Aston Martin', 'model': 'DB2'},
#  {'make': 'Aston Martin', 'model': 'DB4'},
#  {'make': 'Aston Martin', 'model': 'DB5'},
#  {'make': 'Aston Martin', 'model': 'DB6'},
#  {'make': 'Aston Martin', 'model': 'DB7'},
#  {'make': 'Aston Martin', 'model': 'DB9'},
#  {'make': 'Aston Martin', 'model': 'DB AR1'},
#  {'make': 'Aston Martin', 'model': 'DBS'},
#  {'make': 'Aston Martin', 'model': 'DBX'},
#  {'make': 'Aston Martin', 'model': 'Rapide'},
#  {'make': 'Aston Martin', 'model': 'Rapide S'},
#  {'make': 'Aston Martin', 'model': 'V12 Zagato'},
#  {'make': 'Aston Martin', 'model': 'V8'},
#  {'make': 'Aston Martin', 'model': 'Valkyrie'},
#  {'make': 'Aston Martin', 'model': 'Vanquish'},
#  {'make': 'Aston Martin', 'model': 'Vantage'},
#  {'make': 'Aston Martin', 'model': 'Vantage N400'},
#  {'make': 'Aston Martin', 'model': 'Virage'},
#  {'make': 'Aston Martin', 'model': 'Vulcan'},
#  {'make': 'Audi', 'model': '100'},
#  {'make': 'Audi', 'model': '80'},
#  {'make': 'Audi', 'model': '90'},
#  {'make': 'Audi', 'model': 'A1'},
#  {'make': 'Audi', 'model': 'A2'},
#  {'make': 'Audi', 'model': 'A3'},
#  {'make': 'Audi', 'model': 'A3 Cabriolet'},
#  {'make': 'Audi', 'model': 'A4'},
#  {'make': 'Audi', 'model': 'A4 Allroad'},
#  {'make': 'Audi', 'model': 'A4 Avant'},
#  {'make': 'Audi', 'model': 'A4 Cabriolet'},
#  {'make': 'Audi', 'model': 'A5'},
#  {'make': 'Audi', 'model': 'A5 Avant'},
#  {'make': 'Audi', 'model': 'A5 Cabriolet'},
#  {'make': 'Audi', 'model': 'A6 Allroad'},
#  {'make': 'Audi', 'model': 'A6 Avant'},
#  {'make': 'Audi', 'model': 'A6 e-tron Avant'},
#  {'make': 'Audi', 'model': 'A6 e-tron Sportback'},
#  {'make': 'Audi', 'model': 'A6 Saloon'},
#  {'make': 'Audi', 'model': 'A6 Unspecified'},
#  {'make': 'Audi', 'model': 'A7'},
#  {'make': 'Audi', 'model': 'A8'},
#  {'make': 'Audi', 'model': 'Cabriolet'},
#  {'make': 'Audi', 'model': 'Coupe'},
#  {'make': 'Audi', 'model': 'e-tron'},
#  {'make': 'Audi', 'model': 'e-tron GT'},
#  {'make': 'Audi', 'model': 'e-tron S'},
#  {'make': 'Audi', 'model': 'Q2'},
#  {'make': 'Audi', 'model': 'Q3'},
#  {'make': 'Audi', 'model': 'Q4 e-tron'},
#  {'make': 'Audi', 'model': 'Q5'},
#  {'make': 'Audi', 'model': 'Q6 e-tron'},
#  {'make': 'Audi', 'model': 'Q7'},
#  {'make': 'Audi', 'model': 'Q8'},
#  {'make': 'Audi', 'model': 'Q8 e-tron'},
#  {'make': 'Audi', 'model': 'quattro'},
#  {'make': 'Audi', 'model': 'R8'},
#  {'make': 'Audi', 'model': 'RS3'},
#  {'make': 'Audi', 'model': 'RS4'},
#  {'make': 'Audi', 'model': 'RS4 Avant'},
#  {'make': 'Audi', 'model': 'RS4 Cabriolet'},
#  {'make': 'Audi', 'model': 'RS5'},
#  {'make': 'Audi', 'model': 'RS6'},
#  {'make': 'Audi', 'model': 'RS6 Avant'},
#  {'make': 'Audi', 'model': 'RS7'},
#  {'make': 'Audi', 'model': 'RS e-tron GT'},
#  {'make': 'Audi', 'model': 'RS Q3'},
#  {'make': 'Audi', 'model': 'RSQ8'},
#  {'make': 'Audi', 'model': 'S1'},
#  {'make': 'Audi', 'model': 'S3'},
#  {'make': 'Audi', 'model': 'S4'},
#  {'make': 'Audi', 'model': 'S4 Avant'},
#  {'make': 'Audi', 'model': 'S4 Cabriolet'},
#  {'make': 'Audi', 'model': 'S5'},
#  {'make': 'Audi', 'model': 'S5 Avant'},
#  {'make': 'Audi', 'model': 'S6 Avant'},
#  {'make': 'Audi', 'model': 'S6 e-tron Avant'},
#  {'make': 'Audi', 'model': 'S6 e-tron Sportback'},
#  {'make': 'Audi', 'model': 'S6 Saloon'},
#  {'make': 'Audi', 'model': 'S7'},
#  {'make': 'Audi', 'model': 'S8'},
#  {'make': 'Audi', 'model': 'S e-tron GT'},
#  {'make': 'Audi', 'model': 'SQ2'},
#  {'make': 'Audi', 'model': 'SQ5'},
#  {'make': 'Audi', 'model': 'SQ6 e-tron'},
#  {'make': 'Audi', 'model': 'SQ7'},
#  {'make': 'Audi', 'model': 'SQ8'},
#  {'make': 'Audi', 'model': 'SQ8 e-tron'},
#  {'make': 'Audi', 'model': 'TT'},
#  {'make': 'Audi', 'model': 'TT RS'},
#  {'make': 'Audi', 'model': 'TTS'},
#  {'make': 'Austin', 'model': 'Ambassador'},
#  {'make': 'Austin', 'model': 'Healey'},
#  {'make': 'Austin', 'model': 'Maestro'},
#  {'make': 'Austin', 'model': 'Mini'},
#  {'make': 'Austin', 'model': 'Mini Cooper S'},
#  {'make': 'Austin', 'model': 'Mini Moke'},
#  {'make': 'Austin', 'model': 'Seven'},
#  {'make': 'Austin', 'model': 'Twelve'},
#  {'make': 'BAC', 'model': 'Mono'},
#  {'make': 'Beauford', 'model': 'Open Tourer'},
#  {'make': 'Beauford', 'model': 'Series 3'},
#  {'make': 'Bentley', 'model': 'Arnage'},
#  {'make': 'Bentley', 'model': 'Azure'},
#  {'make': 'Bentley', 'model': 'Bentayga'},
#  {'make': 'Bentley', 'model': 'Brooklands'},
#  {'make': 'Bentley', 'model': 'Continental'},
#  {'make': 'Bentley', 'model': 'Eight'},
#  {'make': 'Bentley', 'model': 'Flying Spur'},
#  {'make': 'Bentley', 'model': 'Mulsanne'},
#  {'make': 'Bentley', 'model': 'Series III'},
#  {'make': 'Bentley', 'model': 'Turbo R'},
#  {'make': 'Bentley', 'model': 'Turbo RT'},
#  {'make': 'BMW', 'model': '1602'},
#  {'make': 'BMW', 'model': '1 Series'},
#  {'make': 'BMW', 'model': '2002'},
#  {'make': 'BMW', 'model': '2 Series'},
#  {'make': 'BMW', 'model': '2 Series Active Tourer'},
#  {'make': 'BMW', 'model': '2 Series Gran Coupe'},
#  {'make': 'BMW', 'model': '2 Series Gran Tourer'},
#  {'make': 'BMW', 'model': '3 Series'},
#  {'make': 'BMW', 'model': '3 Series Gran Turismo'},
#  {'make': 'BMW', 'model': '4 Series'},
#  {'make': 'BMW', 'model': '4 Series Gran Coupe'},
#  {'make': 'BMW', 'model': '5 Series'},
#  {'make': 'BMW', 'model': '5 Series Gran Turismo'},
#  {'make': 'BMW', 'model': '6 Series'},
#  {'make': 'BMW', 'model': '6 Series Gran Coupe'},
#  {'make': 'BMW', 'model': '6 Series Gran Turismo'},
#  {'make': 'BMW', 'model': '7 Series'},
#  {'make': 'BMW', 'model': '8 Series'},
#  {'make': 'BMW', 'model': '8 Series Gran Coupe'},
#  {'make': 'BMW', 'model': 'Alpina B10'},
#  {'make': 'BMW', 'model': 'Alpina B12'},
#  {'make': 'BMW', 'model': 'Alpina B3'},
#  {'make': 'BMW', 'model': 'Alpina B3 GT3'},
#  {'make': 'BMW', 'model': 'Alpina B4'},
#  {'make': 'BMW', 'model': 'Alpina B4 Gran Coupe'},
#  {'make': 'BMW', 'model': 'Alpina B5'},
#  {'make': 'BMW', 'model': 'Alpina B7'},
#  {'make': 'BMW', 'model': 'Alpina B8 Gran Coupe'},
#  {'make': 'BMW', 'model': 'Alpina D3'},
#  {'make': 'BMW', 'model': 'Alpina D5'},
#  {'make': 'BMW', 'model': 'Alpina Roadster'},
#  {'make': 'BMW', 'model': 'Alpina XB7'},
#  {'make': 'BMW', 'model': 'Alpina XD3'},
#  {'make': 'BMW', 'model': 'i3'},
#  {'make': 'BMW', 'model': 'i4'},
#  {'make': 'BMW', 'model': 'i5'},
#  {'make': 'BMW', 'model': 'i7'},
#  {'make': 'BMW', 'model': 'i8'},
#  {'make': 'BMW', 'model': 'iX'},
#  {'make': 'BMW', 'model': 'iX1'},
#  {'make': 'BMW', 'model': 'iX2'},
#  {'make': 'BMW', 'model': 'iX3'},
#  {'make': 'BMW', 'model': 'M2'},
#  {'make': 'BMW', 'model': 'M3'},
#  {'make': 'BMW', 'model': 'M4'},
#  {'make': 'BMW', 'model': 'M5'},
#  {'make': 'BMW', 'model': 'M6'},
#  {'make': 'BMW', 'model': 'M6 Gran Coupe'},
#  {'make': 'BMW', 'model': 'M8'},
#  {'make': 'BMW', 'model': 'M8 Gran Coupe'},
#  {'make': 'BMW', 'model': 'X1'},
#  {'make': 'BMW', 'model': 'X2'},
#  {'make': 'BMW', 'model': 'X3'},
#  {'make': 'BMW', 'model': 'X3 M'},
#  {'make': 'BMW', 'model': 'X4'},
#  {'make': 'BMW', 'model': 'X4 M'},
#  {'make': 'BMW', 'model': 'X5'},
#  {'make': 'BMW', 'model': 'X5 M'},
#  {'make': 'BMW', 'model': 'X6'},
#  {'make': 'BMW', 'model': 'X6 M'},
#  {'make': 'BMW', 'model': 'X7'},
#  {'make': 'BMW', 'model': 'XM'},
#  {'make': 'BMW', 'model': 'Z1'},
#  {'make': 'BMW', 'model': 'Z3'},
#  {'make': 'BMW', 'model': 'Z3 M'},
#  {'make': 'BMW', 'model': 'Z4'},
#  {'make': 'BMW', 'model': 'Z4 M'},
#  {'make': 'BMW', 'model': 'Z8'},
#  {'make': 'Bowler', 'model': 'Defender 90'},
#  {'make': 'Bugatti', 'model': 'Chiron'},
#  {'make': 'Bugatti', 'model': 'Type'},
#  {'make': 'Bugatti', 'model': 'Veyron'},
#  {'make': 'Buick', 'model': 'Skylark'},
#  {'make': 'BYD', 'model': 'Atto 2'},
#  {'make': 'BYD', 'model': 'Atto 3'},
#  {'make': 'BYD', 'model': 'Dolphin'},
#  {'make': 'BYD', 'model': 'Dolphin Surf'},
#  {'make': 'BYD', 'model': 'Seal'},
#  {'make': 'BYD', 'model': 'Sealion 7'},
#  {'make': 'BYD', 'model': 'Seal U'},
#  {'make': 'Cadillac', 'model': 'Allante'},
#  {'make': 'Cadillac', 'model': 'CTS'},
#  {'make': 'Cadillac', 'model': 'De Ville'},
#  {'make': 'Cadillac', 'model': 'Escalade'},
#  {'make': 'Cadillac', 'model': 'STS'},
#  {'make': 'Caterham', 'model': 'CSR'},
#  {'make': 'Caterham', 'model': 'Seven'},
#  {'make': 'Caterham', 'model': 'Seven 170 R'},
#  {'make': 'Caterham', 'model': 'Seven 170 S'},
#  {'make': 'Caterham', 'model': 'Super Seven Convertible'},
#  {'make': 'Caterham', 'model': 'Super Seven Sports 2Dr'},
#  {'make': 'CFMOTO', 'model': 'ZFORCE 1000 SPORT'},
#  {'make': 'Changan', 'model': 'Deepal S07'},
#  {'make': 'Chery', 'model': 'Tiggo 7'},
#  {'make': 'Chery', 'model': 'Tiggo 8'},
#  {'make': 'Chesil', 'model': 'Speedster'},
#  {'make': 'Chevrolet', 'model': '210'},
#  {'make': 'Chevrolet', 'model': '3100'},
#  {'make': 'Chevrolet', 'model': 'Astro'},
#  {'make': 'Chevrolet', 'model': 'Aveo'},
#  {'make': 'Chevrolet', 'model': 'Belair'},
#  {'make': 'Chevrolet', 'model': 'C20'},
#  {'make': 'Chevrolet', 'model': 'Camaro'},
#  {'make': 'Chevrolet', 'model': 'Captiva'},
#  {'make': 'Chevrolet', 'model': 'Corvette'},
#  {'make': 'Chevrolet', 'model': 'Corvette E-Ray'},
#  {'make': 'Chevrolet', 'model': 'Corvette Stingray'},
#  {'make': 'Chevrolet', 'model': 'Corvette Z06'},
#  {'make': 'Chevrolet', 'model': 'Cruze'},
#  {'make': 'Chevrolet', 'model': 'GMC'},
#  {'make': 'Chevrolet', 'model': 'Kalos'},
#  {'make': 'Chevrolet', 'model': 'Lacetti'},
#  {'make': 'Chevrolet', 'model': 'Matiz'},
#  {'make': 'Chevrolet', 'model': 'Orlando'},
#  {'make': 'Chevrolet', 'model': 'Silverado'},
#  {'make': 'Chevrolet', 'model': 'Spark'},
#  {'make': 'Chevrolet', 'model': 'SSR'},
#  {'make': 'Chevrolet', 'model': 'Suburban'},
#  {'make': 'Chevrolet', 'model': 'Trax'},
#  {'make': 'Chevrolet', 'model': 'Volt'},
#  {'make': 'Chrysler', 'model': '300C'},
#  {'make': 'Chrysler', 'model': 'Crossfire'},
#  {'make': 'Chrysler', 'model': 'Delta'},
#  {'make': 'Chrysler', 'model': 'Grand Voyager'},
#  {'make': 'Chrysler', 'model': 'Neon'},
#  {'make': 'Chrysler', 'model': 'PT Cruiser'},
#  {'make': 'Chrysler', 'model': 'Sebring'},
#  {'make': 'Chrysler', 'model': 'Voyager'},
#  {'make': 'Chrysler', 'model': 'Windsor'},
#  {'make': 'Chrysler', 'model': 'Ypsilon'},
#  {'make': 'Citroen', 'model': '12/24 Touring'},
#  {'make': 'Citroen', 'model': '2 CV'},
#  {'make': 'Citroen', 'model': 'Ami'},
#  {'make': 'Citroen', 'model': 'AX'},
#  {'make': 'Citroen', 'model': 'Berlingo'},
#  {'make': 'Citroen', 'model': 'C1'},
#  {'make': 'Citroen', 'model': 'C2'},
#  {'make': 'Citroen', 'model': 'C3'},
#  {'make': 'Citroen', 'model': 'C3 Aircross'},
#  {'make': 'Citroen', 'model': 'C3 Picasso'},
#  {'make': 'Citroen', 'model': 'C3 Pluriel'},
#  {'make': 'Citroen', 'model': 'C4'},
#  {'make': 'Citroen', 'model': 'C4 Cactus'},
#  {'make': 'Citroen', 'model': 'C4 Picasso'},
#  {'make': 'Citroen', 'model': 'C4 SpaceTourer'},
#  {'make': 'Citroen', 'model': 'C4 X'},
#  {'make': 'Citroen', 'model': 'C5'},
#  {'make': 'Citroen', 'model': 'C5 Aircross'},
#  {'make': 'Citroen', 'model': 'C5 X'},
#  {'make': 'Citroen', 'model': 'C6'},
#  {'make': 'Citroen', 'model': 'C8'},
#  {'make': 'Citroen', 'model': 'C-Crosser'},
#  {'make': 'Citroen', 'model': 'C-Zero'},
#  {'make': 'Citroen', 'model': 'Dispatch'},
#  {'make': 'Citroen', 'model': 'DS3'},
#  {'make': 'Citroen', 'model': 'DS3 Cabrio'},
#  {'make': 'Citroen', 'model': 'DS4'},
#  {'make': 'Citroen', 'model': 'DS5'},
#  {'make': 'Citroen', 'model': 'e-Berlingo'},
#  {'make': 'Citroen', 'model': 'e-C3'},
#  {'make': 'Citroen', 'model': 'e-C3 Aircross'},
#  {'make': 'Citroen', 'model': 'e-C4'},
#  {'make': 'Citroen', 'model': 'e-C4 X'},
#  {'make': 'Citroen', 'model': 'e-C5 Aircross'},
#  {'make': 'Citroen', 'model': 'e-SpaceTourer'},
#  {'make': 'Citroen', 'model': 'Grand C4 Picasso'},
#  {'make': 'Citroen', 'model': 'Grand C4 SpaceTourer'},
#  {'make': 'Citroen', 'model': 'Holidays'},
#  {'make': 'Citroen', 'model': 'Nemo Multispace'},
#  {'make': 'Citroen', 'model': 'Relay'},
#  {'make': 'Citroen', 'model': 'Saxo'},
#  {'make': 'Citroen', 'model': 'SpaceTourer'},
#  {'make': 'Citroen', 'model': 'Xsara'},
#  {'make': 'Citroen', 'model': 'Xsara Picasso'},
#  {'make': 'Corbin', 'model': 'Sparrow'},
#  {'make': 'Corvette', 'model': 'C7'},
#  {'make': 'Corvette', 'model': 'Stingray'},
#  {'make': 'Corvette', 'model': 'Z06'},
#  {'make': 'CUPRA', 'model': 'Ateca'},
#  {'make': 'CUPRA', 'model': 'Born'},
#  {'make': 'CUPRA', 'model': 'Formentor'},
#  {'make': 'CUPRA', 'model': 'Leon'},
#  {'make': 'CUPRA', 'model': 'Tavascan'},
#  {'make': 'CUPRA', 'model': 'Terramar'},
#  {'make': 'Dacia', 'model': 'Bigster'},
#  {'make': 'Dacia', 'model': 'Duster'},
#  {'make': 'Dacia', 'model': 'Jogger'},
#  {'make': 'Dacia', 'model': 'Logan MCV'},
#  {'make': 'Dacia', 'model': 'Logan MCV Stepway'},
#  {'make': 'Dacia', 'model': 'Sandero'},
#  {'make': 'Dacia', 'model': 'Sandero Stepway'},
#  {'make': 'Dacia', 'model': 'Spring'},
#  {'make': 'Daewoo', 'model': 'Kalos'},
#  {'make': 'Daewoo', 'model': 'Matiz'},
#  {'make': 'Daihatsu', 'model': 'Charade'},
#  {'make': 'Daihatsu', 'model': 'Copen'},
#  {'make': 'Daihatsu', 'model': 'Cuore'},
#  {'make': 'Daihatsu', 'model': 'Fourtrak'},
#  {'make': 'Daihatsu', 'model': 'Materia'},
#  {'make': 'Daihatsu', 'model': 'Move'},
#  {'make': 'Daihatsu', 'model': 'Sirion'},
#  {'make': 'Daihatsu', 'model': 'Tanto'},
#  {'make': 'Daihatsu', 'model': 'Terios'},
#  {'make': 'Daihatsu', 'model': 'YRV'},
#  {'make': 'Daimler', 'model': 'Double Six'},
#  {'make': 'Daimler', 'model': 'Majestic'},
#  {'make': 'Daimler', 'model': 'Saloon'},
#  {'make': 'Daimler', 'model': 'Six'},
#  {'make': 'Daimler', 'model': 'Sovereign'},
#  {'make': 'Daimler', 'model': 'SP'},
#  {'make': 'Daimler', 'model': 'V8-250'},
#  {'make': 'Daimler', 'model': 'XJ6'},
#  {'make': 'Daimler', 'model': 'XJ Series'},
#  {'make': 'Datsun', 'model': 'Sunny'},
#  {'make': 'David Brown', 'model': 'Speedback GT'},
#  {'make': 'Dax', 'model': 'Rush'},
#  {'make': 'Dax', 'model': 'Tojeiro'},
#  {'make': 'Delorean', 'model': 'DMC-12'},
#  {'make': 'De Tomaso', 'model': 'Pantera'},
#  {'make': 'DFSK', 'model': 'Glory'},
#  {'make': 'Dodge', 'model': 'Caliber'},
#  {'make': 'Dodge', 'model': 'Challenger'},
#  {'make': 'Dodge', 'model': 'Charger'},
#  {'make': 'Dodge', 'model': 'Grand Caravan'},
#  {'make': 'Dodge', 'model': 'Journey'},
#  {'make': 'Dodge', 'model': 'Magnum'},
#  {'make': 'Dodge', 'model': 'Nitro'},
#  {'make': 'Dodge', 'model': 'RAM'},
#  {'make': 'Dodge', 'model': 'Viper'},
#  {'make': 'DS AUTOMOBILES', 'model': 'DS 3'},
#  {'make': 'DS AUTOMOBILES', 'model': 'DS 3 CABRIO'},
#  {'make': 'DS AUTOMOBILES', 'model': 'DS 3 CROSSBACK'},
#  {'make': 'DS AUTOMOBILES', 'model': 'DS 4'},
#  {'make': 'DS AUTOMOBILES', 'model': 'DS 4 CROSSBACK'},
#  {'make': 'DS AUTOMOBILES', 'model': 'DS 5'},
#  {'make': 'DS AUTOMOBILES', 'model': 'DS 7'},
#  {'make': 'DS AUTOMOBILES', 'model': 'DS 7 CROSSBACK'},
#  {'make': 'DS AUTOMOBILES', 'model': 'DS 9'},
#  {'make': 'DS AUTOMOBILES', 'model': 'DS No4'},
#  {'make': 'DS AUTOMOBILES', 'model': 'DS No8'},
#  {'make': 'E-COBRA', 'model': 'E-COBRA 2200W'},
#  {'make': 'Ferrari', 'model': '12Cilindri'},
#  {'make': 'Ferrari', 'model': '208'},
#  {'make': 'Ferrari', 'model': '246'},
#  {'make': 'Ferrari', 'model': '250'},
#  {'make': 'Ferrari', 'model': '288'},
#  {'make': 'Ferrari', 'model': '296 GTB'},
#  {'make': 'Ferrari', 'model': '296 GTS'},
#  {'make': 'Ferrari', 'model': '328'},
#  {'make': 'Ferrari', 'model': '330'},
#  {'make': 'Ferrari', 'model': '348'},
#  {'make': 'Ferrari', 'model': '355 F1'},
#  {'make': 'Ferrari', 'model': '360'},
#  {'make': 'Ferrari', 'model': '430'},
#  {'make': 'Ferrari', 'model': '456'},
#  {'make': 'Ferrari', 'model': '456M'},
#  {'make': 'Ferrari', 'model': '458'},
#  {'make': 'Ferrari', 'model': '488'},
#  {'make': 'Ferrari', 'model': '488 Challenge'},
#  {'make': 'Ferrari', 'model': '488 Pista'},
#  {'make': 'Ferrari', 'model': '512 BBI'},
#  {'make': 'Ferrari', 'model': '550'},
#  {'make': 'Ferrari', 'model': '575M'},
#  {'make': 'Ferrari', 'model': '599'},
#  {'make': 'Ferrari', 'model': '612'},
#  {'make': 'Ferrari', 'model': '812 Competizione'},
#  {'make': 'Ferrari', 'model': '812 GTS'},
#  {'make': 'Ferrari', 'model': '812 Superfast'},
#  {'make': 'Ferrari', 'model': 'California'},
#  {'make': 'Ferrari', 'model': 'Daytona'},
#  {'make': 'Ferrari', 'model': 'Daytona SP3'},
#  {'make': 'Ferrari', 'model': 'Dino'},
#  {'make': 'Ferrari', 'model': 'Dino 246 GT'},
#  {'make': 'Ferrari', 'model': 'Dino 308 GT4'},
#  {'make': 'Ferrari', 'model': 'F12 Berlinetta'},
#  {'make': 'Ferrari', 'model': 'F12 tdf'},
#  {'make': 'Ferrari', 'model': 'F355'},
#  {'make': 'Ferrari', 'model': 'F430'},
#  {'make': 'Ferrari', 'model': 'F8 Spider'},
#  {'make': 'Ferrari', 'model': 'F8 Tributo'},
#  {'make': 'Ferrari', 'model': 'FF'},
#  {'make': 'Ferrari', 'model': 'GTC4Lusso'},
#  {'make': 'Ferrari', 'model': 'LaFerrari'},
#  {'make': 'Ferrari', 'model': 'Mondial'},
#  {'make': 'Ferrari', 'model': 'Monza SP1'},
#  {'make': 'Ferrari', 'model': 'Portofino'},
#  {'make': 'Ferrari', 'model': 'Portofino M'},
#  {'make': 'Ferrari', 'model': 'Purosangue'},
#  {'make': 'Ferrari', 'model': 'Roma'},
#  {'make': 'Ferrari', 'model': 'Scuderia Spider'},
#  {'make': 'Ferrari', 'model': 'SF90 Spider'},
#  {'make': 'Ferrari', 'model': 'SF90 Stradale'},
#  {'make': 'Ferrari', 'model': 'SF90 XX Stradale'},
#  {'make': 'Ferrari', 'model': 'Superamerica'},
#  {'make': 'Ferrari', 'model': 'Testarossa'},
#  {'make': 'Fiat', 'model': '124 Spider'},
#  {'make': 'Fiat', 'model': '500'},
#  {'make': 'Fiat', 'model': '500C'},
#  {'make': 'Fiat', 'model': '500e'},
#  {'make': 'Fiat', 'model': '500e C'},
#  {'make': 'Fiat', 'model': '500L'},
#  {'make': 'Fiat', 'model': '500 Topolino'},
#  {'make': 'Fiat', 'model': '500X'},
#  {'make': 'Fiat', 'model': '500X Dolcevita'},
#  {'make': 'Fiat', 'model': '600'},
#  {'make': 'Fiat', 'model': '600e'},
#  {'make': 'Fiat', 'model': 'Barchetta'},
#  {'make': 'Fiat', 'model': 'Bravo'},
#  {'make': 'Fiat', 'model': 'Coupe'},
#  {'make': 'Fiat', 'model': 'Doblo'},
#  {'make': 'Fiat', 'model': 'Ducato'},
#  {'make': 'Fiat', 'model': 'E-Doblo'},
#  {'make': 'Fiat', 'model': 'Fiorino'},
#  {'make': 'Fiat', 'model': 'Fullback'},
#  {'make': 'Fiat', 'model': 'Grande Panda'},
#  {'make': 'Fiat', 'model': 'Grande Punto'},
#  {'make': 'Fiat', 'model': 'Idea'},
#  {'make': 'Fiat', 'model': 'Multipla'},
#  {'make': 'Fiat', 'model': 'Panda'},
#  {'make': 'Fiat', 'model': 'Punto'},
#  {'make': 'Fiat', 'model': 'Punto Evo'},
#  {'make': 'Fiat', 'model': 'Qubo'},
#  {'make': 'Fiat', 'model': 'Scudo'},
#  {'make': 'Fiat', 'model': 'Sedici'},
#  {'make': 'Fiat', 'model': 'Seicento'},
#  {'make': 'Fiat', 'model': 'Stilo'},
#  {'make': 'Fiat', 'model': 'Talento'},
#  {'make': 'Fiat', 'model': 'Tipo'},
#  {'make': 'Fiat', 'model': 'Uno'},
#  {'make': 'Fisker', 'model': 'Ocean'},
#  {'make': 'Ford', 'model': 'Anglia'},
#  {'make': 'Ford', 'model': 'B-Max'},
#  {'make': 'Ford', 'model': 'Bronco'},
#  {'make': 'Ford', 'model': 'Capri'},
#  {'make': 'Ford', 'model': 'C-Max'},
#  {'make': 'Ford', 'model': 'Cortina'},
#  {'make': 'Ford', 'model': 'Cougar'},
#  {'make': 'Ford', 'model': 'EcoSport'},
#  {'make': 'Ford', 'model': 'Edge'},
#  {'make': 'Ford', 'model': 'Escort'},
#  {'make': 'Ford', 'model': 'E-Tourneo Courier'},
#  {'make': 'Ford', 'model': 'E-Tourneo Custom'},
#  {'make': 'Ford', 'model': 'E-Transit Custom'},
#  {'make': 'Ford', 'model': 'Explorer'},
#  {'make': 'Ford', 'model': 'F1'},
#  {'make': 'Ford', 'model': 'F150'},
#  {'make': 'Ford', 'model': 'F350'},
#  {'make': 'Ford', 'model': 'Fiesta'},
#  {'make': 'Ford', 'model': 'Fiesta Van'},
#  {'make': 'Ford', 'model': 'Focus'},
#  {'make': 'Ford', 'model': 'Focus CC'},
#  {'make': 'Ford', 'model': 'Focus C-Max'},
#  {'make': 'Ford', 'model': 'Fusion'},
#  {'make': 'Ford', 'model': 'Galaxy'},
#  {'make': 'Ford', 'model': 'Granada'},
#  {'make': 'Ford', 'model': 'Grand C-Max'},
#  {'make': 'Ford', 'model': 'Grand Tourneo Connect'},
#  {'make': 'Ford', 'model': 'GT'},
#  {'make': 'Ford', 'model': 'Ka'},
#  {'make': 'Ford', 'model': 'Ka+'},
#  {'make': 'Ford', 'model': 'Kuga'},
#  {'make': 'Ford', 'model': 'Mercury'},
#  {'make': 'Ford', 'model': 'Model T'},
#  {'make': 'Ford', 'model': 'Mondeo'},
#  {'make': 'Ford', 'model': 'Mustang'},
#  {'make': 'Ford', 'model': 'Mustang Mach-E'},
#  {'make': 'Ford', 'model': 'Orion'},
#  {'make': 'Ford', 'model': 'Popular'},
#  {'make': 'Ford', 'model': 'Probe'},
#  {'make': 'Ford', 'model': 'Puma'},
#  {'make': 'Ford', 'model': 'Puma Gen-E'},
#  {'make': 'Ford', 'model': 'Ranchero'},
#  {'make': 'Ford', 'model': 'Ranger'},
#  {'make': 'Ford', 'model': 'Scorpio'},
#  {'make': 'Ford', 'model': 'Sierra'},
#  {'make': 'Ford', 'model': 'S-Max'},
#  {'make': 'Ford', 'model': 'Streetka'},
#  {'make': 'Ford', 'model': 'Tourneo Connect'},
#  {'make': 'Ford', 'model': 'Tourneo Courier'},
#  {'make': 'Ford', 'model': 'Tourneo Custom'},
#  {'make': 'Ford', 'model': 'Transit'},
#  {'make': 'Ford', 'model': 'Transit Connect'},
#  {'make': 'Ford', 'model': 'Transit Courier'},
#  {'make': 'Ford', 'model': 'Transit Custom'},
#  {'make': 'Geely', 'model': 'Geely EX5'},
#  {'make': 'Genesis', 'model': 'G70'},
#  {'make': 'Genesis', 'model': 'G80'},
#  {'make': 'Genesis', 'model': 'GV60'},
#  {'make': 'Genesis', 'model': 'GV70'},
#  {'make': 'Genesis', 'model': 'GV80'},
#  {'make': 'Ginetta', 'model': 'G40'},
#  {'make': 'GMC', 'model': 'Sierra'},
#  {'make': 'GMC', 'model': 'Yukon'},
#  {'make': 'Great Wall', 'model': 'Steed'},
#  {'make': 'GWM', 'model': 'Funky Cat'},
#  {'make': 'GWM', 'model': 'Haval Jolion Pro'},
#  {'make': 'GWM', 'model': 'ORA 03'},
#  {'make': 'GWM', 'model': 'POER300'},
#  {'make': 'Hillman', 'model': 'Husky'},
#  {'make': 'Honda', 'model': 'Accord'},
#  {'make': 'Honda', 'model': 'Beat'},
#  {'make': 'Honda', 'model': 'Civic'},
#  {'make': 'Honda', 'model': 'Concerto'},
#  {'make': 'Honda', 'model': 'CR-V'},
#  {'make': 'Honda', 'model': 'CR-X'},
#  {'make': 'Honda', 'model': 'CR-Z'},
#  {'make': 'Honda', 'model': 'e:Ny1'},
#  {'make': 'Honda', 'model': 'Elysion'},
#  {'make': 'Honda', 'model': 'Fit'},
#  {'make': 'Honda', 'model': 'Freed'},
#  {'make': 'Honda', 'model': 'FR-V'},
#  {'make': 'Honda', 'model': 'Honda E'},
#  {'make': 'Honda', 'model': 'HR-V'},
#  {'make': 'Honda', 'model': 'Insight'},
#  {'make': 'Honda', 'model': 'Integra'},
#  {'make': 'Honda', 'model': 'Jazz'},
#  {'make': 'Honda', 'model': 'Legend'},
#  {'make': 'Honda', 'model': 'Life'},
#  {'make': 'Honda', 'model': 'Logo'},
#  {'make': 'Honda', 'model': 'N-Box'},
#  {'make': 'Honda', 'model': 'NSX'},
#  {'make': 'Honda', 'model': 'Odyssey'},
#  {'make': 'Honda', 'model': 'Prelude'},
#  {'make': 'Honda', 'model': 'S2000'},
#  {'make': 'Honda', 'model': 'S660'},
#  {'make': 'Honda', 'model': 'Stepwagon'},
#  {'make': 'Honda', 'model': 'Stream'},
#  {'make': 'Honda', 'model': 'ZR-V'},
#  {'make': 'Humber', 'model': 'Super'},
#  {'make': 'Hummer', 'model': 'H1'},
#  {'make': 'Hummer', 'model': 'H2'},
#  {'make': 'Hummer', 'model': 'H3'},
#  {'make': 'Hyundai', 'model': 'Accent'},
#  {'make': 'Hyundai', 'model': 'Amica'},
#  {'make': 'Hyundai', 'model': 'Atoz'},
#  {'make': 'Hyundai', 'model': 'BAYON'},
#  {'make': 'Hyundai', 'model': 'Coupe'},
#  {'make': 'Hyundai', 'model': 'Elantra'},
#  {'make': 'Hyundai', 'model': 'Genesis'},
#  {'make': 'Hyundai', 'model': 'Getz'},
#  {'make': 'Hyundai', 'model': 'Grandeur'},
#  {'make': 'Hyundai', 'model': 'i10'},
#  {'make': 'Hyundai', 'model': 'i20'},
#  {'make': 'Hyundai', 'model': 'i30'},
#  {'make': 'Hyundai', 'model': 'i40'},
#  {'make': 'Hyundai', 'model': 'i800'},
#  {'make': 'Hyundai', 'model': 'INSTER'},
#  {'make': 'Hyundai', 'model': 'IONIQ'},
#  {'make': 'Hyundai', 'model': 'IONIQ 5'},
#  {'make': 'Hyundai', 'model': 'IONIQ 6'},
#  {'make': 'Hyundai', 'model': 'IONIQ 9'},
#  {'make': 'Hyundai', 'model': 'ix20'},
#  {'make': 'Hyundai', 'model': 'ix35'},
#  {'make': 'Hyundai', 'model': 'KONA'},
#  {'make': 'Hyundai', 'model': 'Matrix'},
#  {'make': 'Hyundai', 'model': 'Santa Fe'},
#  {'make': 'Hyundai', 'model': 'Sonata'},
#  {'make': 'Hyundai', 'model': 'Terracan'},
#  {'make': 'Hyundai', 'model': 'TUCSON'},
#  {'make': 'Hyundai', 'model': 'Veloster'},
#  {'make': 'INEOS', 'model': 'Grenadier'},
#  {'make': 'INEOS', 'model': 'Grenadier Quartermaster'},
#  {'make': 'Infiniti', 'model': 'EX'},
#  {'make': 'Infiniti', 'model': 'FX'},
#  {'make': 'Infiniti', 'model': 'G'},
#  {'make': 'Infiniti', 'model': 'M'},
#  {'make': 'Infiniti', 'model': 'Q30'},
#  {'make': 'Infiniti', 'model': 'Q50'},
#  {'make': 'Infiniti', 'model': 'Q60'},
#  {'make': 'Infiniti', 'model': 'Q70'},
#  {'make': 'Infiniti', 'model': 'QX30'},
#  {'make': 'Infiniti', 'model': 'QX70'},
#  {'make': 'Infiniti', 'model': 'Vettel'},
#  {'make': 'Isuzu', 'model': 'Bighorn'},
#  {'make': 'Isuzu', 'model': 'D-Max'},
#  {'make': 'Isuzu', 'model': 'Rodeo'},
#  {'make': 'Isuzu', 'model': 'TF'},
#  {'make': 'Iveco', 'model': 'Daily'},
#  {'make': 'JAECOO', 'model': 'JAECOO 5'},
#  {'make': 'JAECOO', 'model': 'JAECOO 7'},
#  {'make': 'Jaguar', 'model': 'E-PACE'},
#  {'make': 'Jaguar', 'model': 'E-Type'},
#  {'make': 'Jaguar', 'model': 'F-PACE'},
#  {'make': 'Jaguar', 'model': 'F-Type'},
#  {'make': 'Jaguar', 'model': 'I-PACE'},
#  {'make': 'Jaguar', 'model': 'Mark I'},
#  {'make': 'Jaguar', 'model': 'Mark II'},
#  {'make': 'Jaguar', 'model': 'Mark V'},
#  {'make': 'Jaguar', 'model': 'S-Type'},
#  {'make': 'Jaguar', 'model': 'XE'},
#  {'make': 'Jaguar', 'model': 'XF'},
#  {'make': 'Jaguar', 'model': 'XFR-S'},
#  {'make': 'Jaguar', 'model': 'XJ'},
#  {'make': 'Jaguar', 'model': 'XJ220'},
#  {'make': 'Jaguar', 'model': 'XJR'},
#  {'make': 'Jaguar', 'model': 'XJR-S'},
#  {'make': 'Jaguar', 'model': 'XJS'},
#  {'make': 'Jaguar', 'model': 'XK'},
#  {'make': 'Jaguar', 'model': 'XK120'},
#  {'make': 'Jaguar', 'model': 'XK150'},
#  {'make': 'Jaguar', 'model': 'XK8'},
#  {'make': 'Jaguar', 'model': 'XKR'},
#  {'make': 'Jaguar', 'model': 'XKR-S'},
#  {'make': 'Jaguar', 'model': 'X-Type'},
#  {'make': 'JBA', 'model': 'Falcon'},
#  {'make': 'Jeep', 'model': 'Avenger'},
#  {'make': 'Jeep', 'model': 'Cherokee'},
#  {'make': 'Jeep', 'model': 'Commander'},
#  {'make': 'Jeep', 'model': 'Compass'},
#  {'make': 'Jeep', 'model': 'Gladiator'},
#  {'make': 'Jeep', 'model': 'Grand Cherokee'},
#  {'make': 'Jeep', 'model': 'Patriot'},
#  {'make': 'Jeep', 'model': 'Renegade'},
#  {'make': 'Jeep', 'model': 'Wrangler'},
#  {'make': 'Jensen', 'model': 'Interceptor'},
#  {'make': 'KGM', 'model': 'Actyon'},
#  {'make': 'KGM', 'model': 'Korando'},
#  {'make': 'KGM', 'model': 'Korando e-Motion'},
#  {'make': 'KGM', 'model': 'Musso'},
#  {'make': 'KGM', 'model': 'Rexton'},
#  {'make': 'KGM', 'model': 'Tivoli'},
#  {'make': 'KGM', 'model': 'Torres'},
#  {'make': 'KGM', 'model': 'Torres EVX'},
#  {'make': 'Kia', 'model': 'Carens'},
#  {'make': 'Kia', 'model': 'Ceed'},
#  {'make': 'Kia', 'model': 'Cerato'},
#  {'make': 'Kia', 'model': 'EV3'},
#  {'make': 'Kia', 'model': 'EV4'},
#  {'make': 'Kia', 'model': 'EV5'},
#  {'make': 'Kia', 'model': 'EV6'},
#  {'make': 'Kia', 'model': 'EV9'},
#  {'make': 'Kia', 'model': 'K4'},
#  {'make': 'Kia', 'model': 'Magentis'},
#  {'make': 'Kia', 'model': 'Mentor II'},
#  {'make': 'Kia', 'model': 'Niro'},
#  {'make': 'Kia', 'model': 'Optima'},
#  {'make': 'Kia', 'model': 'Picanto'},
#  {'make': 'Kia', 'model': 'ProCeed'},
#  {'make': 'Kia', 'model': 'PV5'},
#  {'make': 'Kia', 'model': 'Rio'},
#  {'make': 'Kia', 'model': 'Sedona'},
#  {'make': 'Kia', 'model': 'Sorento'},
#  {'make': 'Kia', 'model': 'Soul'},
#  {'make': 'Kia', 'model': 'Sportage'},
#  {'make': 'Kia', 'model': 'Stinger'},
#  {'make': 'Kia', 'model': 'Stonic'},
#  {'make': 'Kia', 'model': 'Venga'},
#  {'make': 'Kia', 'model': 'XCeed'},
#  {'make': 'Koenigsegg', 'model': 'Agera'},
#  {'make': 'Koenigsegg', 'model': 'Regera'},
#  {'make': 'KTM', 'model': 'X-Bow'},
#  {'make': 'Lada', 'model': '1600'},
#  {'make': 'Lada', 'model': 'Niva'},
#  {'make': 'Lagonda', 'model': 'LG6 Roadster'},
#  {'make': 'Lamborghini', 'model': 'Aventador'},
#  {'make': 'Lamborghini', 'model': 'Countach'},
#  {'make': 'Lamborghini', 'model': 'Gallardo'},
#  {'make': 'Lamborghini', 'model': 'Huracan'},
#  {'make': 'Lamborghini', 'model': 'Jalpa'},
#  {'make': 'Lamborghini', 'model': 'Miura'},
#  {'make': 'Lamborghini', 'model': 'Murcielago'},
#  {'make': 'Lamborghini', 'model': 'Reventon'},
#  {'make': 'Lamborghini', 'model': 'Revuelto'},
#  {'make': 'Lamborghini', 'model': 'Silhouette'},
#  {'make': 'Lamborghini', 'model': 'Urus'},
#  {'make': 'Lancia', 'model': 'Beta'},
#  {'make': 'Lancia', 'model': 'Delta'},
#  {'make': 'Lancia', 'model': 'Stratos'},
#  {'make': 'Land Rover', 'model': '110'},
#  {'make': 'Land Rover', 'model': '90'},
#  {'make': 'Land Rover', 'model': 'Defender 110'},
#  {'make': 'Land Rover', 'model': 'Defender 130'},
#  {'make': 'Land Rover', 'model': 'Defender 90'},
#  {'make': 'Land Rover', 'model': 'Defender Unspecified'},
#  {'make': 'Land Rover', 'model': 'Discovery'},
#  {'make': 'Land Rover', 'model': 'Discovery 3'},
#  {'make': 'Land Rover', 'model': 'Discovery 4'},
#  {'make': 'Land Rover', 'model': 'Discovery Sport'},
#  {'make': 'Land Rover', 'model': 'Freelander'},
#  {'make': 'Land Rover', 'model': 'Freelander 2'},
#  {'make': 'Land Rover', 'model': 'Lightweight'},
#  {'make': 'Land Rover', 'model': 'Range Rover'},
#  {'make': 'Land Rover', 'model': 'Range Rover Evoque'},
#  {'make': 'Land Rover', 'model': 'Range Rover Sport'},
#  {'make': 'Land Rover', 'model': 'Range Rover Velar'},
#  {'make': 'Land Rover', 'model': 'Series I'},
#  {'make': 'Land Rover', 'model': 'Series II'},
#  {'make': 'Land Rover', 'model': 'Series III'},
#  {'make': 'LDV', 'model': 'MAXUS'},
#  {'make': 'Leapmotor', 'model': 'B10'},
#  {'make': 'Leapmotor', 'model': 'C10'},
#  {'make': 'Leapmotor', 'model': 'T03'},
#  {'make': 'LEVC', 'model': 'TX'},
#  {'make': 'Lexus', 'model': 'CT'},
#  {'make': 'Lexus', 'model': 'ES'},
#  {'make': 'Lexus', 'model': 'GS'},
#  {'make': 'Lexus', 'model': 'GS F'},
#  {'make': 'Lexus', 'model': 'IS'},
#  {'make': 'Lexus', 'model': 'IS F'},
#  {'make': 'Lexus', 'model': 'LBX'},
#  {'make': 'Lexus', 'model': 'LC'},
#  {'make': 'Lexus', 'model': 'LM'},
#  {'make': 'Lexus', 'model': 'LS'},
#  {'make': 'Lexus', 'model': 'LX'},
#  {'make': 'Lexus', 'model': 'NX'},
#  {'make': 'Lexus', 'model': 'RC'},
#  {'make': 'Lexus', 'model': 'RC F'},
#  {'make': 'Lexus', 'model': 'RX'},
#  {'make': 'Lexus', 'model': 'RX L'},
#  {'make': 'Lexus', 'model': 'RZ'},
#  {'make': 'Lexus', 'model': 'SC'},
#  {'make': 'Lexus', 'model': 'UX'},
#  {'make': 'Leyland', 'model': 'Mini'},
#  {'make': 'Lincoln', 'model': 'Navigator'},
#  {'make': 'Lister', 'model': 'Knobbly'},
#  {'make': 'Lister', 'model': 'Knobbly Continuation'},
#  {'make': 'London Taxis International', 'model': 'TX4'},
#  {'make': 'London Taxis International', 'model': 'TXI'},
#  {'make': 'Lotus', 'model': '340R'},
#  {'make': 'Lotus', 'model': 'Elan'},
#  {'make': 'Lotus', 'model': 'Elan +2'},
#  {'make': 'Lotus', 'model': 'Eletre'},
#  {'make': 'Lotus', 'model': 'Elise'},
#  {'make': 'Lotus', 'model': 'Emeya'},
#  {'make': 'Lotus', 'model': 'Emira'},
#  {'make': 'Lotus', 'model': 'Esprit'},
#  {'make': 'Lotus', 'model': 'Evora'},
#  {'make': 'Lotus', 'model': 'Excel'},
#  {'make': 'Lotus', 'model': 'Exige'},
#  {'make': 'Mahindra', 'model': 'CJ5'},
#  {'make': 'Mahindra', 'model': 'Indian'},
#  {'make': 'Maserati', 'model': '3200'},
#  {'make': 'Maserati', 'model': 'Biturbo'},
#  {'make': 'Maserati', 'model': 'Cambiocorsa'},
#  {'make': 'Maserati', 'model': 'Coupe'},
#  {'make': 'Maserati', 'model': 'Ghibli'},
#  {'make': 'Maserati', 'model': 'GranCabrio'},
#  {'make': 'Maserati', 'model': 'Gransport'},
#  {'make': 'Maserati', 'model': 'Granturismo'},
#  {'make': 'Maserati', 'model': 'Grecale'},
#  {'make': 'Maserati', 'model': 'Levante'},
#  {'make': 'Maserati', 'model': 'MC20'},
#  {'make': 'Maserati', 'model': 'Quattroporte'},
#  {'make': 'Maserati', 'model': 'Spyder'},
#  {'make': 'MAXUS', 'model': 'eTERRON 9'},
#  {'make': 'MAXUS', 'model': 'Mifa 7'},
#  {'make': 'MAXUS', 'model': 'Mifa 9'},
#  {'make': 'MAXUS', 'model': 'T60 MAX'},
#  {'make': 'MAXUS', 'model': 'T90EV'},
#  {'make': 'Maybach', 'model': '57'},
#  {'make': 'Maybach', 'model': '62'},
#  {'make': 'Mazda', 'model': '323'},
#  {'make': 'Mazda', 'model': '626'},
#  {'make': 'Mazda', 'model': 'B2500'},
#  {'make': 'Mazda', 'model': 'Biante'},
#  {'make': 'Mazda', 'model': 'Bongo'},
#  {'make': 'Mazda', 'model': 'CX-3'},
#  {'make': 'Mazda', 'model': 'CX-30'},
#  {'make': 'Mazda', 'model': 'CX-5'},
#  {'make': 'Mazda', 'model': 'CX-60'},
#  {'make': 'Mazda', 'model': 'CX-7'},
#  {'make': 'Mazda', 'model': 'CX-80'},
#  {'make': 'Mazda', 'model': 'Demio'},
#  {'make': 'Mazda', 'model': 'Eunos'},
#  {'make': 'Mazda', 'model': 'Mazda2'},
#  {'make': 'Mazda', 'model': 'Mazda2 HYBRID'},
#  {'make': 'Mazda', 'model': 'Mazda3'},
#  ...]

# %%
#Create a dataframe with all the pairs make-model
df_ref = pd.DataFrame(rows).drop_duplicates()

# %% [markdown]
# Map some specific values to match train.csv dataset

# %%
brand_map = {
    "Vauxhall": "Opel",
    "Mercedes-Benz": "Mercedes",
    "Volkswagen":"VW"
}

df_ref["make"] = df_ref["make"].map(brand_map).fillna(df_ref["make"])

# %%
new_rows_data = [
    {'make': 'Opel', 'model': 'gtc'},
    {'make': 'VW', 'model': 'shuttle'},
    {'make': 'Audi', 'model': 'a6'},
    {'make': 'Skoda', 'model': 'yeti outdoor'}
]

df_ref = pd.concat([df_ref, pd.DataFrame(new_rows_data)], ignore_index=True)

# %%
is_mercedes = df_ref["make"].eq("Mercedes")
has_class   = df_ref["model"].str.contains(r"\bclass\b", case=False)

# %%
to_dup = df_ref[is_mercedes & ~has_class].copy()
to_dup["model"] = to_dup["model"] + " Class"

# %%
df_final = (
    pd.concat([df_ref, to_dup], ignore_index=True)
      .drop_duplicates(subset=["make","model"])
      .sort_values(["make","model"])
      .reset_index(drop=True)
)

# %%
df_final
# Out:
#            make       model
# 0            AC       Cobra
# 1            AC   Dax Cobra
# 2            AK       Cobra
# 3        Abarth  124 Spider
# 4        Abarth         500
# ...         ...         ...
# 1605  Westfield         Sei
# 1606  Westfield       Sport
# 1607  Westfield          Xi
# 1608      XPENG          G6
# 1609      Zenos         E10
#
# [1610 rows x 2 columns]

# %%
#export as csv
df_final.to_csv("make_model_catalog.csv", index=False)
